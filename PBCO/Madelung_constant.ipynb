# %% [markdown]
# # code for my PHYS4050 homework

# %%
from math import sqrt

def madelung_2D_fn(half_lattice_size):
    M = 0.0

    for i in range(-half_lattice_size, half_lattice_size + 1):
        for j in range(-half_lattice_size, half_lattice_size + 1):
            if i == 0 and j == 0:
                continue

            idx_squared = i**2 + j**2
            distance = sqrt(idx_squared)
            sign = 1 if idx_squared % 2 == 0 else -1
            M += sign / distance

    return M

half_lattice_size = 3000
madelung_value_fn = madelung_2D_fn(lattice_size)
print(f"The Madelung constant from function for 2D NaCl with L={lattice_size} is: {madelung_value_fn}")
print("Expected value is approximately -1.615542")
# Out:
# The Madelung constant from function for 2D NaCl with L=3000 is: -1.6153069637299224
# Expected value is approximately -1.615542
