# %% [markdown]
# # Pr-YBCO version Fit modes C4

# %%
import numpy as np
import matplotlib.pyplot as plt
import tensorflow as tf
import pandas as pd
from PrNiO2_C4_alris_functions2 import shift_atoms, transform_list_hkl_p63_p65, get_structure_factors , atom_position_list
from itertools import chain
from matplotlib.markers import MarkerStyle
from tqdm import tqdm
from time import time

# %config InlineBackend.figure_format = 'svg' # make figures appears in .svg style

num_threads = 2  

# Configure TensorFlow to use multiple threads
tf.config.threading.set_intra_op_parallelism_threads(num_threads)
tf.config.threading.set_inter_op_parallelism_threads(num_threads)

print(f"Using {num_threads} threads for intra-op and inter-op parallelism.")

num_of_params = 14
# Out:
# Using 2 threads for intra-op and inter-op parallelism.

# %% [markdown]
# Define the function containing the fitting parameters
#
# <span style="color:yellow">Note on actual unit cell structure refinement problem:</span>
# - `fun_tf()` correspond to the **structure factor calculation function** (one has to convert it to a **TF-compatible** function)
# - <span style="color:red">If conversion to TF-compatible function is not possible, then this approach will probably not work (or becomes much more tedious at least)</span>

# %%
#convert the simulated data to log10 scale (if needed)

def log10(x):
  numerator = tf.math.log(x)
  denominator = tf.math.log(tf.constant(10, dtype=numerator.dtype))
  return numerator / denominator

# %%
def fun_tf(x, pars):
    """
    Fast computation of structure factors with parameter-dependent structure.
        # Get modified structure
    modified_struct = shift_atoms_p65(*pars)
    neg_h = tf.stack([-x[:, 0], x[:, 1], x[:, 2]], axis=1)
    x_combined = tf.concat([x, neg_h], axis=0)  # Shape [2N, 3]

    x_combined = transform_list_hkl_p63_p65(x_combined)

    # Get structure factors
    sf_combined = get_structure_factors(x_combined, modified_struct)
    # Compute intensity
    # Split and compute intensity
    sf_hkl = sf_combined[:tf.shape(x)[0]]
    sf_neg_k = sf_combined[tf.shape(x)[0]:]
    
    intensity = (tf.abs(sf_hkl) + tf.abs(sf_neg_k)) ** 2
    return intensity / tf.reduce_max(intensity)
    """
    # Get modified structure
    atom_shift_list = shift_atoms(*pars)
    print(f"Shape of atom_shift_list: {len(atom_shift_list)}")



    # Flatten atom_shift_list if it contains nested lists
    flat_atom_shift_list = list(chain.from_iterable(
        x if isinstance(x, list) else [x] for x in atom_shift_list
    ))
    modified_struct = atom_position_list(*flat_atom_shift_list)

    #neg_h = tf.stack([-x[:, 0], x[:, 1], x[:, 2]], axis=1)
    x_combined = x
    #x_combined = tf.concat([x, neg_h], axis=0)  # Shape [2N, 3]

    x_combined = transform_list_hkl_p63_p65(x_combined)

    # Get structure factors
    sf_combined = get_structure_factors(x_combined, modified_struct)
    # Compute intensity
    # Split and compute intensity
    sf_hkl = sf_combined[:tf.shape(x)[0]]
    
    print(f"Shape of sf_combined: {sf_combined.shape}, Shape of x_combined: {x_combined.shape}")
    
    intensity = (tf.abs(sf_hkl)) ** 2
    w = tf.constant(0.00159, dtype=tf.float32)  # Debye-Waller factor is 0.00159
    qnorms = tf.norm(tf.cast(x_combined[:tf.shape(x)[0]], tf.float32), axis=1)
    # qnorms = tf.reshape(qnorms, (-1, 1))  # Reshape to match the shape of intensity
    intensity = intensity * tf.exp(-w * qnorms ** 2)  # Apply Debye-Waller factor
    #intensity = log10(intensity + 1)  # Convert to log10 scale
    return intensity / tf.reduce_max(intensity)

# %%
experimental_data = pd.read_csv('C:/Users/User/Desktop/uzh_intern/CrystalClearFit/alrisDistortionFit/PrNiO2/C4/raw_data/combined.csv')
"""
# reduce data to l in [0.5, 1.5, 2.5, 3.5, 4.5 ]
experimental_data = experimental_data[
    (experimental_data["l"] == 0.5) |
    (experimental_data["l"] == 1.5) |
    (experimental_data["l"] == 2.5) |
    (experimental_data["l"] == 3.5) |
    (experimental_data["l"] == 4.5)
]
"""

hkl_list = experimental_data[["h", "k", "l"]].values.tolist()
hkl_list = tf.convert_to_tensor(hkl_list, dtype=tf.float32)
print(experimental_data.shape)
# Out:
# (910, 17)

# %% [markdown]
# Sample the "training data" (features and labels)
#
# <span style="color:yellow">Note on actual unit cell structure refinement problem:</span>
# - The features are the (h,k,l) coordinates (e.g. a vector of size `n_features` x 3, i.e. `n_dim = 3`)
# - Maybe one has to normalize the features (i.e. not using integers but floats between -1 (0) and 1)? Before passing them to the structure calculation function, they should be again rescaled to integers
# - The labels would be the experimental intensities (again, maybe have to be normalized to the range between 0 and 1)

# %%
n_features = experimental_data.shape[0]
n_dim = 3

features = hkl_list
labels = experimental_data["intensity_exp"].tolist()
#labels = tf.convert_to_tensor(labels, dtype=tf.float32)

vol_err = experimental_data["intensity_exp_err"].tolist()
labels_err = []
for label, err in zip(labels, vol_err):
    
    labels_err.append(np.log10((label + 1))**0.5)  # Inverse error


labels = labels / np.max(labels)  # Normalize labels

labels_err = tf.convert_to_tensor(labels_err, dtype=tf.float32)
labels = tf.convert_to_tensor(labels, dtype=tf.float32)

labels = tf.expand_dims(labels, axis=-1)  # Ensure labels are 2D
labels_err = tf.expand_dims(labels_err, axis=-1)  # Ensure labels_err are 2D

print("Max label err:", np.max(labels_err))
print("min label err:", np.min(labels_err))
print("Features shape:", features.shape)
print("Labels shape:", labels.shape)
print('error shape:', labels_err.shape)
print("Max label:", np.max(labels))
print("min label :", np.min(labels))
# Out:
# Max label err: 0.548662
# min label err: 0.0
# Features shape: (910, 3)
# Labels shape: (910, 1)
# error shape: (910, 1)
# Max label: 1.0
# min label : 0.0

# %% [markdown]
# Define a simple model
#
# <span style="color:yellow">Note on actual unit cell structure refinement problem:</span>
# - The six parameters (a,b,c,d,e,f) correspond to the fractional atomic shifts in the modes w.r.t. unit cell lengths
# - Instead of `sigmoid`, `tanh` should be applied to the parameters before passing them to the structure factor calculation function (ensures smoother gradient landscape)
# - The `tanh` function can furthermore be limited to a specific range (e.g. if atomic distortions should not exceed +- 0.1)

# %%
class FunAsLayer(tf.keras.layers.Layer):
    def __init__(self, max_mode_amps,**kwargs):
        super().__init__(**kwargs)
        self.max_mode_amps = max_mode_amps

    def build(self, input_shape):
        self.param = self.add_weight(name='param', shape=(num_of_params,), initializer=tf.keras.initializers.he_uniform(), trainable=True)
        super().build(input_shape)

    def call(self, inputs):
        # Apply tanh to ensure parameters stay within the [-1, 1] range then multiply by max_mode_amps so each parameter is scaled corresponding to the element in max_mode_amps
        pretransform = tf.tanh(self.param)
        transformed_params = pretransform * self.max_mode_amps  # Scale parameters

        output = fun_tf(inputs, tf.unstack(transformed_params))
        return tf.reshape(output , [-1])  # Ensure output is 1D

# %% [markdown]
# Create optimizer and define loss function
#
# <span style="color:yellow">Note on actual unit cell structure refinement problem:</span>
# - The learning rate must be determined by experimentation (same holds for the batch size and the number of epochs below)
# - As a loss function, one can try either MSE or R-score (MSE seems to be the more "natural choice" in this case)

# %%
"""
# R-Score based on intensity
class RFactorLoss(tf.keras.losses.Loss):
    def call(self, y_true, y_pred):
        return tf.reduce_sum(tf.abs(y_true - y_pred)) / tf.reduce_sum(y_true)
"""
    
# mean squared error
class PerSampleMSE(tf.keras.losses.Loss):
    def __init__(self):
        super().__init__(reduction=tf.keras.losses.Reduction.NONE)

    def call(self, y_true, y_pred):
        squared_error = tf.square(y_true - y_pred)
        per_sample_mse = tf.reduce_mean(squared_error, axis=-1)
        return per_sample_mse  # shape (batch_size,)

class MSE_weighted(tf.keras.losses.Loss):
    def call(self, y_true, y_pred):
        # Assume y_true = [labels, errors]
        print('ytrue shape:', y_true.shape)
        print('y true' , y_true)
        labels = y_true[:, 0]
        weights = y_true[:, 1]

        mse = tf.square(labels - y_pred)
        return tf.reduce_sum(mse * weights) / tf.reduce_sum(weights)


# Define the custom metric function
def r_factor_metric(y_true, y_pred):
    labels = y_true
    return tf.reduce_sum(tf.abs(labels - y_pred)) / tf.reduce_sum(labels)

# %% [markdown]
# Train the model for n iterations (to try different initial weights)
#
# <span style="color:yellow">Note on actual unit cell structure refinement problem:</span>
# - The number of iterations defines the "starting position" $w_0$ of the gradient descent algorithm
# - Because there are probably many local minima, changing $w_0$ allows the algorithm to find different minima and increases the chances of finding the global minima

# %%
#squeeze labels and labels_err to ensure they are 1D tensors
#labels = tf.squeeze(labels)
#labels_err = tf.squeeze(labels_err)

print("labels shape:", labels.shape)
print("labels_err shape:", labels_err.shape)


lr = [3e-2]
best_pars_overall = None
best_rf_overall = np.inf
best_loss_overall = []
for learning_rate in lr:
    time_start = time()
    print(f"Learning rate: {learning_rate}")
    optim = tf.keras.optimizers.Adam(learning_rate=learning_rate)

    max_mode_amps = tf.constant([2.0,2.0,2.83,2.83,4.0,4.0,4.0,4.0,4.0,4.0,4.0,4.0,2.0,2.0], dtype=tf.float32) 
    print("max_mode_amps shape:", max_mode_amps.shape)

    n_epochs = 500
    histories = []
    n_iter = 2

    min_loss = np.inf
    best_pars = None

    # List to store the loss values for each epoch
    all_losses = []


    for i in range(n_iter):
        # Create the model
        inputs = tf.keras.Input(shape=(n_dim,))
        outputs = FunAsLayer(max_mode_amps)(inputs)
        model = tf.keras.Model(inputs, outputs)

        # Compile the model with the custom loss function and metric
        model.compile(
            optimizer=optim,
            loss= 'msle', # MSE_weighted() if using errors
            metrics=[r_factor_metric]

        )
        
        history = model.fit(
        x=features,
        y=labels,  # replace with combined_labels if using errors
        batch_size = features.shape[0], # Use a smaller batch size features.shape[0]
        epochs=n_epochs,
        verbose='auto',
        shuffle=True, # not sure whether this matters
        # callbacks=[cb]
        sample_weight=labels_err  # Use sample weights if you have errors
        )

        histories.append(history)
        all_losses.append(history.history['loss'])
        # Check final loss
        final_loss = history.history['loss'][-1]
        print(model.layers[-1].get_weights()[0].shape)
        curren_model_pars = max_mode_amps * tf.tanh(model.layers[-1].get_weights()[0])
        print(f"Final loss: {final_loss:.3e}")
        '''
        print(f"Best parameters for iteration {i+1}:")
        for j, par in enumerate(curren_model_pars):
            print(f"Parameter {j+1}: {par.numpy():.4f}")
        '''

        if final_loss < min_loss:
            # Update best model parameters
            best_model_pars = max_mode_amps * tf.tanh(model.layers[-1].get_weights()[0])
            min_loss = final_loss
            rf = r_factor_metric(labels, fun_tf(features, best_model_pars))
            print(f"Iteration {i+1} - New best loss: {min_loss:.3e} (R-factor: {rf:.3e})")

    if min_loss < best_rf_overall:
        best_rf_overall = min_loss
        best_pars_overall = best_model_pars
        best_loss_overall = all_losses
    print(f"time elapsed: {time() - time_start:.2f} seconds")
    print(f"With {n_epochs*n_iter /(time() - time_start)} iterations per second")
    # Plotting the loss values
    plt.figure(figsize=(10, 6))

    # Plot the loss values for each iteration
    for i, loss_values in enumerate(all_losses):
        plt.plot(loss_values, label=f'Iteration {i+1}')

    plt.title(f'Loss vs Epochs with Learning Rate {learning_rate}')
    plt.xlabel('Epochs')
    plt.ylabel('Loss')
    # plt.legend()
    plt.grid(True)
    plt.show()
# Out:
# labels shape: (910, 1)
# labels_err shape: (910, 1)
# Learning rate: 0.03
# max_mode_amps shape: (14,)
# Shape of atom_shift_list: 14
# Shape of sf_combined: (None,), Shape of x_combined: (None, 3)
# Epoch 1/500
# Shape of atom_shift_list: 14
# Shape of sf_combined: (910,), Shape of x_combined: (910, 3)
# Shape of atom_shift_list: 14
# Shape of sf_combined: (910,), Shape of x_combined: (910, 3)
# 1/1 [==============================] - 3s 3s/step - loss: 0.0038 - r_factor_metric: 1.1090
# Epoch 2/500
# 1/1 [==============================] - 0s 7ms/step - loss: 0.0037 - r_factor_metric: 1.0845
# Epoch 3/500
# 1/1 [==============================] - 0s 7ms/step - loss: 0.0036 - r_factor_metric: 1.0726
# Epoch 4/500
# 1/1 [==============================] - 0s 7ms/step - loss: 0.0036 - r_factor_metric: 1.0662
# Epoch 5/500
# 1/1 [==============================] - 0s 11ms/step - loss: 0.0035 - r_factor_metric: 1.0596
# Epoch 6/500
# 1/1 [==============================] - 0s 8ms/step - loss: 0.0035 - r_factor_metric: 1.0527
# Epoch 7/500
# 1/1 [==============================] - 0s 7ms/step - loss: 0.0035 - r_factor_metric: 1.0471
# Epoch 8/500
# 1/1 [==============================] - 0s 8ms/step - loss: 0.0035 - r_factor_metric: 1.0431
# Epoch 9/500
# 1/1 [==============================] - 0s 8ms/step - loss: 0.0035 - r_factor_metric: 1.0396
# Epoch 10/500
# 1/1 [==============================] - 0s 10ms/step - loss: 0.0035 - r_factor_metric: 1.0365
# Epoch 11/500
# 1/1 [==============================] - 0s 8ms/step - loss: 0.0035 - r_factor_metric: 1.0344
# Epoch 12/500
# 1/1 [==============================] - 0s 9ms/step - loss: 0.0035 - r_factor_metric: 1.0324
# Epoch 13/500
# 1/1 [==============================] - 0s 9ms/step - loss: 0.0035 - r_factor_metric: 1.0311
# Epoch 14/500
# 1/1 [==============================] - 0s 9ms/step - loss: 0.0035 - r_factor_metric: 1.0300
# Epoch 15/500
# 1/1 [==============================] - 0s 9ms/step - loss: 0.0035 - r_factor_metric: 1.0290
# Epoch 16/500
# 1/1 [==============================] - 0s 9ms/step - loss: 0.0034 - r_factor_metric: 1.0282
# Epoch 17/500
# 1/1 [==============================] - 0s 9ms/step - loss: 0.0034 - r_factor_metric: 1.0274
# Epoch 18/500
# 1/1 [==============================] - 0s 8ms/step - loss: 0.0034 - r_factor_metric: 1.0266
# Epoch 19/500
# 1/1 [==============================] - 0s 9ms/step - loss: 0.0034 - r_factor_metric: 1.0261
# Epoch 20/500
# 1/1 [==============================] - 0s 9ms/step - loss: 0.0034 - r_factor_metric: 1.0257
# Epoch 21/500
# 1/1 [==============================] - 0s 9ms/step - loss: 0.0034 - r_factor_metric: 1.0253
# Epoch 22/500
# 1/1 [==============================] - 0s 8ms/step - loss: 0.0034 - r_factor_metric: 1.0248
# Epoch 23/500
# 1/1 [==============================] - 0s 9ms/step - loss: 0.0034 - r_factor_metric: 1.0241
# Epoch 24/500
# 1/1 [==============================] - 0s 7ms/step - loss: 0.0034 - r_factor_metric: 1.0233
# Epoch 25/500
# 1/1 [==============================] - 0s 10ms/step - loss: 0.0034 - r_factor_metric: 1.0224
# Epoch 26/500
# 1/1 [==============================] - 0s 9ms/step - loss: 0.0034 - r_factor_metric: 1.0218
# Epoch 27/500
# 1/1 [==============================] - 0s 9ms/step - loss: 0.0034 - r_factor_metric: 1.0217
# Epoch 28/500
# 1/1 [==============================] - 0s 8ms/step - loss: 0.0034 - r_factor_metric: 1.0216
# Epoch 29/500
# 1/1 [==============================] - 0s 9ms/step - loss: 0.0034 - r_factor_metric: 1.0217
# Epoch 30/500
# 1/1 [==============================] - 0s 8ms/step - loss: 0.0034 - r_factor_metric: 1.0217
# Epoch 31/500
# 1/1 [==============================] - 0s 10ms/step - loss: 0.0034 - r_factor_metric: 1.0219
# Epoch 32/500
# 1/1 [==============================] - 0s 10ms/step - loss: 0.0034 - r_factor_metric: 1.0226
# Epoch 33/500
# 1/1 [==============================] - 0s 8ms/step - loss: 0.0034 - r_factor_metric: 1.0233
# Epoch 34/500
# 1/1 [==============================] - 0s 8ms/step - loss: 0.0034 - r_factor_metric: 1.0237
# Epoch 35/500
# 1/1 [==============================] - 0s 8ms/step - loss: 0.0034 - r_factor_metric: 1.0241
# Epoch 36/500
# 1/1 [==============================] - 0s 7ms/step - loss: 0.0034 - r_factor_metric: 1.0243
# Epoch 37/500
# 1/1 [==============================] - 0s 8ms/step - loss: 0.0034 - r_factor_metric: 1.0243
# Epoch 38/500
# 1/1 [==============================] - 0s 7ms/step - loss: 0.0034 - r_factor_metric: 1.0243
# Epoch 39/500
# 1/1 [==============================] - 0s 10ms/step - loss: 0.0034 - r_factor_metric: 1.0241
# Epoch 40/500
# 1/1 [==============================] - 0s 8ms/step - loss: 0.0034 - r_factor_metric: 1.0240
# Epoch 41/500
# 1/1 [==============================] - 0s 8ms/step - loss: 0.0034 - r_factor_metric: 1.0238
# Epoch 42/500
# 1/1 [==============================] - 0s 8ms/step - loss: 0.0034 - r_factor_metric: 1.0235
# Epoch 43/500
# 1/1 [==============================] - 0s 10ms/step - loss: 0.0034 - r_factor_metric: 1.0231
# Epoch 44/500
# 1/1 [==============================] - 0s 10ms/step - loss: 0.0034 - r_factor_metric: 1.0227
# Epoch 45/500
# 1/1 [==============================] - 0s 8ms/step - loss: 0.0034 - r_factor_metric: 1.0222
# Epoch 46/500
# 1/1 [==============================] - 0s 10ms/step - loss: 0.0034 - r_factor_metric: 1.0218
# Epoch 47/500
# 1/1 [==============================] - 0s 12ms/step - loss: 0.0034 - r_factor_metric: 1.0212
# Epoch 48/500
# 1/1 [==============================] - 0s 8ms/step - loss: 0.0034 - r_factor_metric: 1.0207
# Epoch 49/500
# 1/1 [==============================] - 0s 9ms/step - loss: 0.0034 - r_factor_metric: 1.0200
# Epoch 50/500
# 1/1 [==============================] - 0s 9ms/step - loss: 0.0034 - r_factor_metric: 1.0195
# Epoch 51/500
# 1/1 [==============================] - 0s 9ms/step - loss: 0.0034 - r_factor_metric: 1.0189
# Epoch 52/500
# 1/1 [==============================] - 0s 8ms/step - loss: 0.0034 - r_factor_metric: 1.0184
# Epoch 53/500
# 1/1 [==============================] - 0s 8ms/step - loss: 0.0034 - r_factor_metric: 1.0178
# Epoch 54/500
# 1/1 [==============================] - 0s 8ms/step - loss: 0.0034 - r_factor_metric: 1.0172
# Epoch 55/500
# 1/1 [==============================] - 0s 7ms/step - loss: 0.0034 - r_factor_metric: 1.0166
# Epoch 56/500
# 1/1 [==============================] - 0s 10ms/step - loss: 0.0034 - r_factor_metric: 1.0160
# Epoch 57/500
# 1/1 [==============================] - 0s 9ms/step - loss: 0.0034 - r_factor_metric: 1.0155
# Epoch 58/500
# 1/1 [==============================] - 0s 8ms/step - loss: 0.0034 - r_factor_metric: 1.0149
# Epoch 59/500
# 1/1 [==============================] - 0s 8ms/step - loss: 0.0034 - r_factor_metric: 1.0145
# Epoch 60/500
# 1/1 [==============================] - 0s 10ms/step - loss: 0.0034 - r_factor_metric: 1.0140
# Epoch 61/500
# 1/1 [==============================] - 0s 8ms/step - loss: 0.0034 - r_factor_metric: 1.0134
# Epoch 62/500
# 1/1 [==============================] - 0s 9ms/step - loss: 0.0034 - r_factor_metric: 1.0130
# Epoch 63/500
# 1/1 [==============================] - 0s 7ms/step - loss: 0.0034 - r_factor_metric: 1.0127
# Epoch 64/500
# 1/1 [==============================] - 0s 9ms/step - loss: 0.0034 - r_factor_metric: 1.0123
# Epoch 65/500
# 1/1 [==============================] - 0s 9ms/step - loss: 0.0034 - r_factor_metric: 1.0120
# Epoch 66/500
# 1/1 [==============================] - 0s 9ms/step - loss: 0.0034 - r_factor_metric: 1.0118
# Epoch 67/500
# 1/1 [==============================] - 0s 9ms/step - loss: 0.0034 - r_factor_metric: 1.0118
# Epoch 68/500
# 1/1 [==============================] - 0s 8ms/step - loss: 0.0034 - r_factor_metric: 1.0117
# Epoch 69/500
# 1/1 [==============================] - 0s 8ms/step - loss: 0.0034 - r_factor_metric: 1.0116
# Epoch 70/500
# 1/1 [==============================] - 0s 10ms/step - loss: 0.0034 - r_factor_metric: 1.0115
# Epoch 71/500
# 1/1 [==============================] - 0s 9ms/step - loss: 0.0034 - r_factor_metric: 1.0113
# Epoch 72/500
# 1/1 [==============================] - 0s 9ms/step - loss: 0.0034 - r_factor_metric: 1.0112
# Epoch 73/500
# 1/1 [==============================] - 0s 9ms/step - loss: 0.0034 - r_factor_metric: 1.0111
# Epoch 74/500
# 1/1 [==============================] - 0s 9ms/step - loss: 0.0034 - r_factor_metric: 1.0110
# Epoch 75/500
# 1/1 [==============================] - 0s 9ms/step - loss: 0.0034 - r_factor_metric: 1.0108
# Epoch 76/500
# 1/1 [==============================] - 0s 7ms/step - loss: 0.0034 - r_factor_metric: 1.0107
# Epoch 77/500
# 1/1 [==============================] - 0s 9ms/step - loss: 0.0034 - r_factor_metric: 1.0106
# Epoch 78/500
# 1/1 [==============================] - 0s 9ms/step - loss: 0.0034 - r_factor_metric: 1.0105
# Epoch 79/500
# 1/1 [==============================] - 0s 7ms/step - loss: 0.0034 - r_factor_metric: 1.0103
# Epoch 80/500
# 1/1 [==============================] - 0s 10ms/step - loss: 0.0034 - r_factor_metric: 1.0102
# Epoch 81/500
# 1/1 [==============================] - 0s 10ms/step - loss: 0.0034 - r_factor_metric: 1.0101
# Epoch 82/500
# 1/1 [==============================] - 0s 9ms/step - loss: 0.0034 - r_factor_metric: 1.0100
# Epoch 83/500
# 1/1 [==============================] - 0s 9ms/step - loss: 0.0034 - r_factor_metric: 1.0099
# Epoch 84/500
# 1/1 [==============================] - 0s 8ms/step - loss: 0.0034 - r_factor_metric: 1.0098
# Epoch 85/500
# 1/1 [==============================] - 0s 9ms/step - loss: 0.0034 - r_factor_metric: 1.0097
# Epoch 86/500
# 1/1 [==============================] - 0s 7ms/step - loss: 0.0034 - r_factor_metric: 1.0096
# Epoch 87/500
# 1/1 [==============================] - 0s 8ms/step - loss: 0.0034 - r_factor_metric: 1.0095
# Epoch 88/500
# 1/1 [==============================] - 0s 10ms/step - loss: 0.0034 - r_factor_metric: 1.0095
# Epoch 89/500
# 1/1 [==============================] - 0s 7ms/step - loss: 0.0034 - r_factor_metric: 1.0094
# Epoch 90/500
# 1/1 [==============================] - 0s 8ms/step - loss: 0.0034 - r_factor_metric: 1.0093
# Epoch 91/500
# 1/1 [==============================] - 0s 8ms/step - loss: 0.0034 - r_factor_metric: 1.0093
# Epoch 92/500
# 1/1 [==============================] - 0s 7ms/step - loss: 0.0033 - r_factor_metric: 1.0092
# Epoch 93/500
# 1/1 [==============================] - 0s 10ms/step - loss: 0.0033 - r_factor_metric: 1.0092
# Epoch 94/500
# 1/1 [==============================] - 0s 8ms/step - loss: 0.0033 - r_factor_metric: 1.0091
# Epoch 95/500
# 1/1 [==============================] - 0s 12ms/step - loss: 0.0033 - r_factor_metric: 1.0091
# Epoch 96/500
# 1/1 [==============================] - 0s 9ms/step - loss: 0.0033 - r_factor_metric: 1.0090
# Epoch 97/500
# 1/1 [==============================] - 0s 8ms/step - loss: 0.0033 - r_factor_metric: 1.0089
# Epoch 98/500
# 1/1 [==============================] - 0s 8ms/step - loss: 0.0033 - r_factor_metric: 1.0088
# Epoch 99/500
# 1/1 [==============================] - 0s 9ms/step - loss: 0.0033 - r_factor_metric: 1.0088
# Epoch 100/500
# 1/1 [==============================] - 0s 8ms/step - loss: 0.0033 - r_factor_metric: 1.0087
# Epoch 101/500
# 1/1 [==============================] - 0s 9ms/step - loss: 0.0033 - r_factor_metric: 1.0086
# Epoch 102/500
# 1/1 [==============================] - 0s 9ms/step - loss: 0.0033 - r_factor_metric: 1.0085
# Epoch 103/500
# 1/1 [==============================] - 0s 9ms/step - loss: 0.0033 - r_factor_metric: 1.0084
# Epoch 104/500
# 1/1 [==============================] - 0s 9ms/step - loss: 0.0033 - r_factor_metric: 1.0083
# Epoch 105/500
# 1/1 [==============================] - 0s 10ms/step - loss: 0.0033 - r_factor_metric: 1.0082
# Epoch 106/500
# 1/1 [==============================] - 0s 8ms/step - loss: 0.0033 - r_factor_metric: 1.0081
# Epoch 107/500
# 1/1 [==============================] - 0s 10ms/step - loss: 0.0033 - r_factor_metric: 1.0080
# Epoch 108/500
# 1/1 [==============================] - 0s 8ms/step - loss: 0.0033 - r_factor_metric: 1.0079
# Epoch 109/500
# 1/1 [==============================] - 0s 8ms/step - loss: 0.0033 - r_factor_metric: 1.0078
# Epoch 110/500
# 1/1 [==============================] - 0s 9ms/step - loss: 0.0033 - r_factor_metric: 1.0077
# Epoch 111/500
# 1/1 [==============================] - 0s 9ms/step - loss: 0.0033 - r_factor_metric: 1.0076
# Epoch 112/500
# 1/1 [==============================] - 0s 10ms/step - loss: 0.0033 - r_factor_metric: 1.0075
# Epoch 113/500
# 1/1 [==============================] - 0s 12ms/step - loss: 0.0033 - r_factor_metric: 1.0074
# Epoch 114/500
# 1/1 [==============================] - 0s 16ms/step - loss: 0.0033 - r_factor_metric: 1.0073
# Epoch 115/500
# 1/1 [==============================] - 0s 19ms/step - loss: 0.0033 - r_factor_metric: 1.0073
# Epoch 116/500
# 1/1 [==============================] - 0s 9ms/step - loss: 0.0033 - r_factor_metric: 1.0072
# Epoch 117/500
# 1/1 [==============================] - 0s 7ms/step - loss: 0.0033 - r_factor_metric: 1.0071
# Epoch 118/500
# 1/1 [==============================] - 0s 17ms/step - loss: 0.0033 - r_factor_metric: 1.0070
# Epoch 119/500
# 1/1 [==============================] - 0s 10ms/step - loss: 0.0033 - r_factor_metric: 1.0070
# Epoch 120/500
# 1/1 [==============================] - 0s 8ms/step - loss: 0.0033 - r_factor_metric: 1.0069
# Epoch 121/500
# 1/1 [==============================] - 0s 10ms/step - loss: 0.0033 - r_factor_metric: 1.0068
# Epoch 122/500
# 1/1 [==============================] - 0s 7ms/step - loss: 0.0033 - r_factor_metric: 1.0068
# Epoch 123/500
# 1/1 [==============================] - 0s 8ms/step - loss: 0.0033 - r_factor_metric: 1.0067
# Epoch 124/500
# 1/1 [==============================] - 0s 7ms/step - loss: 0.0033 - r_factor_metric: 1.0066
# Epoch 125/500
# 1/1 [==============================] - 0s 9ms/step - loss: 0.0033 - r_factor_metric: 1.0066
# Epoch 126/500
# 1/1 [==============================] - 0s 9ms/step - loss: 0.0033 - r_factor_metric: 1.0065
# Epoch 127/500
# 1/1 [==============================] - 0s 7ms/step - loss: 0.0033 - r_factor_metric: 1.0065
# Epoch 128/500
# 1/1 [==============================] - 0s 10ms/step - loss: 0.0033 - r_factor_metric: 1.0064
# Epoch 129/500
# 1/1 [==============================] - 0s 7ms/step - loss: 0.0033 - r_factor_metric: 1.0064
# Epoch 130/500
# 1/1 [==============================] - 0s 10ms/step - loss: 0.0033 - r_factor_metric: 1.0063
# Epoch 131/500
# 1/1 [==============================] - 0s 8ms/step - loss: 0.0033 - r_factor_metric: 1.0063
# Epoch 132/500
# 1/1 [==============================] - 0s 9ms/step - loss: 0.0033 - r_factor_metric: 1.0062
# Epoch 133/500
# 1/1 [==============================] - 0s 9ms/step - loss: 0.0033 - r_factor_metric: 1.0062
# Epoch 134/500
# 1/1 [==============================] - 0s 9ms/step - loss: 0.0033 - r_factor_metric: 1.0061
# Epoch 135/500
# 1/1 [==============================] - 0s 11ms/step - loss: 0.0033 - r_factor_metric: 1.0061
# Epoch 136/500
# 1/1 [==============================] - 0s 8ms/step - loss: 0.0033 - r_factor_metric: 1.0060
# Epoch 137/500
# 1/1 [==============================] - 0s 11ms/step - loss: 0.0033 - r_factor_metric: 1.0060
# Epoch 138/500
# 1/1 [==============================] - 0s 7ms/step - loss: 0.0033 - r_factor_metric: 1.0060
# Epoch 139/500
# 1/1 [==============================] - 0s 11ms/step - loss: 0.0033 - r_factor_metric: 1.0059
# Epoch 140/500
# 1/1 [==============================] - 0s 8ms/step - loss: 0.0033 - r_factor_metric: 1.0059
# Epoch 141/500
# 1/1 [==============================] - 0s 7ms/step - loss: 0.0033 - r_factor_metric: 1.0058
# Epoch 142/500
# 1/1 [==============================] - 0s 9ms/step - loss: 0.0033 - r_factor_metric: 1.0058
# Epoch 143/500
# 1/1 [==============================] - 0s 10ms/step - loss: 0.0033 - r_factor_metric: 1.0058
# Epoch 144/500
# 1/1 [==============================] - 0s 9ms/step - loss: 0.0033 - r_factor_metric: 1.0057
# Epoch 145/500
# 1/1 [==============================] - 0s 8ms/step - loss: 0.0033 - r_factor_metric: 1.0057
# Epoch 146/500
# 1/1 [==============================] - 0s 8ms/step - loss: 0.0033 - r_factor_metric: 1.0056
# Epoch 147/500
# 1/1 [==============================] - 0s 7ms/step - loss: 0.0033 - r_factor_metric: 1.0056
# Epoch 148/500
# 1/1 [==============================] - 0s 9ms/step - loss: 0.0033 - r_factor_metric: 1.0056
# Epoch 149/500
# 1/1 [==============================] - 0s 8ms/step - loss: 0.0033 - r_factor_metric: 1.0055
# Epoch 150/500
# 1/1 [==============================] - 0s 9ms/step - loss: 0.0033 - r_factor_metric: 1.0055
# Epoch 151/500
# 1/1 [==============================] - 0s 11ms/step - loss: 0.0033 - r_factor_metric: 1.0054
# Epoch 152/500
# 1/1 [==============================] - 0s 7ms/step - loss: 0.0033 - r_factor_metric: 1.0054
# Epoch 153/500
# 1/1 [==============================] - 0s 9ms/step - loss: 0.0033 - r_factor_metric: 1.0054
# Epoch 154/500
# 1/1 [==============================] - 0s 9ms/step - loss: 0.0033 - r_factor_metric: 1.0053
# Epoch 155/500
# 1/1 [==============================] - 0s 8ms/step - loss: 0.0033 - r_factor_metric: 1.0053
# Epoch 156/500
# 1/1 [==============================] - 0s 9ms/step - loss: 0.0033 - r_factor_metric: 1.0052
# Epoch 157/500
# 1/1 [==============================] - 0s 9ms/step - loss: 0.0033 - r_factor_metric: 1.0052
# Epoch 158/500
# 1/1 [==============================] - 0s 11ms/step - loss: 0.0033 - r_factor_metric: 1.0051
# Epoch 159/500
# 1/1 [==============================] - 0s 7ms/step - loss: 0.0033 - r_factor_metric: 1.0051
# Epoch 160/500
# 1/1 [==============================] - 0s 9ms/step - loss: 0.0033 - r_factor_metric: 1.0051
# Epoch 161/500
# 1/1 [==============================] - 0s 7ms/step - loss: 0.0033 - r_factor_metric: 1.0050
# Epoch 162/500
# 1/1 [==============================] - 0s 10ms/step - loss: 0.0033 - r_factor_metric: 1.0050
# Epoch 163/500
# 1/1 [==============================] - 0s 10ms/step - loss: 0.0033 - r_factor_metric: 1.0049
# Epoch 164/500
# 1/1 [==============================] - 0s 8ms/step - loss: 0.0033 - r_factor_metric: 1.0048
# Epoch 165/500
# 1/1 [==============================] - 0s 9ms/step - loss: 0.0033 - r_factor_metric: 1.0048
# Epoch 166/500
# 1/1 [==============================] - 0s 8ms/step - loss: 0.0033 - r_factor_metric: 1.0047
# Epoch 167/500
# 1/1 [==============================] - 0s 8ms/step - loss: 0.0033 - r_factor_metric: 1.0047
# Epoch 168/500
# 1/1 [==============================] - 0s 8ms/step - loss: 0.0033 - r_factor_metric: 1.0046
# Epoch 169/500
# 1/1 [==============================] - 0s 8ms/step - loss: 0.0033 - r_factor_metric: 1.0046
# Epoch 170/500
# 1/1 [==============================] - 0s 9ms/step - loss: 0.0033 - r_factor_metric: 1.0045
# Epoch 171/500
# 1/1 [==============================] - 0s 9ms/step - loss: 0.0033 - r_factor_metric: 1.0044
# Epoch 172/500
# 1/1 [==============================] - 0s 8ms/step - loss: 0.0033 - r_factor_metric: 1.0043
# Epoch 173/500
# 1/1 [==============================] - 0s 8ms/step - loss: 0.0033 - r_factor_metric: 1.0043
# Epoch 174/500
# 1/1 [==============================] - 0s 9ms/step - loss: 0.0033 - r_factor_metric: 1.0042
# Epoch 175/500
# 1/1 [==============================] - 0s 9ms/step - loss: 0.0033 - r_factor_metric: 1.0041
# Epoch 176/500
# 1/1 [==============================] - 0s 9ms/step - loss: 0.0033 - r_factor_metric: 1.0040
# Epoch 177/500
# 1/1 [==============================] - 0s 8ms/step - loss: 0.0033 - r_factor_metric: 1.0039
# Epoch 178/500
# 1/1 [==============================] - 0s 9ms/step - loss: 0.0033 - r_factor_metric: 1.0038
# Epoch 179/500
# 1/1 [==============================] - 0s 9ms/step - loss: 0.0033 - r_factor_metric: 1.0037
# Epoch 180/500
# 1/1 [==============================] - 0s 7ms/step - loss: 0.0033 - r_factor_metric: 1.0036
# Epoch 181/500
# 1/1 [==============================] - 0s 9ms/step - loss: 0.0033 - r_factor_metric: 1.0035
# Epoch 182/500
# 1/1 [==============================] - 0s 19ms/step - loss: 0.0033 - r_factor_metric: 1.0034
# Epoch 183/500
# 1/1 [==============================] - 0s 131ms/step - loss: 0.0033 - r_factor_metric: 1.0032
# Epoch 184/500
# 1/1 [==============================] - 0s 9ms/step - loss: 0.0033 - r_factor_metric: 1.0031
# Epoch 185/500
# 1/1 [==============================] - 0s 9ms/step - loss: 0.0033 - r_factor_metric: 1.0030
# Epoch 186/500
# 1/1 [==============================] - 0s 10ms/step - loss: 0.0033 - r_factor_metric: 1.0029
# Epoch 187/500
# 1/1 [==============================] - 0s 11ms/step - loss: 0.0033 - r_factor_metric: 1.0028
# Epoch 188/500
# 1/1 [==============================] - 0s 10ms/step - loss: 0.0033 - r_factor_metric: 1.0027
# Epoch 189/500
# 1/1 [==============================] - 0s 10ms/step - loss: 0.0033 - r_factor_metric: 1.0026
# Epoch 190/500
# 1/1 [==============================] - 0s 11ms/step - loss: 0.0033 - r_factor_metric: 1.0025
# Epoch 191/500
# 1/1 [==============================] - 0s 14ms/step - loss: 0.0033 - r_factor_metric: 1.0024
# Epoch 192/500
# 1/1 [==============================] - 0s 14ms/step - loss: 0.0033 - r_factor_metric: 1.0023
# Epoch 193/500
# 1/1 [==============================] - 0s 11ms/step - loss: 0.0033 - r_factor_metric: 1.0021
# Epoch 194/500
# 1/1 [==============================] - 0s 11ms/step - loss: 0.0033 - r_factor_metric: 1.0020
# Epoch 195/500
# 1/1 [==============================] - 0s 11ms/step - loss: 0.0033 - r_factor_metric: 1.0019
# Epoch 196/500
# 1/1 [==============================] - 0s 10ms/step - loss: 0.0033 - r_factor_metric: 1.0018
# Epoch 197/500
# 1/1 [==============================] - 0s 10ms/step - loss: 0.0033 - r_factor_metric: 1.0017
# Epoch 198/500
# 1/1 [==============================] - 0s 15ms/step - loss: 0.0033 - r_factor_metric: 1.0016
# Epoch 199/500
# 1/1 [==============================] - 0s 9ms/step - loss: 0.0033 - r_factor_metric: 1.0014
# Epoch 200/500
# 1/1 [==============================] - 0s 12ms/step - loss: 0.0033 - r_factor_metric: 1.0013
# Epoch 201/500
# 1/1 [==============================] - 0s 11ms/step - loss: 0.0033 - r_factor_metric: 1.0013
# Epoch 202/500
# 1/1 [==============================] - 0s 11ms/step - loss: 0.0033 - r_factor_metric: 1.0012
# Epoch 203/500
# 1/1 [==============================] - 0s 10ms/step - loss: 0.0033 - r_factor_metric: 1.0011
# Epoch 204/500
# 1/1 [==============================] - 0s 11ms/step - loss: 0.0033 - r_factor_metric: 1.0011
# Epoch 205/500
# 1/1 [==============================] - 0s 10ms/step - loss: 0.0033 - r_factor_metric: 1.0011
# Epoch 206/500
# 1/1 [==============================] - 0s 11ms/step - loss: 0.0033 - r_factor_metric: 1.0011
# Epoch 207/500
# 1/1 [==============================] - 0s 12ms/step - loss: 0.0033 - r_factor_metric: 1.0012
# Epoch 208/500
# 1/1 [==============================] - 0s 12ms/step - loss: 0.0033 - r_factor_metric: 1.0012
# Epoch 209/500
# 1/1 [==============================] - 0s 10ms/step - loss: 0.0033 - r_factor_metric: 1.0012
# Epoch 210/500
# 1/1 [==============================] - 0s 9ms/step - loss: 0.0033 - r_factor_metric: 1.0012
# Epoch 211/500
# 1/1 [==============================] - 0s 10ms/step - loss: 0.0033 - r_factor_metric: 1.0012
# Epoch 212/500
# 1/1 [==============================] - 0s 10ms/step - loss: 0.0033 - r_factor_metric: 1.0012
# Epoch 213/500
# 1/1 [==============================] - 0s 12ms/step - loss: 0.0033 - r_factor_metric: 1.0012
# Epoch 214/500
# 1/1 [==============================] - 0s 11ms/step - loss: 0.0033 - r_factor_metric: 1.0012
# Epoch 215/500
# 1/1 [==============================] - 0s 10ms/step - loss: 0.0033 - r_factor_metric: 1.0012
# Epoch 216/500
# 1/1 [==============================] - 0s 11ms/step - loss: 0.0033 - r_factor_metric: 1.0012
# Epoch 217/500
# 1/1 [==============================] - 0s 10ms/step - loss: 0.0033 - r_factor_metric: 1.0012
# Epoch 218/500
# 1/1 [==============================] - 0s 9ms/step - loss: 0.0033 - r_factor_metric: 1.0012
# Epoch 219/500
# 1/1 [==============================] - 0s 10ms/step - loss: 0.0033 - r_factor_metric: 1.0012
# Epoch 220/500
# 1/1 [==============================] - 0s 11ms/step - loss: 0.0033 - r_factor_metric: 1.0013
# Epoch 221/500
# 1/1 [==============================] - 0s 55ms/step - loss: 0.0033 - r_factor_metric: 1.0013
# Epoch 222/500
# 1/1 [==============================] - 0s 30ms/step - loss: 0.0033 - r_factor_metric: 1.0013
# Epoch 223/500
# 1/1 [==============================] - 0s 9ms/step - loss: 0.0033 - r_factor_metric: 1.0013
# Epoch 224/500
# 1/1 [==============================] - 0s 7ms/step - loss: 0.0033 - r_factor_metric: 1.0014
# Epoch 225/500
# 1/1 [==============================] - 0s 13ms/step - loss: 0.0033 - r_factor_metric: 1.0014
# Epoch 226/500
# 1/1 [==============================] - 0s 8ms/step - loss: 0.0033 - r_factor_metric: 1.0014
# Epoch 227/500
# 1/1 [==============================] - 0s 10ms/step - loss: 0.0033 - r_factor_metric: 1.0015
# Epoch 228/500
# 1/1 [==============================] - 0s 10ms/step - loss: 0.0033 - r_factor_metric: 1.0015
# Epoch 229/500
# 1/1 [==============================] - 0s 8ms/step - loss: 0.0033 - r_factor_metric: 1.0015
# Epoch 230/500
# 1/1 [==============================] - 0s 9ms/step - loss: 0.0033 - r_factor_metric: 1.0016
# Epoch 231/500
# 1/1 [==============================] - 0s 9ms/step - loss: 0.0033 - r_factor_metric: 1.0016
# Epoch 232/500
# 1/1 [==============================] - 0s 8ms/step - loss: 0.0033 - r_factor_metric: 1.0016
# Epoch 233/500
# 1/1 [==============================] - 0s 9ms/step - loss: 0.0033 - r_factor_metric: 1.0016
# Epoch 234/500
# 1/1 [==============================] - 0s 9ms/step - loss: 0.0033 - r_factor_metric: 1.0016
# Epoch 235/500
# 1/1 [==============================] - 0s 8ms/step - loss: 0.0033 - r_factor_metric: 1.0016
# Epoch 236/500
# 1/1 [==============================] - 0s 10ms/step - loss: 0.0033 - r_factor_metric: 1.0017
# Epoch 237/500
# 1/1 [==============================] - 0s 8ms/step - loss: 0.0033 - r_factor_metric: 1.0017
# Epoch 238/500
# 1/1 [==============================] - 0s 9ms/step - loss: 0.0033 - r_factor_metric: 1.0017
# Epoch 239/500
# 1/1 [==============================] - 0s 9ms/step - loss: 0.0033 - r_factor_metric: 1.0017
# Epoch 240/500
# 1/1 [==============================] - 0s 7ms/step - loss: 0.0033 - r_factor_metric: 1.0018
# Epoch 241/500
# 1/1 [==============================] - 0s 8ms/step - loss: 0.0033 - r_factor_metric: 1.0018
# Epoch 242/500
# 1/1 [==============================] - 0s 10ms/step - loss: 0.0033 - r_factor_metric: 1.0018
# Epoch 243/500
# 1/1 [==============================] - 0s 10ms/step - loss: 0.0033 - r_factor_metric: 1.0018
# Epoch 244/500
# 1/1 [==============================] - 0s 9ms/step - loss: 0.0033 - r_factor_metric: 1.0019
# Epoch 245/500
# 1/1 [==============================] - 0s 8ms/step - loss: 0.0033 - r_factor_metric: 1.0019
# Epoch 246/500
# 1/1 [==============================] - 0s 8ms/step - loss: 0.0033 - r_factor_metric: 1.0019
# Epoch 247/500
# 1/1 [==============================] - 0s 10ms/step - loss: 0.0033 - r_factor_metric: 1.0019
# Epoch 248/500
# 1/1 [==============================] - 0s 9ms/step - loss: 0.0033 - r_factor_metric: 1.0019
# Epoch 249/500
# 1/1 [==============================] - 0s 8ms/step - loss: 0.0033 - r_factor_metric: 1.0019
# Epoch 250/500
# 1/1 [==============================] - 0s 9ms/step - loss: 0.0033 - r_factor_metric: 1.0019
# Epoch 251/500
# 1/1 [==============================] - 0s 9ms/step - loss: 0.0033 - r_factor_metric: 1.0020
# Epoch 252/500
# 1/1 [==============================] - 0s 8ms/step - loss: 0.0033 - r_factor_metric: 1.0020
# Epoch 253/500
# 1/1 [==============================] - 0s 8ms/step - loss: 0.0033 - r_factor_metric: 1.0020
# Epoch 254/500
# 1/1 [==============================] - 0s 9ms/step - loss: 0.0033 - r_factor_metric: 1.0020
# Epoch 255/500
# 1/1 [==============================] - 0s 9ms/step - loss: 0.0033 - r_factor_metric: 1.0020
# Epoch 256/500
# 1/1 [==============================] - 0s 9ms/step - loss: 0.0033 - r_factor_metric: 1.0021
# Epoch 257/500
# 1/1 [==============================] - 0s 9ms/step - loss: 0.0033 - r_factor_metric: 1.0021
# Epoch 258/500
# 1/1 [==============================] - 0s 8ms/step - loss: 0.0033 - r_factor_metric: 1.0021
# Epoch 259/500
# 1/1 [==============================] - 0s 8ms/step - loss: 0.0033 - r_factor_metric: 1.0021
# Epoch 260/500
# 1/1 [==============================] - 0s 8ms/step - loss: 0.0033 - r_factor_metric: 1.0022
# Epoch 261/500
# 1/1 [==============================] - 0s 9ms/step - loss: 0.0033 - r_factor_metric: 1.0022
# Epoch 262/500
# 1/1 [==============================] - 0s 11ms/step - loss: 0.0033 - r_factor_metric: 1.0022
# Epoch 263/500
# 1/1 [==============================] - 0s 10ms/step - loss: 0.0033 - r_factor_metric: 1.0022
# Epoch 264/500
# 1/1 [==============================] - 0s 9ms/step - loss: 0.0033 - r_factor_metric: 1.0023
# Epoch 265/500
# 1/1 [==============================] - 0s 10ms/step - loss: 0.0033 - r_factor_metric: 1.0023
# Epoch 266/500
# 1/1 [==============================] - 0s 10ms/step - loss: 0.0033 - r_factor_metric: 1.0023
# Epoch 267/500
# 1/1 [==============================] - 0s 9ms/step - loss: 0.0033 - r_factor_metric: 1.0023
# Epoch 268/500
# 1/1 [==============================] - 0s 9ms/step - loss: 0.0033 - r_factor_metric: 1.0023
# Epoch 269/500
# 1/1 [==============================] - 0s 11ms/step - loss: 0.0033 - r_factor_metric: 1.0024
# Epoch 270/500
# 1/1 [==============================] - 0s 8ms/step - loss: 0.0033 - r_factor_metric: 1.0024
# Epoch 271/500
# 1/1 [==============================] - 0s 8ms/step - loss: 0.0033 - r_factor_metric: 1.0024
# Epoch 272/500
# 1/1 [==============================] - 0s 132ms/step - loss: 0.0033 - r_factor_metric: 1.0024
# Epoch 273/500
# 1/1 [==============================] - 0s 10ms/step - loss: 0.0033 - r_factor_metric: 1.0024
# Epoch 274/500
# 1/1 [==============================] - 0s 11ms/step - loss: 0.0033 - r_factor_metric: 1.0024
# Epoch 275/500
# 1/1 [==============================] - 0s 9ms/step - loss: 0.0033 - r_factor_metric: 1.0024
# Epoch 276/500
# 1/1 [==============================] - 0s 10ms/step - loss: 0.0033 - r_factor_metric: 1.0025
# Epoch 277/500
# 1/1 [==============================] - 0s 12ms/step - loss: 0.0033 - r_factor_metric: 1.0025
# Epoch 278/500
# 1/1 [==============================] - 0s 10ms/step - loss: 0.0033 - r_factor_metric: 1.0025
# Epoch 279/500
# 1/1 [==============================] - 0s 10ms/step - loss: 0.0033 - r_factor_metric: 1.0025
# Epoch 280/500
# 1/1 [==============================] - 0s 10ms/step - loss: 0.0033 - r_factor_metric: 1.0025
# Epoch 281/500
# 1/1 [==============================] - 0s 9ms/step - loss: 0.0033 - r_factor_metric: 1.0025
# Epoch 282/500
# 1/1 [==============================] - 0s 8ms/step - loss: 0.0033 - r_factor_metric: 1.0025
# Epoch 283/500
# 1/1 [==============================] - 0s 9ms/step - loss: 0.0033 - r_factor_metric: 1.0025
# Epoch 284/500
# 1/1 [==============================] - 0s 11ms/step - loss: 0.0033 - r_factor_metric: 1.0025
# Epoch 285/500
# 1/1 [==============================] - 0s 10ms/step - loss: 0.0033 - r_factor_metric: 1.0025
# Epoch 286/500
# 1/1 [==============================] - 0s 9ms/step - loss: 0.0033 - r_factor_metric: 1.0025
# Epoch 287/500
# 1/1 [==============================] - 0s 8ms/step - loss: 0.0033 - r_factor_metric: 1.0025
# Epoch 288/500
# 1/1 [==============================] - 0s 10ms/step - loss: 0.0033 - r_factor_metric: 1.0025
# Epoch 289/500
# 1/1 [==============================] - 0s 9ms/step - loss: 0.0033 - r_factor_metric: 1.0025
# Epoch 290/500
# 1/1 [==============================] - 0s 9ms/step - loss: 0.0033 - r_factor_metric: 1.0025
# Epoch 291/500
# 1/1 [==============================] - 0s 9ms/step - loss: 0.0033 - r_factor_metric: 1.0025
# Epoch 292/500
# 1/1 [==============================] - 0s 10ms/step - loss: 0.0033 - r_factor_metric: 1.0025
# Epoch 293/500
# 1/1 [==============================] - 0s 8ms/step - loss: 0.0033 - r_factor_metric: 1.0025
# Epoch 294/500
# 1/1 [==============================] - 0s 11ms/step - loss: 0.0033 - r_factor_metric: 1.0025
# Epoch 295/500
# 1/1 [==============================] - 0s 11ms/step - loss: 0.0033 - r_factor_metric: 1.0025
# Epoch 296/500
# 1/1 [==============================] - 0s 7ms/step - loss: 0.0033 - r_factor_metric: 1.0025
# Epoch 297/500
# 1/1 [==============================] - 0s 12ms/step - loss: 0.0033 - r_factor_metric: 1.0025
# Epoch 298/500
# 1/1 [==============================] - 0s 9ms/step - loss: 0.0033 - r_factor_metric: 1.0025
# Epoch 299/500
# 1/1 [==============================] - 0s 12ms/step - loss: 0.0033 - r_factor_metric: 1.0025
# Epoch 300/500
# 1/1 [==============================] - 0s 22ms/step - loss: 0.0033 - r_factor_metric: 1.0025
# Epoch 301/500
# 1/1 [==============================] - 0s 13ms/step - loss: 0.0033 - r_factor_metric: 1.0025
# Epoch 302/500
# 1/1 [==============================] - 0s 13ms/step - loss: 0.0033 - r_factor_metric: 1.0025
# Epoch 303/500
# 1/1 [==============================] - 0s 30ms/step - loss: 0.0033 - r_factor_metric: 1.0025
# Epoch 304/500
# 1/1 [==============================] - 0s 8ms/step - loss: 0.0033 - r_factor_metric: 1.0025
# Epoch 305/500
# 1/1 [==============================] - 0s 10ms/step - loss: 0.0033 - r_factor_metric: 1.0024
# Epoch 306/500
# 1/1 [==============================] - 0s 8ms/step - loss: 0.0033 - r_factor_metric: 1.0024
# Epoch 307/500
# 1/1 [==============================] - 0s 11ms/step - loss: 0.0033 - r_factor_metric: 1.0024
# Epoch 308/500
# 1/1 [==============================] - 0s 10ms/step - loss: 0.0033 - r_factor_metric: 1.0024
# Epoch 309/500
# 1/1 [==============================] - 0s 10ms/step - loss: 0.0033 - r_factor_metric: 1.0024
# Epoch 310/500
# 1/1 [==============================] - 0s 9ms/step - loss: 0.0033 - r_factor_metric: 1.0024
# Epoch 311/500
# 1/1 [==============================] - 0s 8ms/step - loss: 0.0033 - r_factor_metric: 1.0024
# Epoch 312/500
# 1/1 [==============================] - 0s 10ms/step - loss: 0.0033 - r_factor_metric: 1.0024
# Epoch 313/500
# 1/1 [==============================] - 0s 9ms/step - loss: 0.0033 - r_factor_metric: 1.0024
# Epoch 314/500
# 1/1 [==============================] - 0s 9ms/step - loss: 0.0033 - r_factor_metric: 1.0024
# Epoch 315/500
# 1/1 [==============================] - 0s 10ms/step - loss: 0.0033 - r_factor_metric: 1.0024
# Epoch 316/500
# 1/1 [==============================] - 0s 8ms/step - loss: 0.0033 - r_factor_metric: 1.0024
# Epoch 317/500
# 1/1 [==============================] - 0s 9ms/step - loss: 0.0033 - r_factor_metric: 1.0024
# Epoch 318/500
# 1/1 [==============================] - 0s 9ms/step - loss: 0.0033 - r_factor_metric: 1.0024
# Epoch 319/500
# 1/1 [==============================] - 0s 10ms/step - loss: 0.0033 - r_factor_metric: 1.0024
# Epoch 320/500
# 1/1 [==============================] - 0s 9ms/step - loss: 0.0033 - r_factor_metric: 1.0024
# Epoch 321/500
# 1/1 [==============================] - 0s 12ms/step - loss: 0.0033 - r_factor_metric: 1.0024
# Epoch 322/500
# 1/1 [==============================] - 0s 11ms/step - loss: 0.0033 - r_factor_metric: 1.0023
# Epoch 323/500
# 1/1 [==============================] - 0s 8ms/step - loss: 0.0033 - r_factor_metric: 1.0023
# Epoch 324/500
# 1/1 [==============================] - 0s 9ms/step - loss: 0.0033 - r_factor_metric: 1.0023
# Epoch 325/500
# 1/1 [==============================] - 0s 8ms/step - loss: 0.0033 - r_factor_metric: 1.0023
# Epoch 326/500
# 1/1 [==============================] - 0s 10ms/step - loss: 0.0033 - r_factor_metric: 1.0023
# Epoch 327/500
# 1/1 [==============================] - 0s 7ms/step - loss: 0.0033 - r_factor_metric: 1.0023
# Epoch 328/500
# 1/1 [==============================] - 0s 8ms/step - loss: 0.0033 - r_factor_metric: 1.0023
# Epoch 329/500
# 1/1 [==============================] - 0s 10ms/step - loss: 0.0033 - r_factor_metric: 1.0023
# Epoch 330/500
# 1/1 [==============================] - 0s 11ms/step - loss: 0.0033 - r_factor_metric: 1.0023
# Epoch 331/500
# 1/1 [==============================] - 0s 8ms/step - loss: 0.0033 - r_factor_metric: 1.0023
# Epoch 332/500
# 1/1 [==============================] - 0s 10ms/step - loss: 0.0033 - r_factor_metric: 1.0023
# Epoch 333/500
# 1/1 [==============================] - 0s 9ms/step - loss: 0.0033 - r_factor_metric: 1.0023
# Epoch 334/500
# 1/1 [==============================] - 0s 10ms/step - loss: 0.0033 - r_factor_metric: 1.0023
# Epoch 335/500
# 1/1 [==============================] - 0s 9ms/step - loss: 0.0033 - r_factor_metric: 1.0023
# Epoch 336/500
# 1/1 [==============================] - 0s 10ms/step - loss: 0.0033 - r_factor_metric: 1.0023
# Epoch 337/500
# 1/1 [==============================] - 0s 7ms/step - loss: 0.0033 - r_factor_metric: 1.0023
# Epoch 338/500
# 1/1 [==============================] - 0s 9ms/step - loss: 0.0033 - r_factor_metric: 1.0023
# Epoch 339/500
# 1/1 [==============================] - 0s 8ms/step - loss: 0.0033 - r_factor_metric: 1.0023
# Epoch 340/500
# 1/1 [==============================] - 0s 9ms/step - loss: 0.0033 - r_factor_metric: 1.0022
# Epoch 341/500
# 1/1 [==============================] - 0s 10ms/step - loss: 0.0033 - r_factor_metric: 1.0022
# Epoch 342/500
# 1/1 [==============================] - 0s 7ms/step - loss: 0.0033 - r_factor_metric: 1.0022
# Epoch 343/500
# 1/1 [==============================] - 0s 8ms/step - loss: 0.0033 - r_factor_metric: 1.0022
# Epoch 344/500
# 1/1 [==============================] - 0s 9ms/step - loss: 0.0033 - r_factor_metric: 1.0022
# Epoch 345/500
# 1/1 [==============================] - 0s 9ms/step - loss: 0.0033 - r_factor_metric: 1.0022
# Epoch 346/500
# 1/1 [==============================] - 0s 9ms/step - loss: 0.0033 - r_factor_metric: 1.0022
# Epoch 347/500
# 1/1 [==============================] - 0s 8ms/step - loss: 0.0033 - r_factor_metric: 1.0022
# Epoch 348/500
# 1/1 [==============================] - 0s 10ms/step - loss: 0.0033 - r_factor_metric: 1.0022
# Epoch 349/500
# 1/1 [==============================] - 0s 9ms/step - loss: 0.0033 - r_factor_metric: 1.0022
# Epoch 350/500
# 1/1 [==============================] - 0s 102ms/step - loss: 0.0033 - r_factor_metric: 1.0022
# Epoch 351/500
# 1/1 [==============================] - 0s 9ms/step - loss: 0.0033 - r_factor_metric: 1.0022
# Epoch 352/500
# 1/1 [==============================] - 0s 10ms/step - loss: 0.0033 - r_factor_metric: 1.0022
# Epoch 353/500
# 1/1 [==============================] - 0s 9ms/step - loss: 0.0033 - r_factor_metric: 1.0022
# Epoch 354/500
# 1/1 [==============================] - 0s 10ms/step - loss: 0.0033 - r_factor_metric: 1.0022
# Epoch 355/500
# 1/1 [==============================] - 0s 15ms/step - loss: 0.0033 - r_factor_metric: 1.0022
# Epoch 356/500
# 1/1 [==============================] - 0s 15ms/step - loss: 0.0033 - r_factor_metric: 1.0022
# Epoch 357/500
# 1/1 [==============================] - 0s 46ms/step - loss: 0.0033 - r_factor_metric: 1.0022
# Epoch 358/500
# 1/1 [==============================] - 0s 9ms/step - loss: 0.0033 - r_factor_metric: 1.0022
# Epoch 359/500
# 1/1 [==============================] - 0s 9ms/step - loss: 0.0033 - r_factor_metric: 1.0021
# Epoch 360/500
# 1/1 [==============================] - 0s 14ms/step - loss: 0.0033 - r_factor_metric: 1.0021
# Epoch 361/500
# 1/1 [==============================] - 0s 9ms/step - loss: 0.0033 - r_factor_metric: 1.0021
# Epoch 362/500
# 1/1 [==============================] - 0s 10ms/step - loss: 0.0033 - r_factor_metric: 1.0021
# Epoch 363/500
# 1/1 [==============================] - 0s 9ms/step - loss: 0.0033 - r_factor_metric: 1.0021
# Epoch 364/500
# 1/1 [==============================] - 0s 9ms/step - loss: 0.0033 - r_factor_metric: 1.0021
# Epoch 365/500
# 1/1 [==============================] - 0s 8ms/step - loss: 0.0033 - r_factor_metric: 1.0021
# Epoch 366/500
# 1/1 [==============================] - 0s 10ms/step - loss: 0.0033 - r_factor_metric: 1.0021
# Epoch 367/500
# 1/1 [==============================] - 0s 9ms/step - loss: 0.0033 - r_factor_metric: 1.0021
# Epoch 368/500
# 1/1 [==============================] - 0s 8ms/step - loss: 0.0033 - r_factor_metric: 1.0021
# Epoch 369/500
# 1/1 [==============================] - 0s 9ms/step - loss: 0.0033 - r_factor_metric: 1.0021
# Epoch 370/500
# 1/1 [==============================] - 0s 8ms/step - loss: 0.0033 - r_factor_metric: 1.0021
# Epoch 371/500
# 1/1 [==============================] - 0s 8ms/step - loss: 0.0033 - r_factor_metric: 1.0021
# Epoch 372/500
# 1/1 [==============================] - 0s 9ms/step - loss: 0.0033 - r_factor_metric: 1.0021
# Epoch 373/500
# 1/1 [==============================] - 0s 9ms/step - loss: 0.0033 - r_factor_metric: 1.0021
# Epoch 374/500
# 1/1 [==============================] - 0s 8ms/step - loss: 0.0033 - r_factor_metric: 1.0021
# Epoch 375/500
# 1/1 [==============================] - 0s 8ms/step - loss: 0.0033 - r_factor_metric: 1.0021
# Epoch 376/500
# 1/1 [==============================] - 0s 11ms/step - loss: 0.0033 - r_factor_metric: 1.0021
# Epoch 377/500
# 1/1 [==============================] - 0s 10ms/step - loss: 0.0033 - r_factor_metric: 1.0021
# Epoch 378/500
# 1/1 [==============================] - 0s 9ms/step - loss: 0.0033 - r_factor_metric: 1.0021
# Epoch 379/500
# 1/1 [==============================] - 0s 9ms/step - loss: 0.0033 - r_factor_metric: 1.0020
# Epoch 380/500
# 1/1 [==============================] - 0s 11ms/step - loss: 0.0033 - r_factor_metric: 1.0020
# Epoch 381/500
# 1/1 [==============================] - 0s 7ms/step - loss: 0.0033 - r_factor_metric: 1.0020
# Epoch 382/500
# 1/1 [==============================] - 0s 10ms/step - loss: 0.0033 - r_factor_metric: 1.0020
# Epoch 383/500
# 1/1 [==============================] - 0s 11ms/step - loss: 0.0033 - r_factor_metric: 1.0020
# Epoch 384/500
# 1/1 [==============================] - 0s 8ms/step - loss: 0.0033 - r_factor_metric: 1.0020
# Epoch 385/500
# 1/1 [==============================] - 0s 9ms/step - loss: 0.0033 - r_factor_metric: 1.0020
# Epoch 386/500
# 1/1 [==============================] - 0s 9ms/step - loss: 0.0033 - r_factor_metric: 1.0020
# Epoch 387/500
# 1/1 [==============================] - 0s 9ms/step - loss: 0.0033 - r_factor_metric: 1.0020
# Epoch 388/500
# 1/1 [==============================] - 0s 11ms/step - loss: 0.0033 - r_factor_metric: 1.0020
# Epoch 389/500
# 1/1 [==============================] - 0s 10ms/step - loss: 0.0033 - r_factor_metric: 1.0020
# Epoch 390/500
# 1/1 [==============================] - 0s 8ms/step - loss: 0.0033 - r_factor_metric: 1.0020
# Epoch 391/500
# 1/1 [==============================] - 0s 8ms/step - loss: 0.0033 - r_factor_metric: 1.0020
# Epoch 392/500
# 1/1 [==============================] - 0s 9ms/step - loss: 0.0033 - r_factor_metric: 1.0020
# Epoch 393/500
# 1/1 [==============================] - 0s 9ms/step - loss: 0.0033 - r_factor_metric: 1.0020
# Epoch 394/500
# 1/1 [==============================] - 0s 9ms/step - loss: 0.0033 - r_factor_metric: 1.0020
# Epoch 395/500
# 1/1 [==============================] - 0s 11ms/step - loss: 0.0033 - r_factor_metric: 1.0020
# Epoch 396/500
# 1/1 [==============================] - 0s 9ms/step - loss: 0.0033 - r_factor_metric: 1.0020
# Epoch 397/500
# 1/1 [==============================] - 0s 8ms/step - loss: 0.0033 - r_factor_metric: 1.0020
# Epoch 398/500
# 1/1 [==============================] - 0s 11ms/step - loss: 0.0033 - r_factor_metric: 1.0020
# Epoch 399/500
# 1/1 [==============================] - 0s 9ms/step - loss: 0.0033 - r_factor_metric: 1.0020
# Epoch 400/500
# 1/1 [==============================] - 0s 9ms/step - loss: 0.0033 - r_factor_metric: 1.0020
# Epoch 401/500
# 1/1 [==============================] - 0s 117ms/step - loss: 0.0033 - r_factor_metric: 1.0019
# Epoch 402/500
# 1/1 [==============================] - 0s 9ms/step - loss: 0.0033 - r_factor_metric: 1.0019
# Epoch 403/500
# 1/1 [==============================] - 0s 12ms/step - loss: 0.0033 - r_factor_metric: 1.0019
# Epoch 404/500
# 1/1 [==============================] - 0s 9ms/step - loss: 0.0033 - r_factor_metric: 1.0019
# Epoch 405/500
# 1/1 [==============================] - 0s 9ms/step - loss: 0.0033 - r_factor_metric: 1.0019
# Epoch 406/500
# 1/1 [==============================] - 0s 10ms/step - loss: 0.0033 - r_factor_metric: 1.0019
# Epoch 407/500
# 1/1 [==============================] - 0s 10ms/step - loss: 0.0033 - r_factor_metric: 1.0019
# Epoch 408/500
# 1/1 [==============================] - 0s 8ms/step - loss: 0.0033 - r_factor_metric: 1.0019
# Epoch 409/500
# 1/1 [==============================] - 0s 9ms/step - loss: 0.0033 - r_factor_metric: 1.0019
# Epoch 410/500
# 1/1 [==============================] - 0s 10ms/step - loss: 0.0033 - r_factor_metric: 1.0019
# Epoch 411/500
# 1/1 [==============================] - 0s 8ms/step - loss: 0.0033 - r_factor_metric: 1.0019
# Epoch 412/500
# 1/1 [==============================] - 0s 9ms/step - loss: 0.0033 - r_factor_metric: 1.0019
# Epoch 413/500
# 1/1 [==============================] - 0s 9ms/step - loss: 0.0033 - r_factor_metric: 1.0019
# Epoch 414/500
# 1/1 [==============================] - 0s 10ms/step - loss: 0.0033 - r_factor_metric: 1.0019
# Epoch 415/500
# 1/1 [==============================] - 0s 10ms/step - loss: 0.0033 - r_factor_metric: 1.0019
# Epoch 416/500
# 1/1 [==============================] - 0s 8ms/step - loss: 0.0033 - r_factor_metric: 1.0019
# Epoch 417/500
# 1/1 [==============================] - 0s 9ms/step - loss: 0.0033 - r_factor_metric: 1.0019
# Epoch 418/500
# 1/1 [==============================] - 0s 9ms/step - loss: 0.0033 - r_factor_metric: 1.0019
# Epoch 419/500
# 1/1 [==============================] - 0s 10ms/step - loss: 0.0033 - r_factor_metric: 1.0019
# Epoch 420/500
# 1/1 [==============================] - 0s 8ms/step - loss: 0.0033 - r_factor_metric: 1.0019
# Epoch 421/500
# 1/1 [==============================] - 0s 10ms/step - loss: 0.0033 - r_factor_metric: 1.0019
# Epoch 422/500
# 1/1 [==============================] - 0s 9ms/step - loss: 0.0033 - r_factor_metric: 1.0019
# Epoch 423/500
# 1/1 [==============================] - 0s 9ms/step - loss: 0.0033 - r_factor_metric: 1.0019
# Epoch 424/500
# 1/1 [==============================] - 0s 26ms/step - loss: 0.0033 - r_factor_metric: 1.0019
# Epoch 425/500
# 1/1 [==============================] - 0s 11ms/step - loss: 0.0033 - r_factor_metric: 1.0018
# Epoch 426/500
# 1/1 [==============================] - 0s 15ms/step - loss: 0.0033 - r_factor_metric: 1.0018
# Epoch 427/500
# 1/1 [==============================] - 0s 15ms/step - loss: 0.0033 - r_factor_metric: 1.0018
# Epoch 428/500
# 1/1 [==============================] - 0s 10ms/step - loss: 0.0033 - r_factor_metric: 1.0018
# Epoch 429/500
# 1/1 [==============================] - 0s 8ms/step - loss: 0.0033 - r_factor_metric: 1.0018
# Epoch 430/500
# 1/1 [==============================] - 0s 12ms/step - loss: 0.0033 - r_factor_metric: 1.0018
# Epoch 431/500
# 1/1 [==============================] - 0s 9ms/step - loss: 0.0033 - r_factor_metric: 1.0018
# Epoch 432/500
# 1/1 [==============================] - 0s 8ms/step - loss: 0.0033 - r_factor_metric: 1.0018
# Epoch 433/500
# 1/1 [==============================] - 0s 12ms/step - loss: 0.0033 - r_factor_metric: 1.0018
# Epoch 434/500
# 1/1 [==============================] - 0s 8ms/step - loss: 0.0033 - r_factor_metric: 1.0018
# Epoch 435/500
# 1/1 [==============================] - 0s 10ms/step - loss: 0.0033 - r_factor_metric: 1.0018
# Epoch 436/500
# 1/1 [==============================] - 0s 10ms/step - loss: 0.0033 - r_factor_metric: 1.0018
# Epoch 437/500
# 1/1 [==============================] - 0s 9ms/step - loss: 0.0033 - r_factor_metric: 1.0018
# Epoch 438/500
# 1/1 [==============================] - 0s 9ms/step - loss: 0.0033 - r_factor_metric: 1.0018
# Epoch 439/500
# 1/1 [==============================] - 0s 8ms/step - loss: 0.0033 - r_factor_metric: 1.0018
# Epoch 440/500
# 1/1 [==============================] - 0s 7ms/step - loss: 0.0033 - r_factor_metric: 1.0018
# Epoch 441/500
# 1/1 [==============================] - 0s 9ms/step - loss: 0.0033 - r_factor_metric: 1.0018
# Epoch 442/500
# 1/1 [==============================] - 0s 10ms/step - loss: 0.0033 - r_factor_metric: 1.0018
# Epoch 443/500
# 1/1 [==============================] - 0s 10ms/step - loss: 0.0033 - r_factor_metric: 1.0018
# Epoch 444/500
# 1/1 [==============================] - 0s 7ms/step - loss: 0.0033 - r_factor_metric: 1.0018
# Epoch 445/500
# 1/1 [==============================] - 0s 11ms/step - loss: 0.0033 - r_factor_metric: 1.0018
# Epoch 446/500
# 1/1 [==============================] - 0s 9ms/step - loss: 0.0033 - r_factor_metric: 1.0018
# Epoch 447/500
# 1/1 [==============================] - 0s 8ms/step - loss: 0.0033 - r_factor_metric: 1.0018
# Epoch 448/500
# 1/1 [==============================] - 0s 7ms/step - loss: 0.0033 - r_factor_metric: 1.0018
# Epoch 449/500
# ...
# Epoch 352/500
# 1/1 [==============================] - 0s 10ms/step - loss: 0.0033 - r_factor_metric: 1.0108
# Epoch 353/500
# 1/1 [==============================] - 0s 9ms/step - loss: 0.0033 - r_factor_metric: 1.0108
# Epoch 354/500
# 1/1 [==============================] - 0s 10ms/step - loss: 0.0033 - r_factor_metric: 1.0108
# Epoch 355/500
# 1/1 [==============================] - 0s 9ms/step - loss: 0.0033 - r_factor_metric: 1.0108
# Epoch 356/500
# 1/1 [==============================] - 0s 12ms/step - loss: 0.0033 - r_factor_metric: 1.0108
# Epoch 357/500
# 1/1 [==============================] - 0s 8ms/step - loss: 0.0033 - r_factor_metric: 1.0108
# Epoch 358/500
# 1/1 [==============================] - 0s 10ms/step - loss: 0.0033 - r_factor_metric: 1.0108
# Epoch 359/500
# 1/1 [==============================] - 0s 10ms/step - loss: 0.0033 - r_factor_metric: 1.0108
# Epoch 360/500
# 1/1 [==============================] - 0s 8ms/step - loss: 0.0033 - r_factor_metric: 1.0108
# Epoch 361/500
# 1/1 [==============================] - 0s 9ms/step - loss: 0.0033 - r_factor_metric: 1.0108
# Epoch 362/500
# 1/1 [==============================] - 0s 11ms/step - loss: 0.0033 - r_factor_metric: 1.0108
# Epoch 363/500
# 1/1 [==============================] - 0s 9ms/step - loss: 0.0033 - r_factor_metric: 1.0108
# Epoch 364/500
# 1/1 [==============================] - 0s 9ms/step - loss: 0.0033 - r_factor_metric: 1.0108
# Epoch 365/500
# 1/1 [==============================] - 0s 8ms/step - loss: 0.0033 - r_factor_metric: 1.0108
# Epoch 366/500
# 1/1 [==============================] - 0s 11ms/step - loss: 0.0033 - r_factor_metric: 1.0108
# Epoch 367/500
# 1/1 [==============================] - 0s 9ms/step - loss: 0.0033 - r_factor_metric: 1.0108
# Epoch 368/500
# 1/1 [==============================] - 0s 10ms/step - loss: 0.0033 - r_factor_metric: 1.0108
# Epoch 369/500
# 1/1 [==============================] - 0s 9ms/step - loss: 0.0033 - r_factor_metric: 1.0108
# Epoch 370/500
# 1/1 [==============================] - 0s 10ms/step - loss: 0.0033 - r_factor_metric: 1.0108
# Epoch 371/500
# 1/1 [==============================] - 0s 72ms/step - loss: 0.0033 - r_factor_metric: 1.0108
# Epoch 372/500
# 1/1 [==============================] - 0s 98ms/step - loss: 0.0033 - r_factor_metric: 1.0108
# Epoch 373/500
# 1/1 [==============================] - 0s 12ms/step - loss: 0.0033 - r_factor_metric: 1.0108
# Epoch 374/500
# 1/1 [==============================] - 0s 11ms/step - loss: 0.0033 - r_factor_metric: 1.0108
# Epoch 375/500
# 1/1 [==============================] - 0s 14ms/step - loss: 0.0033 - r_factor_metric: 1.0108
# Epoch 376/500
# 1/1 [==============================] - 0s 12ms/step - loss: 0.0033 - r_factor_metric: 1.0108
# Epoch 377/500
# 1/1 [==============================] - 0s 9ms/step - loss: 0.0033 - r_factor_metric: 1.0108
# Epoch 378/500
# 1/1 [==============================] - 0s 9ms/step - loss: 0.0033 - r_factor_metric: 1.0108
# Epoch 379/500
# 1/1 [==============================] - 0s 9ms/step - loss: 0.0033 - r_factor_metric: 1.0108
# Epoch 380/500
# 1/1 [==============================] - 0s 9ms/step - loss: 0.0033 - r_factor_metric: 1.0108
# Epoch 381/500
# 1/1 [==============================] - 0s 10ms/step - loss: 0.0033 - r_factor_metric: 1.0108
# Epoch 382/500
# 1/1 [==============================] - 0s 10ms/step - loss: 0.0033 - r_factor_metric: 1.0108
# Epoch 383/500
# 1/1 [==============================] - 0s 8ms/step - loss: 0.0033 - r_factor_metric: 1.0108
# Epoch 384/500
# 1/1 [==============================] - 0s 9ms/step - loss: 0.0033 - r_factor_metric: 1.0108
# Epoch 385/500
# 1/1 [==============================] - 0s 11ms/step - loss: 0.0033 - r_factor_metric: 1.0108
# Epoch 386/500
# 1/1 [==============================] - 0s 10ms/step - loss: 0.0033 - r_factor_metric: 1.0108
# Epoch 387/500
# 1/1 [==============================] - 0s 9ms/step - loss: 0.0033 - r_factor_metric: 1.0108
# Epoch 388/500
# 1/1 [==============================] - 0s 10ms/step - loss: 0.0033 - r_factor_metric: 1.0108
# Epoch 389/500
# 1/1 [==============================] - 0s 11ms/step - loss: 0.0033 - r_factor_metric: 1.0108
# Epoch 390/500
# 1/1 [==============================] - 0s 9ms/step - loss: 0.0033 - r_factor_metric: 1.0108
# Epoch 391/500
# 1/1 [==============================] - 0s 10ms/step - loss: 0.0033 - r_factor_metric: 1.0108
# Epoch 392/500
# 1/1 [==============================] - 0s 8ms/step - loss: 0.0033 - r_factor_metric: 1.0108
# Epoch 393/500
# 1/1 [==============================] - 0s 12ms/step - loss: 0.0033 - r_factor_metric: 1.0108
# Epoch 394/500
# 1/1 [==============================] - 0s 9ms/step - loss: 0.0033 - r_factor_metric: 1.0108
# Epoch 395/500
# 1/1 [==============================] - 0s 10ms/step - loss: 0.0033 - r_factor_metric: 1.0108
# Epoch 396/500
# 1/1 [==============================] - 0s 8ms/step - loss: 0.0033 - r_factor_metric: 1.0108
# Epoch 397/500
# 1/1 [==============================] - 0s 9ms/step - loss: 0.0033 - r_factor_metric: 1.0108
# Epoch 398/500
# 1/1 [==============================] - 0s 10ms/step - loss: 0.0033 - r_factor_metric: 1.0108
# Epoch 399/500
# 1/1 [==============================] - 0s 9ms/step - loss: 0.0033 - r_factor_metric: 1.0108
# Epoch 400/500
# 1/1 [==============================] - 0s 10ms/step - loss: 0.0033 - r_factor_metric: 1.0108
# Epoch 401/500
# 1/1 [==============================] - 0s 9ms/step - loss: 0.0033 - r_factor_metric: 1.0108
# Epoch 402/500
# 1/1 [==============================] - 0s 10ms/step - loss: 0.0033 - r_factor_metric: 1.0108
# Epoch 403/500
# 1/1 [==============================] - 0s 8ms/step - loss: 0.0033 - r_factor_metric: 1.0108
# Epoch 404/500
# 1/1 [==============================] - 0s 9ms/step - loss: 0.0033 - r_factor_metric: 1.0108
# Epoch 405/500
# 1/1 [==============================] - 0s 8ms/step - loss: 0.0033 - r_factor_metric: 1.0108
# Epoch 406/500
# 1/1 [==============================] - 0s 10ms/step - loss: 0.0033 - r_factor_metric: 1.0108
# Epoch 407/500
# 1/1 [==============================] - 0s 73ms/step - loss: 0.0033 - r_factor_metric: 1.0108
# Epoch 408/500
# 1/1 [==============================] - 0s 61ms/step - loss: 0.0033 - r_factor_metric: 1.0108
# Epoch 409/500
# 1/1 [==============================] - 0s 7ms/step - loss: 0.0033 - r_factor_metric: 1.0108
# Epoch 410/500
# 1/1 [==============================] - 0s 9ms/step - loss: 0.0033 - r_factor_metric: 1.0108
# Epoch 411/500
# 1/1 [==============================] - 0s 9ms/step - loss: 0.0033 - r_factor_metric: 1.0108
# Epoch 412/500
# 1/1 [==============================] - 0s 10ms/step - loss: 0.0033 - r_factor_metric: 1.0108
# Epoch 413/500
# 1/1 [==============================] - 0s 9ms/step - loss: 0.0033 - r_factor_metric: 1.0108
# Epoch 414/500
# 1/1 [==============================] - 0s 11ms/step - loss: 0.0033 - r_factor_metric: 1.0108
# Epoch 415/500
# 1/1 [==============================] - 0s 11ms/step - loss: 0.0033 - r_factor_metric: 1.0108
# Epoch 416/500
# 1/1 [==============================] - 0s 10ms/step - loss: 0.0033 - r_factor_metric: 1.0108
# Epoch 417/500
# 1/1 [==============================] - 0s 8ms/step - loss: 0.0033 - r_factor_metric: 1.0108
# Epoch 418/500
# 1/1 [==============================] - 0s 9ms/step - loss: 0.0033 - r_factor_metric: 1.0108
# Epoch 419/500
# 1/1 [==============================] - 0s 8ms/step - loss: 0.0033 - r_factor_metric: 1.0108
# Epoch 420/500
# 1/1 [==============================] - 0s 9ms/step - loss: 0.0033 - r_factor_metric: 1.0108
# Epoch 421/500
# 1/1 [==============================] - 0s 8ms/step - loss: 0.0033 - r_factor_metric: 1.0108
# Epoch 422/500
# 1/1 [==============================] - 0s 11ms/step - loss: 0.0033 - r_factor_metric: 1.0108
# Epoch 423/500
# 1/1 [==============================] - 0s 10ms/step - loss: 0.0033 - r_factor_metric: 1.0108
# Epoch 424/500
# 1/1 [==============================] - 0s 10ms/step - loss: 0.0033 - r_factor_metric: 1.0108
# Epoch 425/500
# 1/1 [==============================] - 0s 8ms/step - loss: 0.0033 - r_factor_metric: 1.0108
# Epoch 426/500
# 1/1 [==============================] - 0s 7ms/step - loss: 0.0033 - r_factor_metric: 1.0108
# Epoch 427/500
# 1/1 [==============================] - 0s 14ms/step - loss: 0.0033 - r_factor_metric: 1.0108
# Epoch 428/500
# 1/1 [==============================] - 0s 11ms/step - loss: 0.0033 - r_factor_metric: 1.0108
# Epoch 429/500
# 1/1 [==============================] - 0s 10ms/step - loss: 0.0033 - r_factor_metric: 1.0108
# Epoch 430/500
# 1/1 [==============================] - 0s 9ms/step - loss: 0.0033 - r_factor_metric: 1.0108
# Epoch 431/500
# 1/1 [==============================] - 0s 10ms/step - loss: 0.0033 - r_factor_metric: 1.0108
# Epoch 432/500
# 1/1 [==============================] - 0s 9ms/step - loss: 0.0033 - r_factor_metric: 1.0108
# Epoch 433/500
# 1/1 [==============================] - 0s 9ms/step - loss: 0.0033 - r_factor_metric: 1.0108
# Epoch 434/500
# 1/1 [==============================] - 0s 10ms/step - loss: 0.0033 - r_factor_metric: 1.0108
# Epoch 435/500
# 1/1 [==============================] - 0s 9ms/step - loss: 0.0033 - r_factor_metric: 1.0108
# Epoch 436/500
# 1/1 [==============================] - 0s 12ms/step - loss: 0.0033 - r_factor_metric: 1.0108
# Epoch 437/500
# 1/1 [==============================] - 0s 9ms/step - loss: 0.0033 - r_factor_metric: 1.0108
# Epoch 438/500
# 1/1 [==============================] - 0s 10ms/step - loss: 0.0033 - r_factor_metric: 1.0108
# Epoch 439/500
# 1/1 [==============================] - 0s 9ms/step - loss: 0.0033 - r_factor_metric: 1.0108
# Epoch 440/500
# 1/1 [==============================] - 0s 10ms/step - loss: 0.0033 - r_factor_metric: 1.0108
# Epoch 441/500
# 1/1 [==============================] - 0s 21ms/step - loss: 0.0033 - r_factor_metric: 1.0108
# Epoch 442/500
# 1/1 [==============================] - 0s 98ms/step - loss: 0.0033 - r_factor_metric: 1.0108
# Epoch 443/500
# 1/1 [==============================] - 0s 18ms/step - loss: 0.0033 - r_factor_metric: 1.0108
# Epoch 444/500
# 1/1 [==============================] - 0s 8ms/step - loss: 0.0033 - r_factor_metric: 1.0108
# Epoch 445/500
# 1/1 [==============================] - 0s 8ms/step - loss: 0.0033 - r_factor_metric: 1.0108
# Epoch 446/500
# 1/1 [==============================] - 0s 8ms/step - loss: 0.0033 - r_factor_metric: 1.0108
# Epoch 447/500
# 1/1 [==============================] - 0s 11ms/step - loss: 0.0033 - r_factor_metric: 1.0108
# Epoch 448/500
# 1/1 [==============================] - 0s 12ms/step - loss: 0.0033 - r_factor_metric: 1.0108
# Epoch 449/500
# 1/1 [==============================] - 0s 8ms/step - loss: 0.0033 - r_factor_metric: 1.0108
# Epoch 450/500
# 1/1 [==============================] - 0s 8ms/step - loss: 0.0033 - r_factor_metric: 1.0108
# Epoch 451/500
# 1/1 [==============================] - 0s 11ms/step - loss: 0.0033 - r_factor_metric: 1.0108
# Epoch 452/500
# 1/1 [==============================] - 0s 8ms/step - loss: 0.0033 - r_factor_metric: 1.0108
# Epoch 453/500
# 1/1 [==============================] - 0s 12ms/step - loss: 0.0033 - r_factor_metric: 1.0108
# Epoch 454/500
# 1/1 [==============================] - 0s 10ms/step - loss: 0.0033 - r_factor_metric: 1.0108
# Epoch 455/500
# 1/1 [==============================] - 0s 8ms/step - loss: 0.0033 - r_factor_metric: 1.0108
# Epoch 456/500
# 1/1 [==============================] - 0s 10ms/step - loss: 0.0033 - r_factor_metric: 1.0108
# Epoch 457/500
# 1/1 [==============================] - 0s 10ms/step - loss: 0.0033 - r_factor_metric: 1.0108
# Epoch 458/500
# 1/1 [==============================] - 0s 9ms/step - loss: 0.0033 - r_factor_metric: 1.0108
# Epoch 459/500
# 1/1 [==============================] - 0s 10ms/step - loss: 0.0033 - r_factor_metric: 1.0108
# Epoch 460/500
# 1/1 [==============================] - 0s 9ms/step - loss: 0.0033 - r_factor_metric: 1.0108
# Epoch 461/500
# 1/1 [==============================] - 0s 23ms/step - loss: 0.0033 - r_factor_metric: 1.0108
# Epoch 462/500
# 1/1 [==============================] - 0s 28ms/step - loss: 0.0033 - r_factor_metric: 1.0108
# Epoch 463/500
# 1/1 [==============================] - 0s 11ms/step - loss: 0.0033 - r_factor_metric: 1.0108
# Epoch 464/500
# 1/1 [==============================] - 0s 9ms/step - loss: 0.0033 - r_factor_metric: 1.0108
# Epoch 465/500
# 1/1 [==============================] - 0s 8ms/step - loss: 0.0033 - r_factor_metric: 1.0108
# Epoch 466/500
# 1/1 [==============================] - 0s 11ms/step - loss: 0.0033 - r_factor_metric: 1.0108
# Epoch 467/500
# 1/1 [==============================] - 0s 9ms/step - loss: 0.0033 - r_factor_metric: 1.0108
# Epoch 468/500
# 1/1 [==============================] - 0s 8ms/step - loss: 0.0033 - r_factor_metric: 1.0108
# Epoch 469/500
# 1/1 [==============================] - 0s 9ms/step - loss: 0.0033 - r_factor_metric: 1.0108
# Epoch 470/500
# 1/1 [==============================] - 0s 20ms/step - loss: 0.0033 - r_factor_metric: 1.0108
# Epoch 471/500
# 1/1 [==============================] - 0s 9ms/step - loss: 0.0033 - r_factor_metric: 1.0108
# Epoch 472/500
# 1/1 [==============================] - 0s 10ms/step - loss: 0.0033 - r_factor_metric: 1.0108
# Epoch 473/500
# 1/1 [==============================] - 0s 9ms/step - loss: 0.0033 - r_factor_metric: 1.0108
# Epoch 474/500
# 1/1 [==============================] - 0s 8ms/step - loss: 0.0033 - r_factor_metric: 1.0108
# Epoch 475/500
# 1/1 [==============================] - 0s 11ms/step - loss: 0.0033 - r_factor_metric: 1.0108
# Epoch 476/500
# 1/1 [==============================] - 0s 8ms/step - loss: 0.0033 - r_factor_metric: 1.0108
# Epoch 477/500
# 1/1 [==============================] - 0s 10ms/step - loss: 0.0033 - r_factor_metric: 1.0108
# Epoch 478/500
# 1/1 [==============================] - 0s 9ms/step - loss: 0.0033 - r_factor_metric: 1.0108
# Epoch 479/500
# 1/1 [==============================] - 0s 128ms/step - loss: 0.0033 - r_factor_metric: 1.0108
# Epoch 480/500
# 1/1 [==============================] - 0s 8ms/step - loss: 0.0033 - r_factor_metric: 1.0108
# Epoch 481/500
# 1/1 [==============================] - 0s 10ms/step - loss: 0.0033 - r_factor_metric: 1.0108
# Epoch 482/500
# 1/1 [==============================] - 0s 10ms/step - loss: 0.0033 - r_factor_metric: 1.0108
# Epoch 483/500
# 1/1 [==============================] - 0s 10ms/step - loss: 0.0033 - r_factor_metric: 1.0108
# Epoch 484/500
# 1/1 [==============================] - 0s 10ms/step - loss: 0.0033 - r_factor_metric: 1.0108
# Epoch 485/500
# 1/1 [==============================] - 0s 9ms/step - loss: 0.0033 - r_factor_metric: 1.0108
# Epoch 486/500
# 1/1 [==============================] - 0s 9ms/step - loss: 0.0033 - r_factor_metric: 1.0108
# Epoch 487/500
# 1/1 [==============================] - 0s 9ms/step - loss: 0.0033 - r_factor_metric: 1.0108
# Epoch 488/500
# 1/1 [==============================] - 0s 8ms/step - loss: 0.0033 - r_factor_metric: 1.0108
# Epoch 489/500
# 1/1 [==============================] - 0s 7ms/step - loss: 0.0033 - r_factor_metric: 1.0108
# Epoch 490/500
# 1/1 [==============================] - 0s 10ms/step - loss: 0.0033 - r_factor_metric: 1.0108
# Epoch 491/500
# 1/1 [==============================] - 0s 11ms/step - loss: 0.0033 - r_factor_metric: 1.0108
# Epoch 492/500
# 1/1 [==============================] - 0s 9ms/step - loss: 0.0033 - r_factor_metric: 1.0108
# Epoch 493/500
# 1/1 [==============================] - 0s 10ms/step - loss: 0.0033 - r_factor_metric: 1.0108
# Epoch 494/500
# 1/1 [==============================] - 0s 9ms/step - loss: 0.0033 - r_factor_metric: 1.0108
# Epoch 495/500
# 1/1 [==============================] - 0s 11ms/step - loss: 0.0033 - r_factor_metric: 1.0108
# Epoch 496/500
# 1/1 [==============================] - 0s 10ms/step - loss: 0.0033 - r_factor_metric: 1.0108
# Epoch 497/500
# 1/1 [==============================] - 0s 18ms/step - loss: 0.0033 - r_factor_metric: 1.0108
# Epoch 498/500
# 1/1 [==============================] - 0s 53ms/step - loss: 0.0033 - r_factor_metric: 1.0108
# Epoch 499/500
# 1/1 [==============================] - 0s 15ms/step - loss: 0.0033 - r_factor_metric: 1.0108
# Epoch 500/500
# 1/1 [==============================] - 0s 9ms/step - loss: 0.0033 - r_factor_metric: 1.0108
# (14,)
# Final loss: 3.344e-03
# time elapsed: 22.96 seconds
# With 43.544726063673366 iterations per second

# %%
all_losses = best_loss_overall
best_model_pars = best_pars_overall
min_loss = best_rf_overall

print(f"min loss: {min_loss}")


# Plotting the loss values
plt.figure(figsize=(10, 6))

# Plot the loss values for each iteration
for i, loss_values in enumerate(all_losses):
    plt.plot(loss_values, label=f'Iteration {i+1}')

plt.title('Loss vs Epochs')
plt.xlabel('Epochs')
plt.ylabel('Loss')
# plt.legend()
plt.grid(True)
plt.show()
# Out:
# min loss: 0.0005113011575303972

# %%
mode_names = pd.read_csv('C:/Users/User/Desktop/uzh_intern/CrystalClearFit/alrisDistortionFit/PrNiO2/C4/raw_data/PrNiO2_C4_displacivemode_names.txt' , delim_whitespace=True, header=None)

mode_names = mode_names.values.tolist()
mode_names = pd.DataFrame(mode_names)

# Print the best model parameters
print("Best model parameters:") 
for i, par in enumerate(best_model_pars):
    print(f"{mode_names.iloc[i , 1]} : {par.numpy():.8f}")
    
# Print the model summary
print("Number of iterations:", n_iter)
print("Number of features:", n_features)
#modes = get_mode_amplitudes_p63(*best_model_pars)
#print("Modes:")
##for key, val in modes.items():
    #print(f"{key}: {val*1000:.4f}")
# Out:
# Best model parameters:
# P4/mmm[1/4,1/4,1/2]S1(a,0;b,0)[Pr1:d:dsp]A2u(a) : -0.64292592
# P4/mmm[1/4,1/4,1/2]S1(a,0;b,0)[Pr1:d:dsp]A2u(b) : -0.60938311
# P4/mmm[0,1/2,0]X1+(a;a)[Pr1:d:dsp]Eu(a) : -0.05159410
# P4/mmm[0,1/2,0]X2+(a;a)[Pr1:d:dsp]Eu(a) : -0.00011788
# P4/mmm[1/4,1/4,1/2]S1(a,0;b,0)[O1:f:dsp]B3u(a) : -0.67818880
# P4/mmm[1/4,1/4,1/2]S1(a,0;b,0)[O1:f:dsp]B3u(b) : -0.79106575
# P4/mmm[1/4,1/4,1/2]S1(a,0;b,0)[O1:f:dsp]B2u(a) : -0.67009985
# P4/mmm[1/4,1/4,1/2]S1(a,0;b,0)[O1:f:dsp]B2u(b) : -0.76032257
# P4/mmm[1/2,1/2,0]M1+(a)[O1:f:dsp]B2u(a) : 1.65428257
# P4/mmm[1/2,1/2,0]M4+(a)[O1:f:dsp]B3u(a) : 0.79048854
# P4/mmm[0,1/2,0]X1+(a;a)[O1:f:dsp]B2u(a) : -0.27731568
# P4/mmm[0,1/2,0]X2+(a;a)[O1:f:dsp]B3u(a) : 0.02895240
# P4/mmm[1/4,1/4,1/2]S1(a,0;b,0)[Ni1:a:dsp]Eu(a) : 0.04586520
# P4/mmm[1/4,1/4,1/2]S1(a,0;b,0)[Ni1:a:dsp]Eu(b) : -0.04664319
# Number of iterations: 2
# Number of features: 910
# C:\Users\User\AppData\Local\Temp\ipykernel_25228\2965176560.py:1: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   mode_names = pd.read_csv('C:/Users/User/Desktop/uzh_intern/CrystalClearFit/alrisDistortionFit/PrNiO2/C4/raw_data/PrNiO2_C4_displacivemode_names.txt' , delim_whitespace=True, header=None)

# %%
def plot_plane_sim_vs_exp(ax, df, l, norm_plane=False):
    exp_data_0 = df.loc[df['l'] == l].copy()
    if norm_plane:
        exp_data_0['intensity_sim'] = exp_data_0['intensity_sim'] / np.max(exp_data_0['intensity_sim'])
        exp_data_0['intensity_exp'] = exp_data_0['intensity_exp'] / np.max(exp_data_0['intensity_exp'])
    
    ax.scatter(exp_data_0['h'], -exp_data_0['k'], 
               s=exp_data_0['intensity_sim'] * 300, color='red', edgecolor="black",
               label='Sim', marker=MarkerStyle("o", fillstyle="left"))
    ax.scatter(exp_data_0['h'], -exp_data_0['k'], 
               s=exp_data_0['intensity_exp'] * 300, color='blue', edgecolor="black",
               label='Exp', marker=MarkerStyle("o", fillstyle="right"))
    
    ax.set_xlabel(f"h in (h, k, {l}) [r.l.u.]")
    ax.set_ylabel(f"k in (h, k, {l}) [r.l.u.]")
    ax.set_title(f"l = {l}")
    ax.legend()

# %%
exp_data = pd.read_csv('C:/Users/User/Desktop/uzh_intern/CrystalClearFit/alrisDistortionFit/PrNiO2/C4/raw_data/combined.csv')
exp_data['intensity_sim'] = fun_tf(features, best_model_pars).numpy()
# Out:
# Shape of atom_shift_list: 14
# Shape of sf_combined: (910,), Shape of x_combined: (910, 3)

# %%
# Prepare subplot grid
l_values = np.arange(0, 5, 0.5)
n = len(l_values)
ncols = int(np.ceil(n / 3))
fig, axs = plt.subplots(3, ncols, figsize=(6 * ncols, 12), constrained_layout=True)

# Flatten axs in case it's 2D array
axs = axs.flatten()

plt.style.use('default')


# Plot all subplots
for i, l in enumerate(l_values):
    plot_plane_sim_vs_exp(axs[i], exp_data, l, norm_plane=True)

plt.show()

# %%
#save the experiment data with simulated intensities
exp_data.to_csv('C:/Users/User/Desktop/uzh_intern/CrystalClearFit/alrisDistortionFit/PrNiO2/C4/fitted_data/PrNiO2_peaks_with_simulated_intensities.txt', index=False)

#save all the parameters and the modes
with open('C:/Users/User/Desktop/uzh_intern/CrystalClearFit/alrisDistortionFit/PrNiO2/C4/fitted_data/PrNiO2_parameters_and_modes.txt', 'w') as f:
    f.write(f"final loss: {min_loss:.8f}\n")
    f.write(f"learning_rate: {lr[0]:.8f}\n")
    f.write(f"n_epochs: {n_epochs}\n")
    f.write(f"Best model parameters:\n")
    for i, par in enumerate(best_model_pars):
        f.write(f"{mode_names.iloc[i, 1]} : {par.numpy():.8f} \n")

abs_params = tf.abs(best_model_pars)
best_model_pars_compare = best_model_pars.numpy()
best_model_pars_compare = best_model_pars_compare / np.max(best_model_pars_compare)

#save all the parameters and the modes
with open('C:/Users/User/Desktop/uzh_intern/CrystalClearFit/alrisDistortionFit/PrNiO2/C4/fitted_data/PrNiO2_parameters_and_modes_normalised.txt', 'w') as f:
    f.write(f"final loss: {min_loss:.8f}\n")
    f.write(f"learning_rate: {lr[0]:.8f}\n")
    f.write(f"n_epochs: {n_epochs}\n")
    f.write(f"Best model parameters:\n")
    for i, par in enumerate(best_model_pars_compare):
        f.write(f"{mode_names.iloc[i, 1]} : {par:.8f} \n")

# %%
best_data = pd.read_csv('C:/Users/User/Desktop/uzh_intern/CrystalClearFit/alrisDistortionFit/PrNiO2/C4/fitted_data/PrNiO2_peaks_with_simulated_intensities.txt')


# Prepare subplot grid
l_values = np.arange(0, 5, 0.5)
n = len(l_values)
ncols = int(np.ceil(n / 3))
fig, axs = plt.subplots(3, ncols, figsize=(6 * ncols, 12), constrained_layout=True)

# Flatten axs in case it's 2D array
axs = axs.flatten()

plt.style.use('default')


# Plot all subplots
for i, l in enumerate(l_values):
    plot_plane_sim_vs_exp(axs[i], best_data, l, norm_plane=True)

plt.show()
