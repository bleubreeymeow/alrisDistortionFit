# %% [markdown]
# # Pr-YBCO version Fit modes P3

# %%
import numpy as np
import matplotlib.pyplot as plt
import tensorflow as tf
import pandas as pd
from PrNiO2_alris_functions2 import shift_atoms, transform_list_hkl_p63_p65, get_structure_factors , atom_position_list
from itertools import chain
from matplotlib.markers import MarkerStyle
from tqdm import tqdm
from time import time

# %config InlineBackend.figure_format = 'svg' # make figures appears in .svg style




num_threads = 2  

# Configure TensorFlow to use multiple threads
tf.config.threading.set_intra_op_parallelism_threads(num_threads)
tf.config.threading.set_inter_op_parallelism_threads(num_threads)

print(f"Using {num_threads} threads for intra-op and inter-op parallelism.")
# Out:
# Using 2 threads for intra-op and inter-op parallelism.

# %% [markdown]
# Define the function containing the fitting parameters
#
# <span style="color:yellow">Note on actual unit cell structure refinement problem:</span>
# - `fun_tf()` correspond to the **structure factor calculation function** (one has to convert it to a **TF-compatible** function)
# - <span style="color:red">If conversion to TF-compatible function is not possible, then this approach will probably not work (or becomes much more tedious at least)</span>

# %%
#convert the simulated data to log10 scale

def log10(x):
  numerator = tf.math.log(x)
  denominator = tf.math.log(tf.constant(10, dtype=numerator.dtype))
  return numerator / denominator

# %%
def fun_tf(x, pars):
    """
    Fast computation of structure factors with parameter-dependent structure.
        # Get modified structure
    modified_struct = shift_atoms_p65(*pars)
    neg_h = tf.stack([-x[:, 0], x[:, 1], x[:, 2]], axis=1)
    x_combined = tf.concat([x, neg_h], axis=0)  # Shape [2N, 3]

    x_combined = transform_list_hkl_p63_p65(x_combined)

    # Get structure factors
    sf_combined = get_structure_factors(x_combined, modified_struct)
    # Compute intensity
    # Split and compute intensity
    sf_hkl = sf_combined[:tf.shape(x)[0]]
    sf_neg_k = sf_combined[tf.shape(x)[0]:]
    
    intensity = (tf.abs(sf_hkl) + tf.abs(sf_neg_k)) ** 2
    return intensity / tf.reduce_max(intensity)
    """
    # Get modified structure
    atom_shift_list = shift_atoms(*pars)
    print(f"Shape of atom_shift_list: {len(atom_shift_list)}")



    # Flatten atom_shift_list if it contains nested lists
    flat_atom_shift_list = list(chain.from_iterable(
        x if isinstance(x, list) else [x] for x in atom_shift_list
    ))
    modified_struct = atom_position_list(*flat_atom_shift_list)

    #neg_h = tf.stack([-x[:, 0], x[:, 1], x[:, 2]], axis=1)
    x_combined = x
    #x_combined = tf.concat([x, neg_h], axis=0)  # Shape [2N, 3]

    x_combined = transform_list_hkl_p63_p65(x_combined)

    # Get structure factors
    sf_combined = get_structure_factors(x_combined, modified_struct)
    # Compute intensity
    # Split and compute intensity
    sf_hkl = sf_combined[:tf.shape(x)[0]]
    
    print(f"Shape of sf_combined: {sf_combined.shape}, Shape of x_combined: {x_combined.shape}")
    
    intensity = (tf.abs(sf_hkl)) ** 2
    w = tf.constant(0.00159, dtype=tf.float32)  # Debye-Waller factor is 0.00159
    qnorms = tf.norm(tf.cast(x_combined[:tf.shape(x)[0]], tf.float32), axis=1)
    # qnorms = tf.reshape(qnorms, (-1, 1))  # Reshape to match the shape of intensity
    intensity = intensity * tf.exp(-w * qnorms ** 2)  # Apply Debye-Waller factor
    #intensity = log10(intensity + 1)  # Convert to log10 scale
    return intensity / tf.reduce_max(intensity)

# %%
experimental_data = pd.read_csv('C:/Users/User/Desktop/uzh_intern/CrystalClearFit/alrisDistortionFit/PrNiO2/P3/raw_data/combined.csv')
"""
# reduce data to l in [0.5, 1.5, 2.5, 3.5, 4.5 ]
experimental_data = experimental_data[
    (experimental_data["l"] == 0.5) |
    (experimental_data["l"] == 1.5) |
    (experimental_data["l"] == 2.5) |
    (experimental_data["l"] == 3.5) |
    (experimental_data["l"] == 4.5)
]
"""

hkl_list = experimental_data[["h", "k", "l"]].values.tolist()
hkl_list = tf.convert_to_tensor(hkl_list, dtype=tf.float32)
#remove all the non 0 l values 

print(experimental_data.shape)
print(hkl_list[0:5])
# Out:
# (910, 17)
# tf.Tensor(
# [[-0.5 -0.5  0. ]
#  [ 0.5 -0.5  0. ]
#  [-1.5 -0.5  0. ]
#  [ 1.5 -0.5  0. ]
#  [-2.5 -0.5  0. ]], shape=(5, 3), dtype=float32)

# %% [markdown]
# Sample the "training data" (features and labels)
#
# <span style="color:yellow">Note on actual unit cell structure refinement problem:</span>
# - The features are the (h,k,l) coordinates (e.g. a vector of size `n_features` x 3, i.e. `n_dim = 3`)
# - Maybe one has to normalize the features (i.e. not using integers but floats between -1 (0) and 1)? Before passing them to the structure calculation function, they should be again rescaled to integers
# - The labels would be the experimental intensities (again, maybe have to be normalized to the range between 0 and 1)

# %%
n_features = experimental_data.shape[0]
n_dim = 3

features = hkl_list
labels = experimental_data["intensity_exp"].tolist()
#labels = tf.convert_to_tensor(labels, dtype=tf.float32)
print("Max label:", np.max(labels))
print("min label :", np.min(labels))

plt.hist(labels , 10)
vol_err = experimental_data["intensity_exp_err"].tolist()
labels_err = []
for label, err in zip(labels, vol_err):
    
    labels_err.append(1/(label + 1))  # Inverse error

labels = labels / np.max(labels)  # Normalize labels

labels_err = tf.convert_to_tensor(labels_err, dtype=tf.float32)
labels = tf.convert_to_tensor(labels, dtype=tf.float32)


plt.hist(labels_err , 10)
# Out:
# Max label: 1.0
# min label : 0.0
# (array([  2.,  10.,   6.,  24.,  30.,  48.,  70.,  86., 142., 492.]),
#  array([0.5       , 0.55000001, 0.60000002, 0.64999998, 0.69999999,
#         0.75      , 0.80000001, 0.85000002, 0.89999998, 0.94999999,
#         1.        ]),
#  <BarContainer object of 10 artists>)

# %%
labels = tf.expand_dims(labels, axis=-1)  # Ensure labels are 2D
labels_err = tf.expand_dims(labels_err, axis=-1)  # Ensure labels_err are 2D

print("Max label err:", np.max(labels_err))
print("min label err:", np.min(labels_err))
print("Features shape:", features.shape)
print("Labels shape:", labels.shape)
print('error shape:', labels_err.shape)
print("Max label:", np.max(labels))
print("min label :", np.min(labels))
# Out:
# Max label err: 1.0
# min label err: 0.5
# Features shape: (910, 3)
# Labels shape: (910, 1)
# error shape: (910, 1)
# Max label: 1.0
# min label : 0.0

# %% [markdown]
# Define a simple model
#
# <span style="color:yellow">Note on actual unit cell structure refinement problem:</span>
# - The six parameters (a,b,c,d,e,f) correspond to the fractional atomic shifts in the modes w.r.t. unit cell lengths
# - Instead of `sigmoid`, `tanh` should be applied to the parameters before passing them to the structure factor calculation function (ensures smoother gradient landscape)
# - The `tanh` function can furthermore be limited to a specific range (e.g. if atomic distortions should not exceed +- 0.1)

# %%
class FunAsLayer(tf.keras.layers.Layer):
    def __init__(self, max_mode_amps,**kwargs):
        super().__init__(**kwargs)
        self.max_mode_amps = max_mode_amps

    def build(self, input_shape):
        self.param = self.add_weight(name='param', shape=(7,), initializer=tf.keras.initializers.he_uniform(), trainable=True)
        super().build(input_shape)

    def call(self, inputs):
        # Apply tanh to ensure parameters stay within the [-1, 1] range then multiply by max_mode_amps so each parameter is scaled corresponding to the element in max_mode_amps
        pretransform = tf.tanh(self.param)
        transformed_params = pretransform * self.max_mode_amps  # Scale parameters

        output = fun_tf(inputs, tf.unstack(transformed_params))
        return tf.reshape(output , [-1])  # Ensure output is 1D

# %% [markdown]
# Create optimizer and define loss function
#
# <span style="color:yellow">Note on actual unit cell structure refinement problem:</span>
# - The learning rate must be determined by experimentation (same holds for the batch size and the number of epochs below)
# - As a loss function, one can try either MSE or R-score (MSE seems to be the more "natural choice" in this case)

# %%
"""
# R-Score based on intensity
class RFactorLoss(tf.keras.losses.Loss):
    def call(self, y_true, y_pred):
        return tf.reduce_sum(tf.abs(y_true - y_pred)) / tf.reduce_sum(y_true)
"""
    
# mean squared error
class PerSampleMSE(tf.keras.losses.Loss):
    def __init__(self):
        super().__init__(reduction=tf.keras.losses.Reduction.NONE)

    def call(self, y_true, y_pred):
        squared_error = tf.square(y_true - y_pred)
        per_sample_mse = tf.reduce_mean(squared_error, axis=-1)
        return per_sample_mse  # shape (batch_size,)

class MSE_weighted(tf.keras.losses.Loss):
    def call(self, y_true, y_pred):
        # Assume y_true = [labels, errors]
        print('ytrue shape:', y_true.shape)
        print('y true' , y_true)
        labels = y_true[:, 0]
        weights = y_true[:, 1]

        mse = tf.square(labels - y_pred)
        return tf.reduce_sum(mse * weights) / tf.reduce_sum(weights)


# Define the custom metric function
def r_factor_metric(y_true, y_pred):
    labels = y_true
    return tf.reduce_sum(tf.abs(labels - y_pred)) / tf.reduce_sum(labels)

# %% [markdown]
# Train the model for n iterations (to try different initial weights)
#
# <span style="color:yellow">Note on actual unit cell structure refinement problem:</span>
# - The number of iterations defines the "starting position" $w_0$ of the gradient descent algorithm
# - Because there are probably many local minima, changing $w_0$ allows the algorithm to find different minima and increases the chances of finding the global minima

# %%
#squeeze labels and labels_err to ensure they are 1D tensors
#labels = tf.squeeze(labels)
#labels_err = tf.squeeze(labels_err)

print("labels shape:", labels.shape)
print("labels_err shape:", labels_err.shape)


lr = [1e-2]
best_pars_overall = None
best_rf_overall = np.inf
best_loss_overall = []
for learning_rate in lr:
    time_start = time()
    print(f"Learning rate: {learning_rate}")
    optim = tf.keras.optimizers.Adam(learning_rate=learning_rate)

    max_mode_amps = tf.constant([2.83 , 2.83 , 2.83 , 2.83 , 4.00 , 4.00 , 2.00], dtype=tf.float32) 
    print("max_mode_amps shape:", max_mode_amps.shape)

    n_epochs = 100
    histories = []
    n_iter = 10

    min_loss = np.inf
    best_pars = None

    # List to store the loss values for each epoch
    all_losses = []


    for i in range(n_iter):
        # Create the model
        inputs = tf.keras.Input(shape=(n_dim,))
        outputs = FunAsLayer(max_mode_amps)(inputs)
        model = tf.keras.Model(inputs, outputs)

        # Compile the model with the custom loss function and metric
        model.compile(
            optimizer=optim,
            loss='mse', # MSE_weighted() if using errors
            metrics=[r_factor_metric]

        )
        
        history = model.fit(
        x=features,
        y=labels,  # replace with combined_labels if using errors
        batch_size = features.shape[0], # Use a smaller batch size features.shape[0]
        epochs=n_epochs,
        verbose='auto',
        shuffle=True, # not sure whether this matters
        # callbacks=[cb]
        sample_weight=labels_err  # Use sample weights if you have errors
        )

        histories.append(history)
        all_losses.append(history.history['loss'])
        # Check final loss
        final_loss = history.history['loss'][-1]
        print(model.layers[-1].get_weights()[0].shape)
        curren_model_pars = max_mode_amps * tf.tanh(model.layers[-1].get_weights()[0])
        print(f"Final loss: {final_loss:.3e}")
        '''
        print(f"Best parameters for iteration {i+1}:")
        for j, par in enumerate(curren_model_pars):
            print(f"Parameter {j+1}: {par.numpy():.4f}")
        '''

        if final_loss < min_loss:
            # Update best model parameters
            best_model_pars = max_mode_amps * tf.tanh(model.layers[-1].get_weights()[0])
            min_loss = final_loss
            rf = r_factor_metric(labels, fun_tf(features, best_model_pars))
            print(f"Iteration {i+1} - New best loss: {min_loss:.3e} (R-factor: {rf:.3e})")

    if min_loss < best_rf_overall:
        best_rf_overall = min_loss
        best_pars_overall = best_model_pars
        best_loss_overall = all_losses
    print(f"time elapsed: {time() - time_start:.2f} seconds")
    print(f"With {n_epochs*n_iter /(time() - time_start)} iterations per second")
    # Plotting the loss values
    plt.figure(figsize=(10, 6))

    # Plot the loss values for each iteration
    for i, loss_values in enumerate(all_losses):
        plt.plot(loss_values, label=f'Iteration {i+1}')

    plt.title(f'Loss vs Epochs with Learning Rate {learning_rate}')
    plt.xlabel('Epochs')
    plt.ylabel('Loss')
    # plt.legend()
    plt.grid(True)
    plt.show()
# Out:
# labels shape: (910, 1)
# labels_err shape: (910, 1)
# Learning rate: 0.01
# max_mode_amps shape: (7,)
# Shape of atom_shift_list: 7
# Shape of sf_combined: (None,), Shape of x_combined: (None, 3)
# Epoch 1/100
# Shape of atom_shift_list: 7
# Shape of sf_combined: (910,), Shape of x_combined: (910, 3)
# Shape of atom_shift_list: 7
# Shape of sf_combined: (910,), Shape of x_combined: (910, 3)
# 1/1 [==============================] - 2s 2s/step - loss: 0.0410 - r_factor_metric: 1.3292
# Epoch 2/100
# 1/1 [==============================] - 0s 6ms/step - loss: 0.0397 - r_factor_metric: 1.3102
# Epoch 3/100
# 1/1 [==============================] - 0s 7ms/step - loss: 0.0386 - r_factor_metric: 1.2940
# Epoch 4/100
# 1/1 [==============================] - 0s 5ms/step - loss: 0.0376 - r_factor_metric: 1.2797
# Epoch 5/100
# 1/1 [==============================] - 0s 7ms/step - loss: 0.0368 - r_factor_metric: 1.2681
# Epoch 6/100
# 1/1 [==============================] - 0s 8ms/step - loss: 0.0360 - r_factor_metric: 1.2589
# Epoch 7/100
# 1/1 [==============================] - 0s 6ms/step - loss: 0.0354 - r_factor_metric: 1.2503
# Epoch 8/100
# 1/1 [==============================] - 0s 7ms/step - loss: 0.0348 - r_factor_metric: 1.2423
# Epoch 9/100
# 1/1 [==============================] - 0s 5ms/step - loss: 0.0343 - r_factor_metric: 1.2345
# Epoch 10/100
# 1/1 [==============================] - 0s 8ms/step - loss: 0.0339 - r_factor_metric: 1.2265
# Epoch 11/100
# 1/1 [==============================] - 0s 7ms/step - loss: 0.0334 - r_factor_metric: 1.2178
# Epoch 12/100
# 1/1 [==============================] - 0s 7ms/step - loss: 0.0330 - r_factor_metric: 1.2097
# Epoch 13/100
# 1/1 [==============================] - 0s 6ms/step - loss: 0.0326 - r_factor_metric: 1.2022
# Epoch 14/100
# 1/1 [==============================] - 0s 6ms/step - loss: 0.0318 - r_factor_metric: 1.1864
# Epoch 15/100
# 1/1 [==============================] - 0s 7ms/step - loss: 0.0310 - r_factor_metric: 1.1696
# Epoch 16/100
# 1/1 [==============================] - 0s 6ms/step - loss: 0.0302 - r_factor_metric: 1.1538
# Epoch 17/100
# 1/1 [==============================] - 0s 7ms/step - loss: 0.0295 - r_factor_metric: 1.1388
# Epoch 18/100
# 1/1 [==============================] - 0s 7ms/step - loss: 0.0289 - r_factor_metric: 1.1243
# Epoch 19/100
# 1/1 [==============================] - 0s 7ms/step - loss: 0.0283 - r_factor_metric: 1.1103
# Epoch 20/100
# 1/1 [==============================] - 0s 5ms/step - loss: 0.0278 - r_factor_metric: 1.0972
# Epoch 21/100
# 1/1 [==============================] - 0s 5ms/step - loss: 0.0273 - r_factor_metric: 1.0851
# Epoch 22/100
# 1/1 [==============================] - 0s 8ms/step - loss: 0.0269 - r_factor_metric: 1.0736
# Epoch 23/100
# 1/1 [==============================] - 0s 6ms/step - loss: 0.0265 - r_factor_metric: 1.0632
# Epoch 24/100
# 1/1 [==============================] - 0s 6ms/step - loss: 0.0261 - r_factor_metric: 1.0537
# Epoch 25/100
# 1/1 [==============================] - 0s 7ms/step - loss: 0.0258 - r_factor_metric: 1.0457
# Epoch 26/100
# 1/1 [==============================] - 0s 7ms/step - loss: 0.0256 - r_factor_metric: 1.0388
# Epoch 27/100
# 1/1 [==============================] - 0s 6ms/step - loss: 0.0253 - r_factor_metric: 1.0324
# Epoch 28/100
# 1/1 [==============================] - 0s 7ms/step - loss: 0.0251 - r_factor_metric: 1.0264
# Epoch 29/100
# 1/1 [==============================] - 0s 8ms/step - loss: 0.0249 - r_factor_metric: 1.0211
# Epoch 30/100
# 1/1 [==============================] - 0s 5ms/step - loss: 0.0248 - r_factor_metric: 1.0169
# Epoch 31/100
# 1/1 [==============================] - 0s 6ms/step - loss: 0.0246 - r_factor_metric: 1.0135
# Epoch 32/100
# 1/1 [==============================] - 0s 7ms/step - loss: 0.0245 - r_factor_metric: 1.0107
# Epoch 33/100
# 1/1 [==============================] - 0s 6ms/step - loss: 0.0244 - r_factor_metric: 1.0081
# Epoch 34/100
# 1/1 [==============================] - 0s 7ms/step - loss: 0.0243 - r_factor_metric: 1.0055
# Epoch 35/100
# 1/1 [==============================] - 0s 6ms/step - loss: 0.0242 - r_factor_metric: 1.0031
# Epoch 36/100
# 1/1 [==============================] - 0s 6ms/step - loss: 0.0241 - r_factor_metric: 1.0010
# Epoch 37/100
# 1/1 [==============================] - 0s 9ms/step - loss: 0.0241 - r_factor_metric: 0.9990
# Epoch 38/100
# 1/1 [==============================] - 0s 7ms/step - loss: 0.0240 - r_factor_metric: 0.9971
# Epoch 39/100
# 1/1 [==============================] - 0s 7ms/step - loss: 0.0239 - r_factor_metric: 0.9954
# Epoch 40/100
# 1/1 [==============================] - 0s 7ms/step - loss: 0.0239 - r_factor_metric: 0.9938
# Epoch 41/100
# 1/1 [==============================] - 0s 6ms/step - loss: 0.0238 - r_factor_metric: 0.9923
# Epoch 42/100
# 1/1 [==============================] - 0s 8ms/step - loss: 0.0238 - r_factor_metric: 0.9910
# Epoch 43/100
# 1/1 [==============================] - 0s 9ms/step - loss: 0.0238 - r_factor_metric: 0.9897
# Epoch 44/100
# 1/1 [==============================] - 0s 7ms/step - loss: 0.0237 - r_factor_metric: 0.9886
# Epoch 45/100
# 1/1 [==============================] - 0s 9ms/step - loss: 0.0237 - r_factor_metric: 0.9875
# Epoch 46/100
# 1/1 [==============================] - 0s 7ms/step - loss: 0.0237 - r_factor_metric: 0.9866
# Epoch 47/100
# 1/1 [==============================] - 0s 7ms/step - loss: 0.0236 - r_factor_metric: 0.9857
# Epoch 48/100
# 1/1 [==============================] - 0s 8ms/step - loss: 0.0236 - r_factor_metric: 0.9850
# Epoch 49/100
# 1/1 [==============================] - 0s 8ms/step - loss: 0.0236 - r_factor_metric: 0.9842
# Epoch 50/100
# 1/1 [==============================] - 0s 7ms/step - loss: 0.0236 - r_factor_metric: 0.9836
# Epoch 51/100
# 1/1 [==============================] - 0s 9ms/step - loss: 0.0236 - r_factor_metric: 0.9829
# Epoch 52/100
# 1/1 [==============================] - 0s 8ms/step - loss: 0.0235 - r_factor_metric: 0.9823
# Epoch 53/100
# 1/1 [==============================] - 0s 7ms/step - loss: 0.0235 - r_factor_metric: 0.9817
# Epoch 54/100
# 1/1 [==============================] - 0s 9ms/step - loss: 0.0235 - r_factor_metric: 0.9812
# Epoch 55/100
# 1/1 [==============================] - 0s 7ms/step - loss: 0.0235 - r_factor_metric: 0.9807
# Epoch 56/100
# 1/1 [==============================] - 0s 10ms/step - loss: 0.0235 - r_factor_metric: 0.9802
# Epoch 57/100
# 1/1 [==============================] - 0s 9ms/step - loss: 0.0235 - r_factor_metric: 0.9798
# Epoch 58/100
# 1/1 [==============================] - 0s 7ms/step - loss: 0.0235 - r_factor_metric: 0.9794
# Epoch 59/100
# 1/1 [==============================] - 0s 10ms/step - loss: 0.0235 - r_factor_metric: 0.9790
# Epoch 60/100
# 1/1 [==============================] - 0s 9ms/step - loss: 0.0234 - r_factor_metric: 0.9786
# Epoch 61/100
# 1/1 [==============================] - 0s 7ms/step - loss: 0.0234 - r_factor_metric: 0.9783
# Epoch 62/100
# 1/1 [==============================] - 0s 9ms/step - loss: 0.0234 - r_factor_metric: 0.9780
# Epoch 63/100
# 1/1 [==============================] - 0s 8ms/step - loss: 0.0234 - r_factor_metric: 0.9777
# Epoch 64/100
# 1/1 [==============================] - 0s 7ms/step - loss: 0.0234 - r_factor_metric: 0.9775
# Epoch 65/100
# 1/1 [==============================] - 0s 7ms/step - loss: 0.0234 - r_factor_metric: 0.9773
# Epoch 66/100
# 1/1 [==============================] - 0s 6ms/step - loss: 0.0234 - r_factor_metric: 0.9772
# Epoch 67/100
# 1/1 [==============================] - 0s 7ms/step - loss: 0.0234 - r_factor_metric: 0.9771
# Epoch 68/100
# 1/1 [==============================] - 0s 7ms/step - loss: 0.0234 - r_factor_metric: 0.9771
# Epoch 69/100
# 1/1 [==============================] - 0s 7ms/step - loss: 0.0234 - r_factor_metric: 0.9770
# Epoch 70/100
# 1/1 [==============================] - 0s 8ms/step - loss: 0.0234 - r_factor_metric: 0.9769
# Epoch 71/100
# 1/1 [==============================] - 0s 8ms/step - loss: 0.0234 - r_factor_metric: 0.9769
# Epoch 72/100
# 1/1 [==============================] - 0s 6ms/step - loss: 0.0234 - r_factor_metric: 0.9769
# Epoch 73/100
# 1/1 [==============================] - 0s 8ms/step - loss: 0.0234 - r_factor_metric: 0.9768
# Epoch 74/100
# 1/1 [==============================] - 0s 7ms/step - loss: 0.0234 - r_factor_metric: 0.9768
# Epoch 75/100
# 1/1 [==============================] - 0s 7ms/step - loss: 0.0234 - r_factor_metric: 0.9768
# Epoch 76/100
# 1/1 [==============================] - 0s 9ms/step - loss: 0.0234 - r_factor_metric: 0.9768
# Epoch 77/100
# 1/1 [==============================] - 0s 7ms/step - loss: 0.0234 - r_factor_metric: 0.9768
# Epoch 78/100
# 1/1 [==============================] - 0s 9ms/step - loss: 0.0234 - r_factor_metric: 0.9768
# Epoch 79/100
# 1/1 [==============================] - 0s 7ms/step - loss: 0.0234 - r_factor_metric: 0.9767
# Epoch 80/100
# 1/1 [==============================] - 0s 8ms/step - loss: 0.0234 - r_factor_metric: 0.9767
# Epoch 81/100
# 1/1 [==============================] - 0s 7ms/step - loss: 0.0234 - r_factor_metric: 0.9767
# Epoch 82/100
# 1/1 [==============================] - 0s 8ms/step - loss: 0.0234 - r_factor_metric: 0.9767
# Epoch 83/100
# 1/1 [==============================] - 0s 8ms/step - loss: 0.0234 - r_factor_metric: 0.9767
# Epoch 84/100
# 1/1 [==============================] - 0s 7ms/step - loss: 0.0234 - r_factor_metric: 0.9767
# Epoch 85/100
# 1/1 [==============================] - 0s 8ms/step - loss: 0.0234 - r_factor_metric: 0.9767
# Epoch 86/100
# 1/1 [==============================] - 0s 8ms/step - loss: 0.0234 - r_factor_metric: 0.9767
# Epoch 87/100
# 1/1 [==============================] - 0s 7ms/step - loss: 0.0233 - r_factor_metric: 0.9767
# Epoch 88/100
# 1/1 [==============================] - 0s 7ms/step - loss: 0.0233 - r_factor_metric: 0.9767
# Epoch 89/100
# 1/1 [==============================] - 0s 7ms/step - loss: 0.0233 - r_factor_metric: 0.9767
# Epoch 90/100
# 1/1 [==============================] - 0s 7ms/step - loss: 0.0233 - r_factor_metric: 0.9767
# Epoch 91/100
# 1/1 [==============================] - 0s 8ms/step - loss: 0.0233 - r_factor_metric: 0.9767
# Epoch 92/100
# 1/1 [==============================] - 0s 6ms/step - loss: 0.0233 - r_factor_metric: 0.9766
# Epoch 93/100
# 1/1 [==============================] - 0s 8ms/step - loss: 0.0233 - r_factor_metric: 0.9766
# Epoch 94/100
# 1/1 [==============================] - 0s 6ms/step - loss: 0.0233 - r_factor_metric: 0.9766
# Epoch 95/100
# 1/1 [==============================] - 0s 8ms/step - loss: 0.0233 - r_factor_metric: 0.9765
# Epoch 96/100
# 1/1 [==============================] - 0s 8ms/step - loss: 0.0233 - r_factor_metric: 0.9765
# Epoch 97/100
# 1/1 [==============================] - 0s 9ms/step - loss: 0.0233 - r_factor_metric: 0.9764
# Epoch 98/100
# 1/1 [==============================] - 0s 6ms/step - loss: 0.0233 - r_factor_metric: 0.9764
# Epoch 99/100
# 1/1 [==============================] - 0s 8ms/step - loss: 0.0233 - r_factor_metric: 0.9763
# Epoch 100/100
# 1/1 [==============================] - 0s 6ms/step - loss: 0.0233 - r_factor_metric: 0.9763
# (7,)
# Final loss: 2.334e-02
# Shape of atom_shift_list: 7
# Shape of sf_combined: (910,), Shape of x_combined: (910, 3)
# Iteration 1 - New best loss: 2.334e-02 (R-factor: 9.986e+02)
# Shape of atom_shift_list: 7
# Shape of sf_combined: (None,), Shape of x_combined: (None, 3)
# Epoch 1/100
# Shape of atom_shift_list: 7
# Shape of sf_combined: (910,), Shape of x_combined: (910, 3)
# Shape of atom_shift_list: 7
# Shape of sf_combined: (910,), Shape of x_combined: (910, 3)
# 1/1 [==============================] - 2s 2s/step - loss: 0.0365 - r_factor_metric: 1.2561
# Epoch 2/100
# 1/1 [==============================] - 0s 6ms/step - loss: 0.0352 - r_factor_metric: 1.2280
# Epoch 3/100
# 1/1 [==============================] - 0s 7ms/step - loss: 0.0337 - r_factor_metric: 1.1955
# Epoch 4/100
# 1/1 [==============================] - 0s 6ms/step - loss: 0.0324 - r_factor_metric: 1.1637
# Epoch 5/100
# 1/1 [==============================] - 0s 6ms/step - loss: 0.0312 - r_factor_metric: 1.1332
# Epoch 6/100
# 1/1 [==============================] - 0s 7ms/step - loss: 0.0302 - r_factor_metric: 1.1076
# Epoch 7/100
# 1/1 [==============================] - 0s 6ms/step - loss: 0.0293 - r_factor_metric: 1.0848
# Epoch 8/100
# 1/1 [==============================] - 0s 8ms/step - loss: 0.0287 - r_factor_metric: 1.0673
# Epoch 9/100
# 1/1 [==============================] - 0s 5ms/step - loss: 0.0282 - r_factor_metric: 1.0549
# Epoch 10/100
# 1/1 [==============================] - 0s 8ms/step - loss: 0.0278 - r_factor_metric: 1.0467
# Epoch 11/100
# 1/1 [==============================] - 0s 8ms/step - loss: 0.0275 - r_factor_metric: 1.0412
# Epoch 12/100
# 1/1 [==============================] - 0s 7ms/step - loss: 0.0273 - r_factor_metric: 1.0388
# Epoch 13/100
# 1/1 [==============================] - 0s 7ms/step - loss: 0.0272 - r_factor_metric: 1.0376
# Epoch 14/100
# 1/1 [==============================] - 0s 5ms/step - loss: 0.0271 - r_factor_metric: 1.0372
# Epoch 15/100
# 1/1 [==============================] - 0s 10ms/step - loss: 0.0271 - r_factor_metric: 1.0369
# Epoch 16/100
# 1/1 [==============================] - 0s 7ms/step - loss: 0.0270 - r_factor_metric: 1.0365
# Epoch 17/100
# 1/1 [==============================] - 0s 7ms/step - loss: 0.0270 - r_factor_metric: 1.0359
# Epoch 18/100
# 1/1 [==============================] - 0s 6ms/step - loss: 0.0269 - r_factor_metric: 1.0351
# Epoch 19/100
# 1/1 [==============================] - 0s 6ms/step - loss: 0.0269 - r_factor_metric: 1.0340
# Epoch 20/100
# 1/1 [==============================] - 0s 8ms/step - loss: 0.0268 - r_factor_metric: 1.0324
# Epoch 21/100
# 1/1 [==============================] - 0s 6ms/step - loss: 0.0267 - r_factor_metric: 1.0304
# Epoch 22/100
# 1/1 [==============================] - 0s 7ms/step - loss: 0.0266 - r_factor_metric: 1.0281
# Epoch 23/100
# 1/1 [==============================] - 0s 8ms/step - loss: 0.0265 - r_factor_metric: 1.0255
# Epoch 24/100
# 1/1 [==============================] - 0s 7ms/step - loss: 0.0264 - r_factor_metric: 1.0225
# Epoch 25/100
# 1/1 [==============================] - 0s 7ms/step - loss: 0.0263 - r_factor_metric: 1.0197
# Epoch 26/100
# 1/1 [==============================] - 0s 7ms/step - loss: 0.0263 - r_factor_metric: 1.0173
# Epoch 27/100
# 1/1 [==============================] - 0s 6ms/step - loss: 0.0262 - r_factor_metric: 1.0155
# Epoch 28/100
# 1/1 [==============================] - 0s 7ms/step - loss: 0.0261 - r_factor_metric: 1.0141
# Epoch 29/100
# 1/1 [==============================] - 0s 8ms/step - loss: 0.0260 - r_factor_metric: 1.0129
# Epoch 30/100
# 1/1 [==============================] - 0s 7ms/step - loss: 0.0260 - r_factor_metric: 1.0116
# Epoch 31/100
# 1/1 [==============================] - 0s 7ms/step - loss: 0.0259 - r_factor_metric: 1.0102
# Epoch 32/100
# 1/1 [==============================] - 0s 7ms/step - loss: 0.0259 - r_factor_metric: 1.0090
# Epoch 33/100
# 1/1 [==============================] - 0s 7ms/step - loss: 0.0258 - r_factor_metric: 1.0079
# Epoch 34/100
# 1/1 [==============================] - 0s 8ms/step - loss: 0.0258 - r_factor_metric: 1.0068
# Epoch 35/100
# 1/1 [==============================] - 0s 7ms/step - loss: 0.0258 - r_factor_metric: 1.0058
# Epoch 36/100
# 1/1 [==============================] - 0s 8ms/step - loss: 0.0258 - r_factor_metric: 1.0051
# Epoch 37/100
# 1/1 [==============================] - 0s 6ms/step - loss: 0.0258 - r_factor_metric: 1.0045
# Epoch 38/100
# 1/1 [==============================] - 0s 7ms/step - loss: 0.0257 - r_factor_metric: 1.0040
# Epoch 39/100
# 1/1 [==============================] - 0s 8ms/step - loss: 0.0257 - r_factor_metric: 1.0035
# Epoch 40/100
# 1/1 [==============================] - 0s 7ms/step - loss: 0.0257 - r_factor_metric: 1.0029
# Epoch 41/100
# 1/1 [==============================] - 0s 7ms/step - loss: 0.0257 - r_factor_metric: 1.0025
# Epoch 42/100
# 1/1 [==============================] - 0s 5ms/step - loss: 0.0257 - r_factor_metric: 1.0020
# Epoch 43/100
# 1/1 [==============================] - 0s 6ms/step - loss: 0.0257 - r_factor_metric: 1.0015
# Epoch 44/100
# 1/1 [==============================] - 0s 8ms/step - loss: 0.0256 - r_factor_metric: 1.0008
# Epoch 45/100
# 1/1 [==============================] - 0s 7ms/step - loss: 0.0256 - r_factor_metric: 0.9992
# Epoch 46/100
# 1/1 [==============================] - 0s 6ms/step - loss: 0.0255 - r_factor_metric: 0.9973
# Epoch 47/100
# 1/1 [==============================] - 0s 7ms/step - loss: 0.0254 - r_factor_metric: 0.9953
# Epoch 48/100
# 1/1 [==============================] - 0s 6ms/step - loss: 0.0253 - r_factor_metric: 0.9933
# Epoch 49/100
# 1/1 [==============================] - 0s 8ms/step - loss: 0.0252 - r_factor_metric: 0.9912
# Epoch 50/100
# 1/1 [==============================] - 0s 6ms/step - loss: 0.0251 - r_factor_metric: 0.9890
# Epoch 51/100
# 1/1 [==============================] - 0s 7ms/step - loss: 0.0250 - r_factor_metric: 0.9868
# Epoch 52/100
# 1/1 [==============================] - 0s 6ms/step - loss: 0.0249 - r_factor_metric: 0.9848
# Epoch 53/100
# 1/1 [==============================] - 0s 5ms/step - loss: 0.0248 - r_factor_metric: 0.9830
# Epoch 54/100
# 1/1 [==============================] - 0s 8ms/step - loss: 0.0247 - r_factor_metric: 0.9813
# Epoch 55/100
# 1/1 [==============================] - 0s 6ms/step - loss: 0.0247 - r_factor_metric: 0.9799
# Epoch 56/100
# 1/1 [==============================] - 0s 8ms/step - loss: 0.0246 - r_factor_metric: 0.9785
# Epoch 57/100
# 1/1 [==============================] - 0s 7ms/step - loss: 0.0245 - r_factor_metric: 0.9773
# Epoch 58/100
# 1/1 [==============================] - 0s 7ms/step - loss: 0.0245 - r_factor_metric: 0.9761
# Epoch 59/100
# 1/1 [==============================] - 0s 6ms/step - loss: 0.0244 - r_factor_metric: 0.9750
# Epoch 60/100
# 1/1 [==============================] - 0s 9ms/step - loss: 0.0244 - r_factor_metric: 0.9740
# Epoch 61/100
# 1/1 [==============================] - 0s 6ms/step - loss: 0.0243 - r_factor_metric: 0.9730
# Epoch 62/100
# 1/1 [==============================] - 0s 6ms/step - loss: 0.0243 - r_factor_metric: 0.9720
# Epoch 63/100
# 1/1 [==============================] - 0s 7ms/step - loss: 0.0243 - r_factor_metric: 0.9712
# Epoch 64/100
# 1/1 [==============================] - 0s 6ms/step - loss: 0.0242 - r_factor_metric: 0.9704
# Epoch 65/100
# 1/1 [==============================] - 0s 6ms/step - loss: 0.0242 - r_factor_metric: 0.9696
# Epoch 66/100
# 1/1 [==============================] - 0s 7ms/step - loss: 0.0242 - r_factor_metric: 0.9689
# Epoch 67/100
# 1/1 [==============================] - 0s 6ms/step - loss: 0.0241 - r_factor_metric: 0.9682
# Epoch 68/100
# 1/1 [==============================] - 0s 8ms/step - loss: 0.0241 - r_factor_metric: 0.9676
# Epoch 69/100
# 1/1 [==============================] - 0s 8ms/step - loss: 0.0241 - r_factor_metric: 0.9670
# Epoch 70/100
# 1/1 [==============================] - 0s 8ms/step - loss: 0.0240 - r_factor_metric: 0.9665
# Epoch 71/100
# 1/1 [==============================] - 0s 8ms/step - loss: 0.0240 - r_factor_metric: 0.9661
# Epoch 72/100
# 1/1 [==============================] - 0s 36ms/step - loss: 0.0240 - r_factor_metric: 0.9656
# Epoch 73/100
# 1/1 [==============================] - 0s 24ms/step - loss: 0.0240 - r_factor_metric: 0.9652
# Epoch 74/100
# 1/1 [==============================] - 0s 7ms/step - loss: 0.0240 - r_factor_metric: 0.9649
# Epoch 75/100
# 1/1 [==============================] - 0s 6ms/step - loss: 0.0239 - r_factor_metric: 0.9645
# Epoch 76/100
# 1/1 [==============================] - 0s 7ms/step - loss: 0.0239 - r_factor_metric: 0.9642
# Epoch 77/100
# 1/1 [==============================] - 0s 10ms/step - loss: 0.0239 - r_factor_metric: 0.9638
# Epoch 78/100
# 1/1 [==============================] - 0s 7ms/step - loss: 0.0239 - r_factor_metric: 0.9635
# Epoch 79/100
# 1/1 [==============================] - 0s 7ms/step - loss: 0.0239 - r_factor_metric: 0.9632
# Epoch 80/100
# 1/1 [==============================] - 0s 9ms/step - loss: 0.0239 - r_factor_metric: 0.9629
# Epoch 81/100
# 1/1 [==============================] - 0s 7ms/step - loss: 0.0238 - r_factor_metric: 0.9627
# Epoch 82/100
# 1/1 [==============================] - 0s 8ms/step - loss: 0.0238 - r_factor_metric: 0.9624
# Epoch 83/100
# 1/1 [==============================] - 0s 8ms/step - loss: 0.0238 - r_factor_metric: 0.9621
# Epoch 84/100
# 1/1 [==============================] - 0s 7ms/step - loss: 0.0238 - r_factor_metric: 0.9618
# Epoch 85/100
# 1/1 [==============================] - 0s 9ms/step - loss: 0.0238 - r_factor_metric: 0.9615
# Epoch 86/100
# 1/1 [==============================] - 0s 7ms/step - loss: 0.0238 - r_factor_metric: 0.9613
# Epoch 87/100
# 1/1 [==============================] - 0s 8ms/step - loss: 0.0238 - r_factor_metric: 0.9610
# Epoch 88/100
# 1/1 [==============================] - 0s 8ms/step - loss: 0.0238 - r_factor_metric: 0.9607
# Epoch 89/100
# 1/1 [==============================] - 0s 7ms/step - loss: 0.0237 - r_factor_metric: 0.9605
# Epoch 90/100
# 1/1 [==============================] - 0s 7ms/step - loss: 0.0237 - r_factor_metric: 0.9603
# Epoch 91/100
# 1/1 [==============================] - 0s 6ms/step - loss: 0.0237 - r_factor_metric: 0.9600
# Epoch 92/100
# 1/1 [==============================] - 0s 9ms/step - loss: 0.0237 - r_factor_metric: 0.9598
# Epoch 93/100
# 1/1 [==============================] - 0s 8ms/step - loss: 0.0237 - r_factor_metric: 0.9596
# Epoch 94/100
# 1/1 [==============================] - 0s 7ms/step - loss: 0.0237 - r_factor_metric: 0.9594
# Epoch 95/100
# 1/1 [==============================] - 0s 7ms/step - loss: 0.0237 - r_factor_metric: 0.9592
# Epoch 96/100
# 1/1 [==============================] - 0s 7ms/step - loss: 0.0237 - r_factor_metric: 0.9590
# Epoch 97/100
# 1/1 [==============================] - 0s 7ms/step - loss: 0.0237 - r_factor_metric: 0.9589
# Epoch 98/100
# 1/1 [==============================] - 0s 7ms/step - loss: 0.0237 - r_factor_metric: 0.9587
# Epoch 99/100
# 1/1 [==============================] - 0s 7ms/step - loss: 0.0237 - r_factor_metric: 0.9585
# Epoch 100/100
# 1/1 [==============================] - 0s 9ms/step - loss: 0.0236 - r_factor_metric: 0.9584
# (7,)
# Final loss: 2.365e-02
# Shape of atom_shift_list: 7
# Shape of sf_combined: (None,), Shape of x_combined: (None, 3)
# Epoch 1/100
# Shape of atom_shift_list: 7
# Shape of sf_combined: (910,), Shape of x_combined: (910, 3)
# Shape of atom_shift_list: 7
# Shape of sf_combined: (910,), Shape of x_combined: (910, 3)
# 1/1 [==============================] - 2s 2s/step - loss: 0.0369 - r_factor_metric: 1.2698
# Epoch 2/100
# 1/1 [==============================] - 0s 6ms/step - loss: 0.0361 - r_factor_metric: 1.2564
# Epoch 3/100
# 1/1 [==============================] - 0s 7ms/step - loss: 0.0352 - r_factor_metric: 1.2375
# Epoch 4/100
# 1/1 [==============================] - 0s 5ms/step - loss: 0.0342 - r_factor_metric: 1.2126
# Epoch 5/100
# 1/1 [==============================] - 0s 8ms/step - loss: 0.0329 - r_factor_metric: 1.1825
# Epoch 6/100
# 1/1 [==============================] - 0s 7ms/step - loss: 0.0316 - r_factor_metric: 1.1490
# Epoch 7/100
# 1/1 [==============================] - 0s 9ms/step - loss: 0.0303 - r_factor_metric: 1.1158
# Epoch 8/100
# 1/1 [==============================] - 0s 6ms/step - loss: 0.0291 - r_factor_metric: 1.0850
# Epoch 9/100
# 1/1 [==============================] - 0s 7ms/step - loss: 0.0282 - r_factor_metric: 1.0570
# Epoch 10/100
# 1/1 [==============================] - 0s 7ms/step - loss: 0.0274 - r_factor_metric: 1.0316
# Epoch 11/100
# 1/1 [==============================] - 0s 7ms/step - loss: 0.0270 - r_factor_metric: 1.0156
# Epoch 12/100
# 1/1 [==============================] - 0s 7ms/step - loss: 0.0268 - r_factor_metric: 1.0102
# Epoch 13/100
# 1/1 [==============================] - 0s 7ms/step - loss: 0.0262 - r_factor_metric: 1.0026
# Epoch 14/100
# 1/1 [==============================] - 0s 6ms/step - loss: 0.0255 - r_factor_metric: 0.9932
# Epoch 15/100
# 1/1 [==============================] - 0s 8ms/step - loss: 0.0250 - r_factor_metric: 0.9892
# Epoch 16/100
# 1/1 [==============================] - 0s 7ms/step - loss: 0.0248 - r_factor_metric: 0.9903
# Epoch 17/100
# 1/1 [==============================] - 0s 7ms/step - loss: 0.0247 - r_factor_metric: 0.9934
# Epoch 18/100
# 1/1 [==============================] - 0s 8ms/step - loss: 0.0247 - r_factor_metric: 0.9963
# Epoch 19/100
# 1/1 [==============================] - 0s 8ms/step - loss: 0.0247 - r_factor_metric: 0.9986
# Epoch 20/100
# 1/1 [==============================] - 0s 5ms/step - loss: 0.0247 - r_factor_metric: 0.9996
# Epoch 21/100
# 1/1 [==============================] - 0s 7ms/step - loss: 0.0247 - r_factor_metric: 0.9994
# Epoch 22/100
# 1/1 [==============================] - 0s 6ms/step - loss: 0.0247 - r_factor_metric: 0.9988
# Epoch 23/100
# 1/1 [==============================] - 0s 9ms/step - loss: 0.0247 - r_factor_metric: 0.9979
# Epoch 24/100
# 1/1 [==============================] - 0s 8ms/step - loss: 0.0247 - r_factor_metric: 0.9969
# Epoch 25/100
# 1/1 [==============================] - 0s 8ms/step - loss: 0.0247 - r_factor_metric: 0.9957
# Epoch 26/100
# 1/1 [==============================] - 0s 7ms/step - loss: 0.0247 - r_factor_metric: 0.9943
# Epoch 27/100
# 1/1 [==============================] - 0s 8ms/step - loss: 0.0247 - r_factor_metric: 0.9928
# Epoch 28/100
# 1/1 [==============================] - 0s 7ms/step - loss: 0.0246 - r_factor_metric: 0.9917
# Epoch 29/100
# 1/1 [==============================] - 0s 7ms/step - loss: 0.0246 - r_factor_metric: 0.9906
# Epoch 30/100
# 1/1 [==============================] - 0s 7ms/step - loss: 0.0246 - r_factor_metric: 0.9899
# Epoch 31/100
# 1/1 [==============================] - 0s 6ms/step - loss: 0.0245 - r_factor_metric: 0.9892
# Epoch 32/100
# 1/1 [==============================] - 0s 8ms/step - loss: 0.0245 - r_factor_metric: 0.9886
# Epoch 33/100
# 1/1 [==============================] - 0s 6ms/step - loss: 0.0245 - r_factor_metric: 0.9880
# Epoch 34/100
# 1/1 [==============================] - 0s 7ms/step - loss: 0.0245 - r_factor_metric: 0.9874
# Epoch 35/100
# 1/1 [==============================] - 0s 7ms/step - loss: 0.0245 - r_factor_metric: 0.9868
# Epoch 36/100
# 1/1 [==============================] - 0s 6ms/step - loss: 0.0244 - r_factor_metric: 0.9864
# Epoch 37/100
# 1/1 [==============================] - 0s 9ms/step - loss: 0.0244 - r_factor_metric: 0.9860
# Epoch 38/100
# 1/1 [==============================] - 0s 6ms/step - loss: 0.0244 - r_factor_metric: 0.9855
# Epoch 39/100
# 1/1 [==============================] - 0s 7ms/step - loss: 0.0244 - r_factor_metric: 0.9851
# Epoch 40/100
# 1/1 [==============================] - 0s 8ms/step - loss: 0.0244 - r_factor_metric: 0.9846
# Epoch 41/100
# 1/1 [==============================] - 0s 8ms/step - loss: 0.0244 - r_factor_metric: 0.9841
# Epoch 42/100
# 1/1 [==============================] - 0s 7ms/step - loss: 0.0243 - r_factor_metric: 0.9836
# Epoch 43/100
# 1/1 [==============================] - 0s 7ms/step - loss: 0.0243 - r_factor_metric: 0.9832
# Epoch 44/100
# 1/1 [==============================] - 0s 6ms/step - loss: 0.0243 - r_factor_metric: 0.9829
# Epoch 45/100
# 1/1 [==============================] - 0s 6ms/step - loss: 0.0243 - r_factor_metric: 0.9825
# Epoch 46/100
# 1/1 [==============================] - 0s 7ms/step - loss: 0.0243 - r_factor_metric: 0.9821
# Epoch 47/100
# 1/1 [==============================] - 0s 7ms/step - loss: 0.0243 - r_factor_metric: 0.9817
# Epoch 48/100
# 1/1 [==============================] - 0s 6ms/step - loss: 0.0243 - r_factor_metric: 0.9812
# Epoch 49/100
# 1/1 [==============================] - 0s 7ms/step - loss: 0.0242 - r_factor_metric: 0.9807
# Epoch 50/100
# 1/1 [==============================] - 0s 6ms/step - loss: 0.0242 - r_factor_metric: 0.9801
# Epoch 51/100
# 1/1 [==============================] - 0s 7ms/step - loss: 0.0242 - r_factor_metric: 0.9795
# Epoch 52/100
# 1/1 [==============================] - 0s 8ms/step - loss: 0.0242 - r_factor_metric: 0.9788
# Epoch 53/100
# 1/1 [==============================] - 0s 8ms/step - loss: 0.0242 - r_factor_metric: 0.9781
# Epoch 54/100
# 1/1 [==============================] - 0s 8ms/step - loss: 0.0242 - r_factor_metric: 0.9774
# Epoch 55/100
# 1/1 [==============================] - 0s 7ms/step - loss: 0.0242 - r_factor_metric: 0.9767
# Epoch 56/100
# 1/1 [==============================] - 0s 7ms/step - loss: 0.0241 - r_factor_metric: 0.9760
# Epoch 57/100
# 1/1 [==============================] - 0s 9ms/step - loss: 0.0241 - r_factor_metric: 0.9753
# Epoch 58/100
# 1/1 [==============================] - 0s 6ms/step - loss: 0.0241 - r_factor_metric: 0.9746
# Epoch 59/100
# 1/1 [==============================] - 0s 8ms/step - loss: 0.0241 - r_factor_metric: 0.9739
# Epoch 60/100
# 1/1 [==============================] - 0s 6ms/step - loss: 0.0241 - r_factor_metric: 0.9733
# Epoch 61/100
# 1/1 [==============================] - 0s 7ms/step - loss: 0.0241 - r_factor_metric: 0.9726
# Epoch 62/100
# 1/1 [==============================] - 0s 6ms/step - loss: 0.0241 - r_factor_metric: 0.9719
# Epoch 63/100
# 1/1 [==============================] - 0s 6ms/step - loss: 0.0240 - r_factor_metric: 0.9713
# Epoch 64/100
# 1/1 [==============================] - 0s 8ms/step - loss: 0.0240 - r_factor_metric: 0.9708
# Epoch 65/100
# 1/1 [==============================] - 0s 6ms/step - loss: 0.0240 - r_factor_metric: 0.9703
# Epoch 66/100
# 1/1 [==============================] - 0s 8ms/step - loss: 0.0240 - r_factor_metric: 0.9699
# Epoch 67/100
# 1/1 [==============================] - 0s 8ms/step - loss: 0.0240 - r_factor_metric: 0.9696
# Epoch 68/100
# 1/1 [==============================] - 0s 6ms/step - loss: 0.0240 - r_factor_metric: 0.9692
# Epoch 69/100
# 1/1 [==============================] - 0s 7ms/step - loss: 0.0240 - r_factor_metric: 0.9689
# Epoch 70/100
# 1/1 [==============================] - 0s 6ms/step - loss: 0.0240 - r_factor_metric: 0.9685
# Epoch 71/100
# 1/1 [==============================] - 0s 8ms/step - loss: 0.0240 - r_factor_metric: 0.9682
# Epoch 72/100
# 1/1 [==============================] - 0s 6ms/step - loss: 0.0239 - r_factor_metric: 0.9679
# Epoch 73/100
# 1/1 [==============================] - 0s 7ms/step - loss: 0.0239 - r_factor_metric: 0.9676
# Epoch 74/100
# 1/1 [==============================] - 0s 6ms/step - loss: 0.0239 - r_factor_metric: 0.9672
# Epoch 75/100
# 1/1 [==============================] - 0s 6ms/step - loss: 0.0239 - r_factor_metric: 0.9669
# Epoch 76/100
# 1/1 [==============================] - 0s 6ms/step - loss: 0.0239 - r_factor_metric: 0.9666
# Epoch 77/100
# 1/1 [==============================] - 0s 8ms/step - loss: 0.0239 - r_factor_metric: 0.9663
# Epoch 78/100
# 1/1 [==============================] - 0s 6ms/step - loss: 0.0239 - r_factor_metric: 0.9660
# Epoch 79/100
# 1/1 [==============================] - 0s 7ms/step - loss: 0.0239 - r_factor_metric: 0.9658
# Epoch 80/100
# 1/1 [==============================] - 0s 7ms/step - loss: 0.0239 - r_factor_metric: 0.9656
# Epoch 81/100
# 1/1 [==============================] - 0s 7ms/step - loss: 0.0239 - r_factor_metric: 0.9654
# Epoch 82/100
# 1/1 [==============================] - 0s 6ms/step - loss: 0.0239 - r_factor_metric: 0.9652
# Epoch 83/100
# 1/1 [==============================] - 0s 8ms/step - loss: 0.0239 - r_factor_metric: 0.9651
# Epoch 84/100
# 1/1 [==============================] - 0s 7ms/step - loss: 0.0239 - r_factor_metric: 0.9649
# Epoch 85/100
# 1/1 [==============================] - 0s 9ms/step - loss: 0.0239 - r_factor_metric: 0.9648
# Epoch 86/100
# 1/1 [==============================] - 0s 6ms/step - loss: 0.0239 - r_factor_metric: 0.9647
# Epoch 87/100
# 1/1 [==============================] - 0s 161ms/step - loss: 0.0239 - r_factor_metric: 0.9646
# Epoch 88/100
# 1/1 [==============================] - 0s 8ms/step - loss: 0.0239 - r_factor_metric: 0.9645
# Epoch 89/100
# 1/1 [==============================] - 0s 14ms/step - loss: 0.0238 - r_factor_metric: 0.9645
# Epoch 90/100
# 1/1 [==============================] - 0s 8ms/step - loss: 0.0238 - r_factor_metric: 0.9644
# Epoch 91/100
# 1/1 [==============================] - 0s 10ms/step - loss: 0.0238 - r_factor_metric: 0.9644
# Epoch 92/100
# 1/1 [==============================] - 0s 10ms/step - loss: 0.0238 - r_factor_metric: 0.9643
# Epoch 93/100
# 1/1 [==============================] - 0s 7ms/step - loss: 0.0238 - r_factor_metric: 0.9642
# Epoch 94/100
# 1/1 [==============================] - 0s 9ms/step - loss: 0.0238 - r_factor_metric: 0.9642
# Epoch 95/100
# 1/1 [==============================] - 0s 9ms/step - loss: 0.0238 - r_factor_metric: 0.9641
# Epoch 96/100
# 1/1 [==============================] - 0s 6ms/step - loss: 0.0238 - r_factor_metric: 0.9641
# Epoch 97/100
# 1/1 [==============================] - 0s 8ms/step - loss: 0.0238 - r_factor_metric: 0.9641
# Epoch 98/100
# 1/1 [==============================] - 0s 10ms/step - loss: 0.0238 - r_factor_metric: 0.9640
# Epoch 99/100
# 1/1 [==============================] - 0s 7ms/step - loss: 0.0238 - r_factor_metric: 0.9640
# Epoch 100/100
# 1/1 [==============================] - 0s 9ms/step - loss: 0.0238 - r_factor_metric: 0.9640
# (7,)
# Final loss: 2.380e-02
# Shape of atom_shift_list: 7
# Shape of sf_combined: (None,), Shape of x_combined: (None, 3)
# Epoch 1/100
# Shape of atom_shift_list: 7
# Shape of sf_combined: (910,), Shape of x_combined: (910, 3)
# Shape of atom_shift_list: 7
# Shape of sf_combined: (910,), Shape of x_combined: (910, 3)
# 1/1 [==============================] - 2s 2s/step - loss: 0.0396 - r_factor_metric: 1.2780
# Epoch 2/100
# 1/1 [==============================] - 0s 5ms/step - loss: 0.0384 - r_factor_metric: 1.2521
# Epoch 3/100
# 1/1 [==============================] - 0s 6ms/step - loss: 0.0372 - r_factor_metric: 1.2222
# Epoch 4/100
# 1/1 [==============================] - 0s 6ms/step - loss: 0.0361 - r_factor_metric: 1.1957
# Epoch 5/100
# 1/1 [==============================] - 0s 6ms/step - loss: 0.0353 - r_factor_metric: 1.1753
# Epoch 6/100
# 1/1 [==============================] - 0s 7ms/step - loss: 0.0339 - r_factor_metric: 1.1493
# Epoch 7/100
# 1/1 [==============================] - 0s 6ms/step - loss: 0.0320 - r_factor_metric: 1.1182
# Epoch 8/100
# 1/1 [==============================] - 0s 7ms/step - loss: 0.0304 - r_factor_metric: 1.0914
# Epoch 9/100
# 1/1 [==============================] - 0s 7ms/step - loss: 0.0292 - r_factor_metric: 1.0688
# Epoch 10/100
# 1/1 [==============================] - 0s 6ms/step - loss: 0.0283 - r_factor_metric: 1.0516
# Epoch 11/100
# 1/1 [==============================] - 0s 7ms/step - loss: 0.0277 - r_factor_metric: 1.0404
# Epoch 12/100
# 1/1 [==============================] - 0s 8ms/step - loss: 0.0273 - r_factor_metric: 1.0331
# Epoch 13/100
# 1/1 [==============================] - 0s 7ms/step - loss: 0.0270 - r_factor_metric: 1.0283
# Epoch 14/100
# 1/1 [==============================] - 0s 7ms/step - loss: 0.0269 - r_factor_metric: 1.0260
# Epoch 15/100
# 1/1 [==============================] - 0s 7ms/step - loss: 0.0268 - r_factor_metric: 1.0254
# Epoch 16/100
# 1/1 [==============================] - 0s 6ms/step - loss: 0.0268 - r_factor_metric: 1.0260
# Epoch 17/100
# 1/1 [==============================] - 0s 6ms/step - loss: 0.0269 - r_factor_metric: 1.0277
# Epoch 18/100
# 1/1 [==============================] - 0s 7ms/step - loss: 0.0269 - r_factor_metric: 1.0299
# Epoch 19/100
# 1/1 [==============================] - 0s 8ms/step - loss: 0.0270 - r_factor_metric: 1.0320
# Epoch 20/100
# 1/1 [==============================] - 0s 7ms/step - loss: 0.0270 - r_factor_metric: 1.0334
# Epoch 21/100
# 1/1 [==============================] - 0s 7ms/step - loss: 0.0270 - r_factor_metric: 1.0343
# Epoch 22/100
# 1/1 [==============================] - 0s 8ms/step - loss: 0.0271 - r_factor_metric: 1.0347
# Epoch 23/100
# 1/1 [==============================] - 0s 6ms/step - loss: 0.0271 - r_factor_metric: 1.0343
# Epoch 24/100
# 1/1 [==============================] - 0s 8ms/step - loss: 0.0270 - r_factor_metric: 1.0335
# Epoch 25/100
# 1/1 [==============================] - 0s 6ms/step - loss: 0.0270 - r_factor_metric: 1.0327
# Epoch 26/100
# 1/1 [==============================] - 0s 7ms/step - loss: 0.0270 - r_factor_metric: 1.0318
# Epoch 27/100
# 1/1 [==============================] - 0s 7ms/step - loss: 0.0269 - r_factor_metric: 1.0305
# Epoch 28/100
# 1/1 [==============================] - 0s 7ms/step - loss: 0.0269 - r_factor_metric: 1.0291
# Epoch 29/100
# 1/1 [==============================] - 0s 6ms/step - loss: 0.0268 - r_factor_metric: 1.0276
# Epoch 30/100
# 1/1 [==============================] - 0s 8ms/step - loss: 0.0267 - r_factor_metric: 1.0260
# Epoch 31/100
# 1/1 [==============================] - 0s 6ms/step - loss: 0.0267 - r_factor_metric: 1.0242
# Epoch 32/100
# 1/1 [==============================] - 0s 7ms/step - loss: 0.0266 - r_factor_metric: 1.0224
# Epoch 33/100
# 1/1 [==============================] - 0s 8ms/step - loss: 0.0266 - r_factor_metric: 1.0210
# Epoch 34/100
# 1/1 [==============================] - 0s 6ms/step - loss: 0.0266 - r_factor_metric: 1.0199
# Epoch 35/100
# 1/1 [==============================] - 0s 7ms/step - loss: 0.0266 - r_factor_metric: 1.0189
# Epoch 36/100
# 1/1 [==============================] - 0s 6ms/step - loss: 0.0266 - r_factor_metric: 1.0183
# Epoch 37/100
# 1/1 [==============================] - 0s 6ms/step - loss: 0.0265 - r_factor_metric: 1.0179
# Epoch 38/100
# 1/1 [==============================] - 0s 8ms/step - loss: 0.0265 - r_factor_metric: 1.0177
# Epoch 39/100
# 1/1 [==============================] - 0s 8ms/step - loss: 0.0265 - r_factor_metric: 1.0179
# Epoch 40/100
# 1/1 [==============================] - 0s 9ms/step - loss: 0.0265 - r_factor_metric: 1.0182
# Epoch 41/100
# 1/1 [==============================] - 0s 8ms/step - loss: 0.0265 - r_factor_metric: 1.0184
# Epoch 42/100
# 1/1 [==============================] - 0s 8ms/step - loss: 0.0265 - r_factor_metric: 1.0186
# Epoch 43/100
# 1/1 [==============================] - 0s 8ms/step - loss: 0.0266 - r_factor_metric: 1.0188
# Epoch 44/100
# 1/1 [==============================] - 0s 87ms/step - loss: 0.0266 - r_factor_metric: 1.0189
# Epoch 45/100
# 1/1 [==============================] - 0s 7ms/step - loss: 0.0265 - r_factor_metric: 1.0189
# Epoch 46/100
# 1/1 [==============================] - 0s 8ms/step - loss: 0.0265 - r_factor_metric: 1.0189
# Epoch 47/100
# 1/1 [==============================] - 0s 7ms/step - loss: 0.0265 - r_factor_metric: 1.0188
# Epoch 48/100
# 1/1 [==============================] - 0s 10ms/step - loss: 0.0265 - r_factor_metric: 1.0186
# Epoch 49/100
# 1/1 [==============================] - 0s 8ms/step - loss: 0.0265 - r_factor_metric: 1.0184
# Epoch 50/100
# 1/1 [==============================] - 0s 8ms/step - loss: 0.0265 - r_factor_metric: 1.0182
# Epoch 51/100
# 1/1 [==============================] - 0s 9ms/step - loss: 0.0265 - r_factor_metric: 1.0180
# Epoch 52/100
# 1/1 [==============================] - 0s 8ms/step - loss: 0.0265 - r_factor_metric: 1.0178
# Epoch 53/100
# 1/1 [==============================] - 0s 8ms/step - loss: 0.0265 - r_factor_metric: 1.0176
# Epoch 54/100
# 1/1 [==============================] - 0s 8ms/step - loss: 0.0265 - r_factor_metric: 1.0175
# Epoch 55/100
# 1/1 [==============================] - 0s 7ms/step - loss: 0.0265 - r_factor_metric: 1.0174
# Epoch 56/100
# 1/1 [==============================] - 0s 8ms/step - loss: 0.0265 - r_factor_metric: 1.0172
# Epoch 57/100
# 1/1 [==============================] - 0s 8ms/step - loss: 0.0265 - r_factor_metric: 1.0171
# Epoch 58/100
# 1/1 [==============================] - 0s 8ms/step - loss: 0.0265 - r_factor_metric: 1.0170
# Epoch 59/100
# 1/1 [==============================] - 0s 7ms/step - loss: 0.0265 - r_factor_metric: 1.0169
# Epoch 60/100
# 1/1 [==============================] - 0s 18ms/step - loss: 0.0265 - r_factor_metric: 1.0168
# Epoch 61/100
# 1/1 [==============================] - 0s 54ms/step - loss: 0.0265 - r_factor_metric: 1.0167
# Epoch 62/100
# 1/1 [==============================] - 0s 7ms/step - loss: 0.0264 - r_factor_metric: 1.0166
# Epoch 63/100
# 1/1 [==============================] - 0s 7ms/step - loss: 0.0264 - r_factor_metric: 1.0165
# Epoch 64/100
# 1/1 [==============================] - 0s 10ms/step - loss: 0.0264 - r_factor_metric: 1.0164
# Epoch 65/100
# 1/1 [==============================] - 0s 7ms/step - loss: 0.0264 - r_factor_metric: 1.0163
# Epoch 66/100
# 1/1 [==============================] - 0s 9ms/step - loss: 0.0264 - r_factor_metric: 1.0162
# Epoch 67/100
# 1/1 [==============================] - 0s 7ms/step - loss: 0.0264 - r_factor_metric: 1.0161
# Epoch 68/100
# 1/1 [==============================] - 0s 7ms/step - loss: 0.0264 - r_factor_metric: 1.0160
# Epoch 69/100
# 1/1 [==============================] - 0s 8ms/step - loss: 0.0264 - r_factor_metric: 1.0159
# Epoch 70/100
# 1/1 [==============================] - 0s 7ms/step - loss: 0.0264 - r_factor_metric: 1.0158
# Epoch 71/100
# 1/1 [==============================] - 0s 8ms/step - loss: 0.0264 - r_factor_metric: 1.0157
# Epoch 72/100
# 1/1 [==============================] - 0s 6ms/step - loss: 0.0264 - r_factor_metric: 1.0157
# Epoch 73/100
# 1/1 [==============================] - 0s 9ms/step - loss: 0.0264 - r_factor_metric: 1.0156
# Epoch 74/100
# 1/1 [==============================] - 0s 7ms/step - loss: 0.0264 - r_factor_metric: 1.0155
# Epoch 75/100
# 1/1 [==============================] - 0s 8ms/step - loss: 0.0264 - r_factor_metric: 1.0154
# Epoch 76/100
# 1/1 [==============================] - 0s 8ms/step - loss: 0.0264 - r_factor_metric: 1.0152
# Epoch 77/100
# 1/1 [==============================] - 0s 8ms/step - loss: 0.0264 - r_factor_metric: 1.0151
# Epoch 78/100
# 1/1 [==============================] - 0s 7ms/step - loss: 0.0264 - r_factor_metric: 1.0150
# Epoch 79/100
# 1/1 [==============================] - 0s 8ms/step - loss: 0.0264 - r_factor_metric: 1.0148
# Epoch 80/100
# 1/1 [==============================] - 0s 7ms/step - loss: 0.0264 - r_factor_metric: 1.0147
# Epoch 81/100
# 1/1 [==============================] - 0s 7ms/step - loss: 0.0264 - r_factor_metric: 1.0145
# Epoch 82/100
# 1/1 [==============================] - 0s 7ms/step - loss: 0.0264 - r_factor_metric: 1.0144
# Epoch 83/100
# 1/1 [==============================] - 0s 7ms/step - loss: 0.0263 - r_factor_metric: 1.0142
# Epoch 84/100
# 1/1 [==============================] - 0s 7ms/step - loss: 0.0263 - r_factor_metric: 1.0140
# Epoch 85/100
# 1/1 [==============================] - 0s 9ms/step - loss: 0.0263 - r_factor_metric: 1.0138
# Epoch 86/100
# 1/1 [==============================] - 0s 6ms/step - loss: 0.0263 - r_factor_metric: 1.0135
# Epoch 87/100
# 1/1 [==============================] - 0s 8ms/step - loss: 0.0263 - r_factor_metric: 1.0132
# Epoch 88/100
# 1/1 [==============================] - 0s 6ms/step - loss: 0.0263 - r_factor_metric: 1.0130
# Epoch 89/100
# 1/1 [==============================] - 0s 7ms/step - loss: 0.0263 - r_factor_metric: 1.0127
# Epoch 90/100
# 1/1 [==============================] - 0s 7ms/step - loss: 0.0263 - r_factor_metric: 1.0124
# Epoch 91/100
# 1/1 [==============================] - 0s 7ms/step - loss: 0.0263 - r_factor_metric: 1.0122
# Epoch 92/100
# 1/1 [==============================] - 0s 8ms/step - loss: 0.0263 - r_factor_metric: 1.0119
# Epoch 93/100
# 1/1 [==============================] - 0s 7ms/step - loss: 0.0263 - r_factor_metric: 1.0116
# Epoch 94/100
# 1/1 [==============================] - 0s 8ms/step - loss: 0.0263 - r_factor_metric: 1.0114
# Epoch 95/100
# 1/1 [==============================] - 0s 7ms/step - loss: 0.0263 - r_factor_metric: 1.0112
# Epoch 96/100
# 1/1 [==============================] - 0s 7ms/step - loss: 0.0263 - r_factor_metric: 1.0111
# Epoch 97/100
# 1/1 [==============================] - 0s 8ms/step - loss: 0.0263 - r_factor_metric: 1.0109
# Epoch 98/100
# 1/1 [==============================] - 0s 7ms/step - loss: 0.0263 - r_factor_metric: 1.0108
# Epoch 99/100
# 1/1 [==============================] - 0s 8ms/step - loss: 0.0263 - r_factor_metric: 1.0106
# Epoch 100/100
# 1/1 [==============================] - 0s 10ms/step - loss: 0.0263 - r_factor_metric: 1.0104
# (7,)
# Final loss: 2.626e-02
# Shape of atom_shift_list: 7
# Shape of sf_combined: (None,), Shape of x_combined: (None, 3)
# Epoch 1/100
# Shape of atom_shift_list: 7
# Shape of sf_combined: (910,), Shape of x_combined: (910, 3)
# Shape of atom_shift_list: 7
# Shape of sf_combined: (910,), Shape of x_combined: (910, 3)
# 1/1 [==============================] - 2s 2s/step - loss: 0.0516 - r_factor_metric: 1.5371
# Epoch 2/100
# 1/1 [==============================] - 0s 5ms/step - loss: 0.0458 - r_factor_metric: 1.4284
# Epoch 3/100
# 1/1 [==============================] - 0s 6ms/step - loss: 0.0402 - r_factor_metric: 1.3118
# Epoch 4/100
# 1/1 [==============================] - 0s 6ms/step - loss: 0.0361 - r_factor_metric: 1.2160
# Epoch 5/100
# 1/1 [==============================] - 0s 6ms/step - loss: 0.0333 - r_factor_metric: 1.1568
# Epoch 6/100
# 1/1 [==============================] - 0s 7ms/step - loss: 0.0317 - r_factor_metric: 1.1259
# Epoch 7/100
# 1/1 [==============================] - 0s 7ms/step - loss: 0.0308 - r_factor_metric: 1.1167
# Epoch 8/100
# 1/1 [==============================] - 0s 7ms/step - loss: 0.0303 - r_factor_metric: 1.1141
# Epoch 9/100
# 1/1 [==============================] - 0s 7ms/step - loss: 0.0301 - r_factor_metric: 1.1126
# Epoch 10/100
# 1/1 [==============================] - 0s 9ms/step - loss: 0.0301 - r_factor_metric: 1.1155
# Epoch 11/100
# 1/1 [==============================] - 0s 7ms/step - loss: 0.0300 - r_factor_metric: 1.1182
# Epoch 12/100
# 1/1 [==============================] - 0s 8ms/step - loss: 0.0299 - r_factor_metric: 1.1181
# Epoch 13/100
# 1/1 [==============================] - 0s 8ms/step - loss: 0.0298 - r_factor_metric: 1.1172
# Epoch 14/100
# 1/1 [==============================] - 0s 7ms/step - loss: 0.0296 - r_factor_metric: 1.1147
# Epoch 15/100
# 1/1 [==============================] - 0s 7ms/step - loss: 0.0294 - r_factor_metric: 1.1106
# Epoch 16/100
# 1/1 [==============================] - 0s 6ms/step - loss: 0.0292 - r_factor_metric: 1.1058
# Epoch 17/100
# 1/1 [==============================] - 0s 7ms/step - loss: 0.0290 - r_factor_metric: 1.1005
# Epoch 18/100
# 1/1 [==============================] - 0s 6ms/step - loss: 0.0287 - r_factor_metric: 1.0944
# Epoch 19/100
# 1/1 [==============================] - 0s 29ms/step - loss: 0.0285 - r_factor_metric: 1.0879
# Epoch 20/100
# 1/1 [==============================] - 0s 16ms/step - loss: 0.0283 - r_factor_metric: 1.0809
# Epoch 21/100
# 1/1 [==============================] - 0s 9ms/step - loss: 0.0281 - r_factor_metric: 1.0739
# Epoch 22/100
# 1/1 [==============================] - 0s 10ms/step - loss: 0.0279 - r_factor_metric: 1.0673
# Epoch 23/100
# 1/1 [==============================] - 0s 9ms/step - loss: 0.0278 - r_factor_metric: 1.0627
# Epoch 24/100
# 1/1 [==============================] - 0s 8ms/step - loss: 0.0276 - r_factor_metric: 1.0586
# Epoch 25/100
# 1/1 [==============================] - 0s 8ms/step - loss: 0.0276 - r_factor_metric: 1.0551
# Epoch 26/100
# 1/1 [==============================] - 0s 14ms/step - loss: 0.0275 - r_factor_metric: 1.0523
# Epoch 27/100
# 1/1 [==============================] - 0s 8ms/step - loss: 0.0275 - r_factor_metric: 1.0497
# Epoch 28/100
# 1/1 [==============================] - 0s 8ms/step - loss: 0.0274 - r_factor_metric: 1.0474
# Epoch 29/100
# 1/1 [==============================] - 0s 8ms/step - loss: 0.0274 - r_factor_metric: 1.0459
# Epoch 30/100
# 1/1 [==============================] - 0s 7ms/step - loss: 0.0274 - r_factor_metric: 1.0447
# Epoch 31/100
# 1/1 [==============================] - 0s 6ms/step - loss: 0.0273 - r_factor_metric: 1.0437
# Epoch 32/100
# 1/1 [==============================] - 0s 7ms/step - loss: 0.0273 - r_factor_metric: 1.0427
# Epoch 33/100
# 1/1 [==============================] - 0s 6ms/step - loss: 0.0273 - r_factor_metric: 1.0418
# Epoch 34/100
# 1/1 [==============================] - 0s 9ms/step - loss: 0.0272 - r_factor_metric: 1.0408
# Epoch 35/100
# 1/1 [==============================] - 0s 10ms/step - loss: 0.0272 - r_factor_metric: 1.0397
# Epoch 36/100
# 1/1 [==============================] - 0s 7ms/step - loss: 0.0271 - r_factor_metric: 1.0387
# Epoch 37/100
# 1/1 [==============================] - 0s 10ms/step - loss: 0.0271 - r_factor_metric: 1.0376
# Epoch 38/100
# 1/1 [==============================] - 0s 121ms/step - loss: 0.0270 - r_factor_metric: 1.0367
# Epoch 39/100
# 1/1 [==============================] - 0s 7ms/step - loss: 0.0270 - r_factor_metric: 1.0357
# Epoch 40/100
# 1/1 [==============================] - 0s 8ms/step - loss: 0.0270 - r_factor_metric: 1.0348
# Epoch 41/100
# 1/1 [==============================] - 0s 8ms/step - loss: 0.0269 - r_factor_metric: 1.0338
# Epoch 42/100
# ...
# Epoch 53/100
# 1/1 [==============================] - 0s 7ms/step - loss: 0.0224 - r_factor_metric: 0.9754
# Epoch 54/100
# 1/1 [==============================] - 0s 11ms/step - loss: 0.0224 - r_factor_metric: 0.9759
# Epoch 55/100
# 1/1 [==============================] - 0s 7ms/step - loss: 0.0224 - r_factor_metric: 0.9769
# Epoch 56/100
# 1/1 [==============================] - 0s 9ms/step - loss: 0.0224 - r_factor_metric: 0.9780
# Epoch 57/100
# 1/1 [==============================] - 0s 10ms/step - loss: 0.0224 - r_factor_metric: 0.9790
# Epoch 58/100
# 1/1 [==============================] - 0s 8ms/step - loss: 0.0224 - r_factor_metric: 0.9800
# Epoch 59/100
# 1/1 [==============================] - 0s 7ms/step - loss: 0.0224 - r_factor_metric: 0.9809
# Epoch 60/100
# 1/1 [==============================] - 0s 9ms/step - loss: 0.0224 - r_factor_metric: 0.9814
# Epoch 61/100
# 1/1 [==============================] - 0s 7ms/step - loss: 0.0224 - r_factor_metric: 0.9817
# Epoch 62/100
# 1/1 [==============================] - 0s 66ms/step - loss: 0.0224 - r_factor_metric: 0.9817
# Epoch 63/100
# 1/1 [==============================] - 0s 7ms/step - loss: 0.0224 - r_factor_metric: 0.9814
# Epoch 64/100
# 1/1 [==============================] - 0s 9ms/step - loss: 0.0224 - r_factor_metric: 0.9810
# Epoch 65/100
# 1/1 [==============================] - 0s 12ms/step - loss: 0.0224 - r_factor_metric: 0.9805
# Epoch 66/100
# 1/1 [==============================] - 0s 7ms/step - loss: 0.0224 - r_factor_metric: 0.9800
# Epoch 67/100
# 1/1 [==============================] - 0s 6ms/step - loss: 0.0223 - r_factor_metric: 0.9796
# Epoch 68/100
# 1/1 [==============================] - 0s 7ms/step - loss: 0.0223 - r_factor_metric: 0.9793
# Epoch 69/100
# 1/1 [==============================] - 0s 9ms/step - loss: 0.0223 - r_factor_metric: 0.9790
# Epoch 70/100
# 1/1 [==============================] - 0s 7ms/step - loss: 0.0223 - r_factor_metric: 0.9788
# Epoch 71/100
# 1/1 [==============================] - 0s 11ms/step - loss: 0.0223 - r_factor_metric: 0.9787
# Epoch 72/100
# 1/1 [==============================] - 0s 8ms/step - loss: 0.0223 - r_factor_metric: 0.9786
# Epoch 73/100
# 1/1 [==============================] - 0s 8ms/step - loss: 0.0223 - r_factor_metric: 0.9786
# Epoch 74/100
# 1/1 [==============================] - 0s 113ms/step - loss: 0.0223 - r_factor_metric: 0.9787
# Epoch 75/100
# 1/1 [==============================] - 0s 7ms/step - loss: 0.0223 - r_factor_metric: 0.9787
# Epoch 76/100
# 1/1 [==============================] - 0s 9ms/step - loss: 0.0223 - r_factor_metric: 0.9787
# Epoch 77/100
# 1/1 [==============================] - 0s 9ms/step - loss: 0.0223 - r_factor_metric: 0.9787
# Epoch 78/100
# 1/1 [==============================] - 0s 8ms/step - loss: 0.0223 - r_factor_metric: 0.9787
# Epoch 79/100
# 1/1 [==============================] - 0s 10ms/step - loss: 0.0223 - r_factor_metric: 0.9787
# Epoch 80/100
# 1/1 [==============================] - 0s 9ms/step - loss: 0.0223 - r_factor_metric: 0.9787
# Epoch 81/100
# 1/1 [==============================] - 0s 8ms/step - loss: 0.0223 - r_factor_metric: 0.9787
# Epoch 82/100
# 1/1 [==============================] - 0s 11ms/step - loss: 0.0223 - r_factor_metric: 0.9788
# Epoch 83/100
# 1/1 [==============================] - 0s 8ms/step - loss: 0.0223 - r_factor_metric: 0.9789
# Epoch 84/100
# 1/1 [==============================] - 0s 8ms/step - loss: 0.0223 - r_factor_metric: 0.9790
# Epoch 85/100
# 1/1 [==============================] - 0s 8ms/step - loss: 0.0223 - r_factor_metric: 0.9791
# Epoch 86/100
# 1/1 [==============================] - 0s 8ms/step - loss: 0.0223 - r_factor_metric: 0.9792
# Epoch 87/100
# 1/1 [==============================] - 0s 8ms/step - loss: 0.0223 - r_factor_metric: 0.9793
# Epoch 88/100
# 1/1 [==============================] - 0s 8ms/step - loss: 0.0223 - r_factor_metric: 0.9794
# Epoch 89/100
# 1/1 [==============================] - 0s 10ms/step - loss: 0.0223 - r_factor_metric: 0.9794
# Epoch 90/100
# 1/1 [==============================] - 0s 7ms/step - loss: 0.0223 - r_factor_metric: 0.9794
# Epoch 91/100
# 1/1 [==============================] - 0s 13ms/step - loss: 0.0223 - r_factor_metric: 0.9794
# Epoch 92/100
# 1/1 [==============================] - 0s 8ms/step - loss: 0.0223 - r_factor_metric: 0.9793
# Epoch 93/100
# 1/1 [==============================] - 0s 8ms/step - loss: 0.0223 - r_factor_metric: 0.9792
# Epoch 94/100
# 1/1 [==============================] - 0s 8ms/step - loss: 0.0223 - r_factor_metric: 0.9790
# Epoch 95/100
# 1/1 [==============================] - 0s 6ms/step - loss: 0.0223 - r_factor_metric: 0.9789
# Epoch 96/100
# 1/1 [==============================] - 0s 10ms/step - loss: 0.0223 - r_factor_metric: 0.9788
# Epoch 97/100
# 1/1 [==============================] - 0s 9ms/step - loss: 0.0223 - r_factor_metric: 0.9788
# Epoch 98/100
# 1/1 [==============================] - 0s 8ms/step - loss: 0.0223 - r_factor_metric: 0.9788
# Epoch 99/100
# 1/1 [==============================] - 0s 7ms/step - loss: 0.0223 - r_factor_metric: 0.9788
# Epoch 100/100
# 1/1 [==============================] - 0s 8ms/step - loss: 0.0223 - r_factor_metric: 0.9788
# (7,)
# Final loss: 2.234e-02
# Shape of atom_shift_list: 7
# Shape of sf_combined: (None,), Shape of x_combined: (None, 3)
# Epoch 1/100
# Shape of atom_shift_list: 7
# Shape of sf_combined: (910,), Shape of x_combined: (910, 3)
# Shape of atom_shift_list: 7
# Shape of sf_combined: (910,), Shape of x_combined: (910, 3)
# 1/1 [==============================] - 3s 3s/step - loss: 0.0683 - r_factor_metric: 1.8132
# Epoch 2/100
# 1/1 [==============================] - 0s 4ms/step - loss: 0.0580 - r_factor_metric: 1.6567
# Epoch 3/100
# 1/1 [==============================] - 0s 6ms/step - loss: 0.0427 - r_factor_metric: 1.4009
# Epoch 4/100
# 1/1 [==============================] - 0s 6ms/step - loss: 0.0368 - r_factor_metric: 1.2582
# Epoch 5/100
# 1/1 [==============================] - 0s 6ms/step - loss: 0.0343 - r_factor_metric: 1.2134
# Epoch 6/100
# 1/1 [==============================] - 0s 6ms/step - loss: 0.0329 - r_factor_metric: 1.2167
# Epoch 7/100
# 1/1 [==============================] - 0s 6ms/step - loss: 0.0322 - r_factor_metric: 1.2289
# Epoch 8/100
# 1/1 [==============================] - 0s 7ms/step - loss: 0.0316 - r_factor_metric: 1.2339
# Epoch 9/100
# 1/1 [==============================] - 0s 8ms/step - loss: 0.0309 - r_factor_metric: 1.2277
# Epoch 10/100
# 1/1 [==============================] - 0s 9ms/step - loss: 0.0302 - r_factor_metric: 1.2133
# Epoch 11/100
# 1/1 [==============================] - 0s 8ms/step - loss: 0.0293 - r_factor_metric: 1.1946
# Epoch 12/100
# 1/1 [==============================] - 0s 7ms/step - loss: 0.0285 - r_factor_metric: 1.1738
# Epoch 13/100
# 1/1 [==============================] - 0s 10ms/step - loss: 0.0277 - r_factor_metric: 1.1529
# Epoch 14/100
# 1/1 [==============================] - 0s 10ms/step - loss: 0.0270 - r_factor_metric: 1.1330
# Epoch 15/100
# 1/1 [==============================] - 0s 7ms/step - loss: 0.0263 - r_factor_metric: 1.1150
# Epoch 16/100
# 1/1 [==============================] - 0s 7ms/step - loss: 0.0258 - r_factor_metric: 1.0986
# Epoch 17/100
# 1/1 [==============================] - 0s 6ms/step - loss: 0.0252 - r_factor_metric: 1.0827
# Epoch 18/100
# 1/1 [==============================] - 0s 8ms/step - loss: 0.0247 - r_factor_metric: 1.0674
# Epoch 19/100
# 1/1 [==============================] - 0s 7ms/step - loss: 0.0243 - r_factor_metric: 1.0526
# Epoch 20/100
# 1/1 [==============================] - 0s 4ms/step - loss: 0.0239 - r_factor_metric: 1.0386
# Epoch 21/100
# 1/1 [==============================] - 0s 8ms/step - loss: 0.0236 - r_factor_metric: 1.0255
# Epoch 22/100
# 1/1 [==============================] - 0s 6ms/step - loss: 0.0233 - r_factor_metric: 1.0130
# Epoch 23/100
# 1/1 [==============================] - 0s 7ms/step - loss: 0.0230 - r_factor_metric: 1.0009
# Epoch 24/100
# 1/1 [==============================] - 0s 19ms/step - loss: 0.0227 - r_factor_metric: 0.9892
# Epoch 25/100
# 1/1 [==============================] - 0s 163ms/step - loss: 0.0225 - r_factor_metric: 0.9784
# Epoch 26/100
# 1/1 [==============================] - 0s 9ms/step - loss: 0.0223 - r_factor_metric: 0.9687
# Epoch 27/100
# 1/1 [==============================] - 0s 9ms/step - loss: 0.0221 - r_factor_metric: 0.9597
# Epoch 28/100
# 1/1 [==============================] - 0s 10ms/step - loss: 0.0219 - r_factor_metric: 0.9518
# Epoch 29/100
# 1/1 [==============================] - 0s 10ms/step - loss: 0.0218 - r_factor_metric: 0.9445
# Epoch 30/100
# 1/1 [==============================] - 0s 8ms/step - loss: 0.0216 - r_factor_metric: 0.9378
# Epoch 31/100
# 1/1 [==============================] - 0s 10ms/step - loss: 0.0215 - r_factor_metric: 0.9330
# Epoch 32/100
# 1/1 [==============================] - 0s 9ms/step - loss: 0.0215 - r_factor_metric: 0.9290
# Epoch 33/100
# 1/1 [==============================] - 0s 8ms/step - loss: 0.0214 - r_factor_metric: 0.9262
# Epoch 34/100
# 1/1 [==============================] - 0s 9ms/step - loss: 0.0214 - r_factor_metric: 0.9249
# Epoch 35/100
# 1/1 [==============================] - 0s 7ms/step - loss: 0.0214 - r_factor_metric: 0.9248
# Epoch 36/100
# 1/1 [==============================] - 0s 7ms/step - loss: 0.0214 - r_factor_metric: 0.9253
# Epoch 37/100
# 1/1 [==============================] - 0s 9ms/step - loss: 0.0214 - r_factor_metric: 0.9257
# Epoch 38/100
# 1/1 [==============================] - 0s 8ms/step - loss: 0.0214 - r_factor_metric: 0.9259
# Epoch 39/100
# 1/1 [==============================] - 0s 6ms/step - loss: 0.0214 - r_factor_metric: 0.9257
# Epoch 40/100
# 1/1 [==============================] - 0s 7ms/step - loss: 0.0214 - r_factor_metric: 0.9254
# Epoch 41/100
# 1/1 [==============================] - 0s 7ms/step - loss: 0.0214 - r_factor_metric: 0.9250
# Epoch 42/100
# 1/1 [==============================] - 0s 9ms/step - loss: 0.0214 - r_factor_metric: 0.9248
# Epoch 43/100
# 1/1 [==============================] - 0s 6ms/step - loss: 0.0214 - r_factor_metric: 0.9248
# Epoch 44/100
# 1/1 [==============================] - 0s 8ms/step - loss: 0.0214 - r_factor_metric: 0.9250
# Epoch 45/100
# 1/1 [==============================] - 0s 8ms/step - loss: 0.0214 - r_factor_metric: 0.9253
# Epoch 46/100
# 1/1 [==============================] - 0s 9ms/step - loss: 0.0214 - r_factor_metric: 0.9256
# Epoch 47/100
# 1/1 [==============================] - 0s 9ms/step - loss: 0.0214 - r_factor_metric: 0.9258
# Epoch 48/100
# 1/1 [==============================] - 0s 40ms/step - loss: 0.0214 - r_factor_metric: 0.9258
# Epoch 49/100
# 1/1 [==============================] - 0s 35ms/step - loss: 0.0214 - r_factor_metric: 0.9258
# Epoch 50/100
# 1/1 [==============================] - 0s 9ms/step - loss: 0.0214 - r_factor_metric: 0.9257
# Epoch 51/100
# 1/1 [==============================] - 0s 7ms/step - loss: 0.0213 - r_factor_metric: 0.9257
# Epoch 52/100
# 1/1 [==============================] - 0s 8ms/step - loss: 0.0213 - r_factor_metric: 0.9258
# Epoch 53/100
# 1/1 [==============================] - 0s 8ms/step - loss: 0.0213 - r_factor_metric: 0.9260
# Epoch 54/100
# 1/1 [==============================] - 0s 8ms/step - loss: 0.0213 - r_factor_metric: 0.9263
# Epoch 55/100
# 1/1 [==============================] - 0s 9ms/step - loss: 0.0213 - r_factor_metric: 0.9266
# Epoch 56/100
# 1/1 [==============================] - 0s 6ms/step - loss: 0.0213 - r_factor_metric: 0.9270
# Epoch 57/100
# 1/1 [==============================] - 0s 7ms/step - loss: 0.0213 - r_factor_metric: 0.9275
# Epoch 58/100
# 1/1 [==============================] - 0s 9ms/step - loss: 0.0213 - r_factor_metric: 0.9279
# Epoch 59/100
# 1/1 [==============================] - 0s 9ms/step - loss: 0.0213 - r_factor_metric: 0.9283
# Epoch 60/100
# 1/1 [==============================] - 0s 128ms/step - loss: 0.0213 - r_factor_metric: 0.9285
# Epoch 61/100
# 1/1 [==============================] - 0s 7ms/step - loss: 0.0213 - r_factor_metric: 0.9287
# Epoch 62/100
# 1/1 [==============================] - 0s 7ms/step - loss: 0.0213 - r_factor_metric: 0.9288
# Epoch 63/100
# 1/1 [==============================] - 0s 12ms/step - loss: 0.0213 - r_factor_metric: 0.9288
# Epoch 64/100
# 1/1 [==============================] - 0s 11ms/step - loss: 0.0213 - r_factor_metric: 0.9287
# Epoch 65/100
# 1/1 [==============================] - 0s 10ms/step - loss: 0.0213 - r_factor_metric: 0.9287
# Epoch 66/100
# 1/1 [==============================] - 0s 10ms/step - loss: 0.0213 - r_factor_metric: 0.9286
# Epoch 67/100
# 1/1 [==============================] - 0s 8ms/step - loss: 0.0213 - r_factor_metric: 0.9285
# Epoch 68/100
# 1/1 [==============================] - 0s 10ms/step - loss: 0.0213 - r_factor_metric: 0.9285
# Epoch 69/100
# 1/1 [==============================] - 0s 9ms/step - loss: 0.0213 - r_factor_metric: 0.9284
# Epoch 70/100
# 1/1 [==============================] - 0s 8ms/step - loss: 0.0213 - r_factor_metric: 0.9282
# Epoch 71/100
# 1/1 [==============================] - 0s 8ms/step - loss: 0.0213 - r_factor_metric: 0.9281
# Epoch 72/100
# 1/1 [==============================] - 0s 8ms/step - loss: 0.0213 - r_factor_metric: 0.9279
# Epoch 73/100
# 1/1 [==============================] - 0s 9ms/step - loss: 0.0213 - r_factor_metric: 0.9278
# Epoch 74/100
# 1/1 [==============================] - 0s 10ms/step - loss: 0.0213 - r_factor_metric: 0.9276
# Epoch 75/100
# 1/1 [==============================] - 0s 9ms/step - loss: 0.0213 - r_factor_metric: 0.9275
# Epoch 76/100
# 1/1 [==============================] - 0s 12ms/step - loss: 0.0213 - r_factor_metric: 0.9273
# Epoch 77/100
# 1/1 [==============================] - 0s 8ms/step - loss: 0.0213 - r_factor_metric: 0.9272
# Epoch 78/100
# 1/1 [==============================] - 0s 8ms/step - loss: 0.0213 - r_factor_metric: 0.9271
# Epoch 79/100
# 1/1 [==============================] - 0s 6ms/step - loss: 0.0213 - r_factor_metric: 0.9270
# Epoch 80/100
# 1/1 [==============================] - 0s 8ms/step - loss: 0.0213 - r_factor_metric: 0.9269
# Epoch 81/100
# 1/1 [==============================] - 0s 9ms/step - loss: 0.0213 - r_factor_metric: 0.9268
# Epoch 82/100
# 1/1 [==============================] - 0s 9ms/step - loss: 0.0213 - r_factor_metric: 0.9266
# Epoch 83/100
# 1/1 [==============================] - 0s 8ms/step - loss: 0.0213 - r_factor_metric: 0.9265
# Epoch 84/100
# 1/1 [==============================] - 0s 9ms/step - loss: 0.0213 - r_factor_metric: 0.9264
# Epoch 85/100
# 1/1 [==============================] - 0s 8ms/step - loss: 0.0213 - r_factor_metric: 0.9264
# Epoch 86/100
# 1/1 [==============================] - 0s 9ms/step - loss: 0.0213 - r_factor_metric: 0.9263
# Epoch 87/100
# 1/1 [==============================] - 0s 9ms/step - loss: 0.0213 - r_factor_metric: 0.9262
# Epoch 88/100
# 1/1 [==============================] - 0s 7ms/step - loss: 0.0213 - r_factor_metric: 0.9262
# Epoch 89/100
# 1/1 [==============================] - 0s 9ms/step - loss: 0.0213 - r_factor_metric: 0.9262
# Epoch 90/100
# 1/1 [==============================] - 0s 111ms/step - loss: 0.0213 - r_factor_metric: 0.9261
# Epoch 91/100
# 1/1 [==============================] - 0s 65ms/step - loss: 0.0213 - r_factor_metric: 0.9261
# Epoch 92/100
# 1/1 [==============================] - 0s 6ms/step - loss: 0.0213 - r_factor_metric: 0.9261
# Epoch 93/100
# 1/1 [==============================] - 0s 19ms/step - loss: 0.0213 - r_factor_metric: 0.9261
# Epoch 94/100
# 1/1 [==============================] - 0s 30ms/step - loss: 0.0213 - r_factor_metric: 0.9261
# Epoch 95/100
# 1/1 [==============================] - 0s 9ms/step - loss: 0.0213 - r_factor_metric: 0.9262
# Epoch 96/100
# 1/1 [==============================] - 0s 9ms/step - loss: 0.0213 - r_factor_metric: 0.9262
# Epoch 97/100
# 1/1 [==============================] - 0s 20ms/step - loss: 0.0213 - r_factor_metric: 0.9262
# Epoch 98/100
# 1/1 [==============================] - 0s 10ms/step - loss: 0.0213 - r_factor_metric: 0.9262
# Epoch 99/100
# 1/1 [==============================] - 0s 8ms/step - loss: 0.0213 - r_factor_metric: 0.9263
# Epoch 100/100
# 1/1 [==============================] - 0s 18ms/step - loss: 0.0213 - r_factor_metric: 0.9263
# (7,)
# Final loss: 2.130e-02
# time elapsed: 43.08 seconds
# With 23.212064271705756 iterations per second

# %%
all_losses = best_loss_overall
best_model_pars = best_pars_overall
min_loss = best_rf_overall

print(f"min loss: {min_loss}")


# Plotting the loss values
plt.figure(figsize=(10, 6))

# Plot the loss values for each iteration
for i, loss_values in enumerate(all_losses):
    plt.plot(loss_values, label=f'Iteration {i+1}')

plt.title('Loss vs Epochs')
plt.xlabel('Epochs')
plt.ylabel('Loss')
# plt.legend()
plt.grid(True)
plt.show()
# Out:
# min loss: 0.021240418776869774

# %%
mode_names = pd.read_csv('C:/Users/User/Desktop/uzh_intern/CrystalClearFit/alrisDistortionFit/PrNiO2/P3/raw_data/PrNiO2_displacivemode_names.txt' , delim_whitespace=True, header=None)
mode_names = mode_names.values.tolist()
mode_names = pd.DataFrame(mode_names)


# Print the best model parameters
print("Best model parameters:") 
for i, par in enumerate(best_model_pars):
    print(f"mode a{i+1} {mode_names.iloc[i, 0]} : {par.numpy():.8f}")
    
# Print the model summary
print("Number of iterations:", n_iter)
print("Number of features:", n_features)
model.summary()
#modes = get_mode_amplitudes_p63(*best_model_pars)
#print("Modes:")
##for key, val in modes.items():
    #print(f"{key}: {val*1000:.4f}")
# Out:
# Best model parameters:
# mode a1 [1/4,1/4,1/2]S1(a,0;a,0)[Pr1:d:dsp]A2u(a) : -0.18785222
# mode a2 [0,1/2,0]X1+(a;a)[Pr1:d:dsp]Eu(a) : 0.30026722
# mode a3 [1/4,1/4,1/2]S1(a,0;a,0)[O1:f:dsp]B3u(a) : 2.00258875
# mode a4 [1/4,1/4,1/2]S1(a,0;a,0)[O1:f:dsp]B2u(a) : 2.69743395
# mode a5 [1/2,1/2,0]M1+(a)[O1:f:dsp]B2u(a) : -3.66051197
# mode a6 [0,1/2,0]X1+(a;a)[O1:f:dsp]B2u(a) : -3.29296851
# mode a7 [1/4,1/4,1/2]S1(a,0;a,0)[Ni1:a:dsp]Eu(a) : 1.10260415
# Number of iterations: 10
# Number of features: 910
# Model: "model_64"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_65 (InputLayer)       [(None, 3)]               0
#
#  fun_as_layer_64 (FunAsLayer  (None,)                  7
#  )
#
# =================================================================
# Total params: 7
# Trainable params: 7
# Non-trainable params: 0
# _________________________________________________________________
# C:\Users\User\AppData\Local\Temp\ipykernel_21204\2346003310.py:1: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   mode_names = pd.read_csv('C:/Users/User/Desktop/uzh_intern/CrystalClearFit/alrisDistortionFit/PrNiO2/P3/raw_data/PrNiO2_displacivemode_names.txt' , delim_whitespace=True, header=None)

# %%
def plot_plane_sim_vs_exp(ax, df, l, norm_plane=False):
    exp_data_0 = df.loc[df['l'] == l].copy()
    if norm_plane:
        exp_data_0['intensity_sim'] = exp_data_0['intensity_sim'] / np.max(exp_data_0['intensity_sim'])
        exp_data_0['intensity_exp'] = exp_data_0['intensity_exp'] / np.max(exp_data_0['intensity_exp'])
    
    ax.scatter(exp_data_0['h'], -exp_data_0['k'], 
               s=exp_data_0['intensity_sim'] * 300, color='red', edgecolor="black",
               label='Sim', marker=MarkerStyle("o", fillstyle="left"))
    ax.scatter(exp_data_0['h'], -exp_data_0['k'], 
               s=exp_data_0['intensity_exp'] * 300, color='blue', edgecolor="black",
               label='Exp', marker=MarkerStyle("o", fillstyle="right"))
    
    ax.set_xlabel(f"h in (h, k, {l}) [r.l.u.]")
    ax.set_ylabel(f"k in (h, k, {l}) [r.l.u.]")
    ax.set_title(f"l = {l}")
    ax.legend()

# %%
exp_data = pd.read_csv('C:/Users/User/Desktop/uzh_intern/CrystalClearFit/alrisDistortionFit/PrNiO2/P3/raw_data/combined.csv')
exp_data['intensity_sim'] = fun_tf(features, best_model_pars).numpy()
# Out:
# Shape of atom_shift_list: 7
# Shape of sf_combined: (910,), Shape of x_combined: (910, 3)

# %%
# Prepare subplot grid
l_values = np.arange(0, 5, 0.5)
n = len(l_values)
ncols = int(np.ceil(n / 3))
fig, axs = plt.subplots(3, ncols, figsize=(6 * ncols, 12), constrained_layout=True)

# Flatten axs in case it's 2D array
axs = axs.flatten()

plt.style.use('default')


# Plot all subplots
for i, l in enumerate(l_values):
    plot_plane_sim_vs_exp(axs[i], exp_data, l, norm_plane=True)

plt.show()

# %%
#save the experiment data with simulated intensities
exp_data.to_csv('C:/Users/User/Desktop/uzh_intern/CrystalClearFit/alrisDistortionFit/PrNiO2/P3/fitted_data/PrNiO2_peaks_with_simulated_intensities.txt', index=False)

#save all the parameters and the modes
with open('C:/Users/User/Desktop/uzh_intern/CrystalClearFit/alrisDistortionFit/PrNiO2/P3/fitted_data/PrNiO2_parameters_and_modes.txt', 'w') as f:
    f.write(f"final loss: {min_loss:.8f}\n")
    f.write(f"learning_rate: {lr[0]:.8f}\n")
    f.write(f"n_epochs: {n_epochs}\n")
    f.write(f"Best model parameters:\n")
    for i, par in enumerate(best_model_pars):
        f.write(f"{mode_names.iloc[i, 0]} : {par.numpy():.8f} \n")

abs_params = tf.abs(best_model_pars)
best_model_pars_compare = best_model_pars.numpy()
best_model_pars_compare = best_model_pars_compare / np.max(best_model_pars_compare)

#save all the parameters and the modes
with open('C:/Users/User/Desktop/uzh_intern/CrystalClearFit/alrisDistortionFit/PrNiO2/P3/fitted_data/PrNiO2_parameters_and_modes_normalised.txt', 'w') as f:
    f.write(f"final loss: {min_loss:.8f}\n")
    f.write(f"learning_rate: {lr[0]:.8f}\n")
    f.write(f"n_epochs: {n_epochs}\n")
    f.write(f"Best model parameters:\n")
    for i, par in enumerate(best_model_pars_compare):
        f.write(f"{mode_names.iloc[i, 1]} : {par:.8f} \n")

# %%
best_data = pd.read_csv('C:/Users/User/Desktop/uzh_intern/CrystalClearFit/alrisDistortionFit/PrNiO2/P3/fitted_data/PrNiO2_peaks_with_simulated_intensities.txt')


# Prepare subplot grid
l_values = np.arange(0, 5, 0.5)
n = len(l_values)
ncols = int(np.ceil(n / 3))
fig, axs = plt.subplots(3, ncols, figsize=(6 * ncols, 12), constrained_layout=True)

# Flatten axs in case it's 2D array
axs = axs.flatten()

plt.style.use('default')


# Plot all subplots
for i, l in enumerate(l_values):
    plot_plane_sim_vs_exp(axs[i], best_data, l, norm_plane=True)

plt.show()
