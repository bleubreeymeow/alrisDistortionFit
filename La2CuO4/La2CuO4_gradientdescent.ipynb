# %% [markdown]
# # La2CuO4 version Fit modes

# %%
import numpy as np
import matplotlib.pyplot as plt
import tensorflow as tf
import pandas as pd
from La2CuO4_alris_functions2 import shift_atoms, transform_list_hkl_p63_p65, get_structure_factors , atom_position_list
from itertools import chain
from matplotlib.markers import MarkerStyle
from tqdm import tqdm
from time import time

# %config InlineBackend.figure_format = 'svg' # make figures appears in .svg style

num_threads = 2  

# Configure TensorFlow to use multiple threads
tf.config.threading.set_intra_op_parallelism_threads(num_threads)
tf.config.threading.set_inter_op_parallelism_threads(num_threads)

print(f"Using {num_threads} threads for intra-op and inter-op parallelism.")

num_of_params = 20
# Out:
# Using 2 threads for intra-op and inter-op parallelism.

# %% [markdown]
# Define the function containing the fitting parameters
#
# <span style="color:yellow">Note on actual unit cell structure refinement problem:</span>
# - `fun_tf()` correspond to the **structure factor calculation function** (one has to convert it to a **TF-compatible** function)
# - <span style="color:red">If conversion to TF-compatible function is not possible, then this approach will probably not work (or becomes much more tedious at least)</span>

# %%
#convert the simulated data to log10 scale (if needed)

def log10(x):
  numerator = tf.math.log(x)
  denominator = tf.math.log(tf.constant(10, dtype=numerator.dtype))
  return numerator / denominator

# %%
def fun_tf(x, pars):
    """
    Fast computation of structure factors with parameter-dependent structure.
        # Get modified structure
    modified_struct = shift_atoms_p65(*pars)
    neg_h = tf.stack([-x[:, 0], x[:, 1], x[:, 2]], axis=1)
    x_combined = tf.concat([x, neg_h], axis=0)  # Shape [2N, 3]

    x_combined = transform_list_hkl_p63_p65(x_combined)

    # Get structure factors
    sf_combined = get_structure_factors(x_combined, modified_struct)
    # Compute intensity
    # Split and compute intensity
    sf_hkl = sf_combined[:tf.shape(x)[0]]
    sf_neg_k = sf_combined[tf.shape(x)[0]:]
    
    intensity = (tf.abs(sf_hkl) + tf.abs(sf_neg_k)) ** 2
    return intensity / tf.reduce_max(intensity)
    """
    # Get modified structure
    atom_shift_list = shift_atoms(*pars)
    print(f"Shape of atom_shift_list: {len(atom_shift_list)}")



    # Flatten atom_shift_list if it contains nested lists
    flat_atom_shift_list = list(chain.from_iterable(
        x if isinstance(x, list) else [x] for x in atom_shift_list
    ))
    modified_struct = atom_position_list(*flat_atom_shift_list)

    #neg_h = tf.stack([-x[:, 0], x[:, 1], x[:, 2]], axis=1)
    x_combined = x
    #x_combined = tf.concat([x, neg_h], axis=0)  # Shape [2N, 3]

    #x_combined = transform_list_hkl_p63_p65(x_combined)

    # Get structure factors
    sf_combined = get_structure_factors(x_combined, modified_struct)
    # Compute intensity
    # Split and compute intensity
    sf_hkl = sf_combined[:tf.shape(x)[0]]
    
    print(f"Shape of sf_combined: {sf_combined.shape}, Shape of x_combined: {x_combined.shape}")
    
    intensity = (tf.abs(sf_hkl)) ** 2
    # w = tf.constant(0.00159, dtype=tf.float32)  # Debye-Waller factor is 0.00159
    w = tf.constant(0, dtype=tf.float32)  # Debye-Waller factor is 0.00159
    qnorms = tf.norm(tf.cast(x_combined[:tf.shape(x)[0]], tf.float32), axis=1)
    # qnorms = tf.reshape(qnorms, (-1, 1))  # Reshape to match the shape of intensity
    intensity = intensity * tf.exp(-w * qnorms ** 2)  # Apply Debye-Waller factor
    #intensity = log10(intensity + 1)  # Convert to log10 scale
    intensity_summed = tf.reduce_sum(intensity)  # Sum intensity for normalization
    intensity_unscaled = intensity  # Store unscaled intensity
    intensity_scaled = intensity  * 30 / intensity_summed
    return intensity_scaled , intensity_summed , intensity_unscaled

# %%
experimental_data = pd.read_csv('C:/Users/User/Desktop/uzh_intern/CrystalClearFit/alrisDistortionFit/La2CuO4/raw_data/peaks1.csv')
"""
# reduce data to l in [0.5, 1.5, 2.5, 3.5, 4.5 ]
experimental_data = experimental_data[
    (experimental_data["l"] == 0.5) |
    (experimental_data["l"] == 1.5) |
    (experimental_data["l"] == 2.5) |
    (experimental_data["l"] == 3.5) |
    (experimental_data["l"] == 4.5)
]
"""
hkl_list = experimental_data[["h", "k", "l"]].values.tolist()
hkl_list = tf.convert_to_tensor(hkl_list, dtype=tf.float32)
print(experimental_data.shape)
# Out:
# (67, 4)

# %% [markdown]
# Sample the "training data" (features and labels)
#
# <span style="color:yellow">Note on actual unit cell structure refinement problem:</span>
# - The features are the (h,k,l) coordinates (e.g. a vector of size `n_features` x 3, i.e. `n_dim = 3`)
# - Maybe one has to normalize the features (i.e. not using integers but floats between -1 (0) and 1)? Before passing them to the structure calculation function, they should be again rescaled to integers
# - The labels would be the experimental intensities (again, maybe have to be normalized to the range between 0 and 1)

# %%
n_features = experimental_data.shape[0]
n_dim = 3

features = hkl_list
labels = experimental_data["intensity_exp"].tolist()
labels = labels / np.sum(labels)  * 30# Normalize labels

labels_err = []
for label in labels:
    # labels_err.append(np.sqrt(0.8/label) - 1.5)
    labels_err.append(np.sqrt(0.8/label) - 1)


labels_err = tf.convert_to_tensor(labels_err, dtype=tf.float32)
labels = tf.convert_to_tensor(labels, dtype=tf.float32)

labels = tf.expand_dims(labels, axis=-1)  # Ensure labels are 2D
labels_err = tf.expand_dims(labels_err, axis=-1)  # Ensure labels_err are 2D

print("Max label err:", np.max(labels_err))
print("min label err:", np.min(labels_err))
print("Features shape:", features.shape)
print("Labels shape:", labels.shape)
print('error shape:', labels_err.shape)
print("Max label:", np.max(labels))
print("min label :", np.min(labels))
plt.hist(labels.numpy(), bins=50, alpha=0.5, label='Labels')
plt.hist(labels_err.numpy(), bins=50, alpha=0.5, label='Labels Error')
# Out:
# Max label err: 1.0229311
# min label err: -0.106198326
# Features shape: (67, 3)
# Labels shape: (67, 1)
# error shape: (67, 1)
# Max label: 1.0014001
# min label : 0.19549146
# (array([1., 0., 0., 0., 1., 1., 2., 1., 0., 1., 2., 1., 1., 1., 3., 4., 4.,
#         2., 3., 2., 3., 2., 4., 2., 0., 3., 4., 3., 2., 2., 0., 1., 1., 1.,
#         0., 4., 0., 1., 1., 0., 0., 1., 0., 0., 0., 1., 0., 0., 0., 1.]),
#  array([-0.10619833, -0.08361574, -0.06103315, -0.03845056, -0.01586797,
#          0.00671462,  0.0292972 ,  0.05187979,  0.07446238,  0.09704497,
#          0.11962756,  0.14221014,  0.16479273,  0.18737532,  0.20995791,
#          0.2325405 ,  0.25512308,  0.27770567,  0.30028826,  0.32287085,
#          0.34545344,  0.36803603,  0.39061862,  0.41320121,  0.4357838 ,
#          0.45836639,  0.48094898,  0.50353158,  0.52611417,  0.54869676,
#          0.57127935,  0.59386194,  0.61644453,  0.63902712,  0.66160971,
#          0.6841923 ,  0.70677483,  0.72935742,  0.75194001,  0.7745226 ,
#          0.79710519,  0.81968778,  0.84227037,  0.86485296,  0.88743556,
#          0.91001815,  0.93260074,  0.95518333,  0.97776592,  1.00034857,
#          1.0229311 ]),
#  <BarContainer object of 50 artists>)

# %% [markdown]
# Define a simple model
#
# <span style="color:yellow">Note on actual unit cell structure refinement problem:</span>
# - The six parameters (a,b,c,d,e,f) correspond to the fractional atomic shifts in the modes w.r.t. unit cell lengths
# - Instead of `sigmoid`, `tanh` should be applied to the parameters before passing them to the structure factor calculation function (ensures smoother gradient landscape)
# - The `tanh` function can furthermore be limited to a specific range (e.g. if atomic distortions should not exceed +- 0.1)

# %%
class FunAsLayer(tf.keras.layers.Layer):
    def __init__(self, max_mode_amps,**kwargs):
        super().__init__(**kwargs)
        self.max_mode_amps = max_mode_amps

    def build(self, input_shape):
        self.param = self.add_weight(name='param', shape=(num_of_params,), initializer=tf.keras.initializers.GlorotNormal(seed=1), trainable=True)
        super().build(input_shape)

    def call(self, inputs):
        # Apply tanh to ensure parameters stay within the [-1, 1] range then multiply by max_mode_amps so each parameter is scaled corresponding to the element in max_mode_amps
        pretransform = tf.tanh(self.param)
        transformed_params = pretransform * self.max_mode_amps  # Scale parameters

        output, intensity_summed  , intensity_unscaled = fun_tf(inputs, tf.unstack(transformed_params))
        return tf.reshape(output , [-1]) # Ensure output is 1D

# %% [markdown]
# Create optimizer and define loss function
#
# <span style="color:yellow">Note on actual unit cell structure refinement problem:</span>
# - The learning rate must be determined by experimentation (same holds for the batch size and the number of epochs below)
# - As a loss function, one can try either MSE or R-score (MSE seems to be the more "natural choice" in this case)

# %%
"""
# R-Score based on intensity
class RFactorLoss(tf.keras.losses.Loss):
    def call(self, y_true, y_pred):
        return tf.reduce_sum(tf.abs(y_true - y_pred)) / tf.reduce_sum(y_true)
"""
    
# mean squared error
class PerSampleMSE(tf.keras.losses.Loss):
    def __init__(self):
        super().__init__(reduction=tf.keras.losses.Reduction.NONE)

    def call(self, y_true, y_pred):
        squared_error = tf.square(y_true - y_pred)
        per_sample_mse = tf.reduce_mean(squared_error, axis=-1)
        return per_sample_mse  # shape (batch_size,)

class MSE_weighted(tf.keras.losses.Loss):
    def call(self, y_true, y_pred):
        # Assume y_true = [labels, errors]
        print('ytrue shape:', y_true.shape)
        print('y true' , y_true)
        labels = y_true[:, 0]
        weights = y_true[:, 1]

        mse = tf.square(labels - y_pred)
        return tf.reduce_sum(mse * weights) / tf.reduce_sum(weights)


# Define the custom metric function
def r_factor_metric(y_true, y_pred):
    labels = y_true
    return tf.reduce_sum(tf.abs(labels - y_pred)) / tf.reduce_sum(labels)

# %% [markdown]
# Train the model for n iterations (to try different initial weights)
#
# <span style="color:yellow">Note on actual unit cell structure refinement problem:</span>
# - The number of iterations defines the "starting position" $w_0$ of the gradient descent algorithm
# - Because there are probably many local minima, changing $w_0$ allows the algorithm to find different minima and increases the chances of finding the global minima

# %%
#squeeze labels and labels_err to ensure they are 1D tensors
#labels = tf.squeeze(labels)
#labels_err = tf.squeeze(labels_err)

print("labels shape:", labels.shape)
print("labels_err shape:", labels_err.shape)


lr = [1e-6]
best_pars_overall = None
best_rf_overall = np.inf
best_loss_overall = []
for learning_rate in lr:
    time_start = time()
    print(f"Learning rate: {learning_rate}")
    optim = tf.keras.optimizers.Adam(learning_rate=learning_rate)

    max_mode_amps = tf.constant([5.66,5.66,5.66,5.66,5.66,5.66,5.66,5.66,5.66,5.66,5.66,8.0,8.0,8.0,8.0,8.0,8.0,5.66,5.66,5.66], dtype=tf.float32) 
    print("max_mode_amps shape:", max_mode_amps.shape)

    n_epochs = 60
    histories = []
    n_iter = 5

    min_loss = np.inf
    best_pars = None

    # List to store the loss values for each epoch
    all_losses = []
    r_factor_list = []
    intensity_summed_list = []


    for i in range(n_iter):
        # Create the model
        inputs = tf.keras.Input(shape=(n_dim,))
        outputs = FunAsLayer(max_mode_amps)(inputs)
        model = tf.keras.Model(inputs, outputs)

        # Compile the model with the custom loss function and metric
        model.compile(
            optimizer=optim,
            loss= 'mse', # MSE_weighted() if using errors
            metrics=[r_factor_metric]

        )
        
        history = model.fit(
        x=features,
        y=labels,  # replace with combined_labels if using errors
        batch_size = features.shape[0], # Use a smaller batch size features.shape[0]
        epochs=n_epochs,
        verbose='auto',
        shuffle=True, # not sure whether this matters
        # callbacks=[cb]
        sample_weight=labels_err  # Use sample weights if you have errors
        )

        histories.append(history)
        all_losses.append(history.history['loss'])
 
        # Check final loss
        final_loss = history.history['loss'][-1]
        print(model.layers[-1].get_weights()[0].shape)
        curren_model_pars = max_mode_amps * tf.tanh(model.layers[-1].get_weights()[0])
        print(f"Final loss: {final_loss:.3e}")
        '''
        print(f"Best parameters for iteration {i+1}:")
        for j, par in enumerate(curren_model_pars):
            print(f"Parameter {j+1}: {par.numpy():.4f}")
        '''

        if final_loss < min_loss:
            # Update best model parameters
            best_model_pars = max_mode_amps * tf.tanh(model.layers[-1].get_weights()[0])
            min_loss = final_loss
            intensity_scaled , intensity_summed , intensity_unscaled= fun_tf(features, best_model_pars)
            rf = r_factor_metric(labels, intensity_scaled)
            #print(f"Iteration {i+1} - New best loss: {min_loss:.3e} (R-factor: {rf:.3e})")

    if min_loss < best_rf_overall:
        best_rf_overall = min_loss
        best_pars_overall = best_model_pars
        best_loss_overall = all_losses
        best_intensity_summed = intensity_summed
    print(f"time elapsed: {time() - time_start:.2f} seconds")
    print(f"With {n_epochs*n_iter /(time() - time_start)} iterations per second")
    # Plotting the loss values
    plt.figure(figsize=(10, 6))

    # Plot the loss values for each iteration
    for i, loss_values in enumerate(all_losses):
        plt.plot(loss_values, label=f'Iteration {i+1}')

    plt.title(f'Loss vs Epochs with Learning Rate {learning_rate}')
    plt.xlabel('Epochs')
    plt.ylabel('Loss')
    # plt.legend()
    plt.grid(True)
    plt.show()
# Out:
# labels shape: (67, 1)
# labels_err shape: (67, 1)
# Learning rate: 1e-06
# max_mode_amps shape: (20,)
# Shape of atom_shift_list: 156
# Shape of sf_combined: (None,), Shape of x_combined: (None, 3)
# Epoch 1/60
# Shape of atom_shift_list: 156
# Shape of sf_combined: (67,), Shape of x_combined: (67, 3)
# Shape of atom_shift_list: 156
# Shape of sf_combined: (67,), Shape of x_combined: (67, 3)
# 1/1 [==============================] - 8s 8s/step - loss: 0.1012 - r_factor_metric: 0.8538
# Epoch 2/60
# 1/1 [==============================] - 0s 32ms/step - loss: 0.0715 - r_factor_metric: 0.7171
# Epoch 3/60
# 1/1 [==============================] - 0s 31ms/step - loss: 0.2650 - r_factor_metric: 0.9548
# Epoch 4/60
# 1/1 [==============================] - 0s 33ms/step - loss: 0.1276 - r_factor_metric: 0.8981
# Epoch 5/60
# 1/1 [==============================] - 0s 33ms/step - loss: 0.0599 - r_factor_metric: 0.6442
# Epoch 6/60
# 1/1 [==============================] - 0s 32ms/step - loss: 0.1125 - r_factor_metric: 0.7854
# Epoch 7/60
# 1/1 [==============================] - 0s 34ms/step - loss: 0.0834 - r_factor_metric: 0.8218
# Epoch 8/60
# 1/1 [==============================] - 0s 33ms/step - loss: 0.2807 - r_factor_metric: 1.0460
# Epoch 9/60
# 1/1 [==============================] - 0s 34ms/step - loss: 0.1038 - r_factor_metric: 0.8644
# Epoch 10/60
# 1/1 [==============================] - 0s 34ms/step - loss: 0.1063 - r_factor_metric: 0.9079
# Epoch 11/60
# 1/1 [==============================] - 0s 32ms/step - loss: 0.1435 - r_factor_metric: 0.8666
# Epoch 12/60
# 1/1 [==============================] - 0s 33ms/step - loss: 0.1087 - r_factor_metric: 0.8950
# Epoch 13/60
# 1/1 [==============================] - 0s 33ms/step - loss: 0.0922 - r_factor_metric: 0.7671
# Epoch 14/60
# 1/1 [==============================] - 0s 34ms/step - loss: 0.0759 - r_factor_metric: 0.7891
# Epoch 15/60
# 1/1 [==============================] - 0s 33ms/step - loss: 0.0919 - r_factor_metric: 0.7833
# Epoch 16/60
# 1/1 [==============================] - 0s 34ms/step - loss: 0.0976 - r_factor_metric: 0.8559
# Epoch 17/60
# 1/1 [==============================] - 0s 33ms/step - loss: 0.0994 - r_factor_metric: 0.6932
# Epoch 18/60
# 1/1 [==============================] - 0s 32ms/step - loss: 0.1237 - r_factor_metric: 0.9517
# Epoch 19/60
# 1/1 [==============================] - 0s 34ms/step - loss: 0.1235 - r_factor_metric: 0.8701
# Epoch 20/60
# 1/1 [==============================] - 0s 33ms/step - loss: 0.1117 - r_factor_metric: 0.8334
# Epoch 21/60
# 1/1 [==============================] - 0s 34ms/step - loss: 0.1081 - r_factor_metric: 0.8446
# Epoch 22/60
# 1/1 [==============================] - 0s 33ms/step - loss: 0.0902 - r_factor_metric: 0.7782
# Epoch 23/60
# 1/1 [==============================] - 0s 35ms/step - loss: 0.0869 - r_factor_metric: 0.7617
# Epoch 24/60
# 1/1 [==============================] - 0s 33ms/step - loss: 0.1115 - r_factor_metric: 0.8268
# Epoch 25/60
# 1/1 [==============================] - 0s 32ms/step - loss: 0.0698 - r_factor_metric: 0.7554
# Epoch 26/60
# 1/1 [==============================] - 0s 31ms/step - loss: 0.0913 - r_factor_metric: 0.7657
# Epoch 27/60
# 1/1 [==============================] - 0s 32ms/step - loss: 0.1034 - r_factor_metric: 0.7970
# Epoch 28/60
# 1/1 [==============================] - 0s 33ms/step - loss: 0.1465 - r_factor_metric: 0.9303
# Epoch 29/60
# 1/1 [==============================] - 0s 33ms/step - loss: 0.1080 - r_factor_metric: 0.9020
# Epoch 30/60
# 1/1 [==============================] - 0s 32ms/step - loss: 0.1332 - r_factor_metric: 0.9012
# Epoch 31/60
# 1/1 [==============================] - 0s 34ms/step - loss: 0.1413 - r_factor_metric: 0.8296
# Epoch 32/60
# 1/1 [==============================] - 0s 34ms/step - loss: 0.0833 - r_factor_metric: 0.7520
# Epoch 33/60
# 1/1 [==============================] - 0s 32ms/step - loss: 0.0581 - r_factor_metric: 0.6503
# Epoch 34/60
# 1/1 [==============================] - 0s 32ms/step - loss: 0.1878 - r_factor_metric: 0.9817
# Epoch 35/60
# 1/1 [==============================] - 0s 32ms/step - loss: 0.1163 - r_factor_metric: 0.9057
# Epoch 36/60
# 1/1 [==============================] - 0s 35ms/step - loss: 0.1471 - r_factor_metric: 0.9201
# Epoch 37/60
# 1/1 [==============================] - 0s 33ms/step - loss: 0.1631 - r_factor_metric: 1.0143
# Epoch 38/60
# 1/1 [==============================] - 0s 33ms/step - loss: 0.1221 - r_factor_metric: 0.8305
# Epoch 39/60
# 1/1 [==============================] - 0s 34ms/step - loss: 0.0992 - r_factor_metric: 0.8418
# Epoch 40/60
# 1/1 [==============================] - 0s 33ms/step - loss: 0.1281 - r_factor_metric: 0.9559
# Epoch 41/60
# 1/1 [==============================] - 0s 34ms/step - loss: 0.1142 - r_factor_metric: 0.9117
# Epoch 42/60
# 1/1 [==============================] - 0s 33ms/step - loss: 0.2349 - r_factor_metric: 1.1174
# Epoch 43/60
# 1/1 [==============================] - 0s 34ms/step - loss: 0.1532 - r_factor_metric: 0.9826
# Epoch 44/60
# 1/1 [==============================] - 0s 33ms/step - loss: 0.0986 - r_factor_metric: 0.7604
# Epoch 45/60
# 1/1 [==============================] - 0s 33ms/step - loss: 0.0825 - r_factor_metric: 0.7919
# Epoch 46/60
# 1/1 [==============================] - 0s 34ms/step - loss: 0.0989 - r_factor_metric: 0.8480
# Epoch 47/60
# 1/1 [==============================] - 0s 32ms/step - loss: 0.1572 - r_factor_metric: 0.9036
# Epoch 48/60
# 1/1 [==============================] - 0s 31ms/step - loss: 0.1741 - r_factor_metric: 0.8965
# Epoch 49/60
# 1/1 [==============================] - 0s 34ms/step - loss: 0.0978 - r_factor_metric: 0.7891
# Epoch 50/60
# 1/1 [==============================] - 0s 34ms/step - loss: 0.0627 - r_factor_metric: 0.6922
# Epoch 51/60
# 1/1 [==============================] - 0s 33ms/step - loss: 0.1563 - r_factor_metric: 0.9415
# Epoch 52/60
# 1/1 [==============================] - 0s 33ms/step - loss: 0.1166 - r_factor_metric: 0.8582
# Epoch 53/60
# 1/1 [==============================] - 0s 34ms/step - loss: 0.1053 - r_factor_metric: 0.8959
# Epoch 54/60
# 1/1 [==============================] - 0s 33ms/step - loss: 0.1258 - r_factor_metric: 0.8788
# Epoch 55/60
# 1/1 [==============================] - 0s 36ms/step - loss: 0.1629 - r_factor_metric: 0.9453
# Epoch 56/60
# 1/1 [==============================] - 0s 34ms/step - loss: 0.0951 - r_factor_metric: 0.8620
# Epoch 57/60
# 1/1 [==============================] - 0s 35ms/step - loss: 0.0783 - r_factor_metric: 0.8011
# Epoch 58/60
# 1/1 [==============================] - 0s 34ms/step - loss: 0.0836 - r_factor_metric: 0.7991
# Epoch 59/60
# 1/1 [==============================] - 0s 32ms/step - loss: 0.0968 - r_factor_metric: 0.9007
# Epoch 60/60
# 1/1 [==============================] - 0s 33ms/step - loss: 0.0971 - r_factor_metric: 0.8942
# (20,)
# Final loss: 9.714e-02
# Shape of atom_shift_list: 156
# Shape of sf_combined: (67,), Shape of x_combined: (67, 3)
# Shape of atom_shift_list: 156
# Shape of sf_combined: (None,), Shape of x_combined: (None, 3)
# Epoch 1/60
# Shape of atom_shift_list: 156
# Shape of sf_combined: (67,), Shape of x_combined: (67, 3)
# Shape of atom_shift_list: 156
# Shape of sf_combined: (67,), Shape of x_combined: (67, 3)
# 1/1 [==============================] - 8s 8s/step - loss: 0.0922 - r_factor_metric: 0.8232
# Epoch 2/60
# 1/1 [==============================] - 0s 32ms/step - loss: 0.1195 - r_factor_metric: 0.8494
# Epoch 3/60
# 1/1 [==============================] - 0s 33ms/step - loss: 0.1065 - r_factor_metric: 0.8220
# Epoch 4/60
# 1/1 [==============================] - 0s 33ms/step - loss: 0.1144 - r_factor_metric: 0.8686
# Epoch 5/60
# 1/1 [==============================] - 0s 32ms/step - loss: 0.0795 - r_factor_metric: 0.7465
# Epoch 6/60
# 1/1 [==============================] - 0s 35ms/step - loss: 0.3362 - r_factor_metric: 1.0307
# Epoch 7/60
# 1/1 [==============================] - 0s 34ms/step - loss: 0.2624 - r_factor_metric: 1.0222
# Epoch 8/60
# 1/1 [==============================] - 0s 34ms/step - loss: 0.1214 - r_factor_metric: 0.7696
# Epoch 9/60
# 1/1 [==============================] - 0s 34ms/step - loss: 0.1135 - r_factor_metric: 0.9119
# Epoch 10/60
# 1/1 [==============================] - 0s 33ms/step - loss: 0.1231 - r_factor_metric: 0.8772
# Epoch 11/60
# 1/1 [==============================] - 0s 33ms/step - loss: 0.0836 - r_factor_metric: 0.8330
# Epoch 12/60
# 1/1 [==============================] - 0s 33ms/step - loss: 0.0818 - r_factor_metric: 0.8441
# Epoch 13/60
# 1/1 [==============================] - 0s 34ms/step - loss: 0.1782 - r_factor_metric: 0.8059
# Epoch 14/60
# 1/1 [==============================] - 0s 34ms/step - loss: 0.0688 - r_factor_metric: 0.7526
# Epoch 15/60
# 1/1 [==============================] - 0s 33ms/step - loss: 0.0976 - r_factor_metric: 0.7838
# Epoch 16/60
# 1/1 [==============================] - 0s 33ms/step - loss: 0.1404 - r_factor_metric: 0.8781
# Epoch 17/60
# 1/1 [==============================] - 0s 33ms/step - loss: 0.1625 - r_factor_metric: 0.8855
# Epoch 18/60
# 1/1 [==============================] - 0s 33ms/step - loss: 0.1449 - r_factor_metric: 0.9198
# Epoch 19/60
# 1/1 [==============================] - 0s 33ms/step - loss: 0.1210 - r_factor_metric: 0.8905
# Epoch 20/60
# 1/1 [==============================] - 0s 33ms/step - loss: 0.1234 - r_factor_metric: 0.7905
# Epoch 21/60
# 1/1 [==============================] - 0s 34ms/step - loss: 0.1076 - r_factor_metric: 0.8155
# Epoch 22/60
# 1/1 [==============================] - 0s 33ms/step - loss: 0.1373 - r_factor_metric: 0.9059
# Epoch 23/60
# 1/1 [==============================] - 0s 32ms/step - loss: 0.1315 - r_factor_metric: 0.8553
# Epoch 24/60
# 1/1 [==============================] - 0s 33ms/step - loss: 0.1159 - r_factor_metric: 0.8579
# Epoch 25/60
# 1/1 [==============================] - 0s 33ms/step - loss: 0.1010 - r_factor_metric: 0.8280
# Epoch 26/60
# 1/1 [==============================] - 0s 33ms/step - loss: 0.1465 - r_factor_metric: 0.9436
# Epoch 27/60
# 1/1 [==============================] - 0s 34ms/step - loss: 0.1368 - r_factor_metric: 1.0163
# Epoch 28/60
# 1/1 [==============================] - 0s 34ms/step - loss: 0.0836 - r_factor_metric: 0.7912
# Epoch 29/60
# 1/1 [==============================] - 0s 32ms/step - loss: 0.0797 - r_factor_metric: 0.7494
# Epoch 30/60
# 1/1 [==============================] - 0s 33ms/step - loss: 0.1060 - r_factor_metric: 0.8932
# Epoch 31/60
# 1/1 [==============================] - 0s 33ms/step - loss: 0.1473 - r_factor_metric: 0.9835
# Epoch 32/60
# 1/1 [==============================] - 0s 33ms/step - loss: 0.0929 - r_factor_metric: 0.8341
# Epoch 33/60
# 1/1 [==============================] - 0s 33ms/step - loss: 0.1099 - r_factor_metric: 0.8204
# Epoch 34/60
# 1/1 [==============================] - 0s 34ms/step - loss: 0.1190 - r_factor_metric: 0.8629
# Epoch 35/60
# 1/1 [==============================] - 0s 33ms/step - loss: 0.1181 - r_factor_metric: 0.9431
# Epoch 36/60
# 1/1 [==============================] - 0s 34ms/step - loss: 0.1550 - r_factor_metric: 0.8229
# Epoch 37/60
# 1/1 [==============================] - 0s 33ms/step - loss: 0.1188 - r_factor_metric: 0.8257
# Epoch 38/60
# 1/1 [==============================] - 0s 33ms/step - loss: 0.0969 - r_factor_metric: 0.8480
# Epoch 39/60
# 1/1 [==============================] - 0s 35ms/step - loss: 0.0919 - r_factor_metric: 0.8348
# Epoch 40/60
# 1/1 [==============================] - 0s 34ms/step - loss: 0.1741 - r_factor_metric: 0.9177
# Epoch 41/60
# 1/1 [==============================] - 0s 34ms/step - loss: 0.1473 - r_factor_metric: 0.8479
# Epoch 42/60
# 1/1 [==============================] - 0s 33ms/step - loss: 0.1646 - r_factor_metric: 0.8533
# Epoch 43/60
# 1/1 [==============================] - 0s 33ms/step - loss: 0.0897 - r_factor_metric: 0.7611
# Epoch 44/60
# 1/1 [==============================] - 0s 33ms/step - loss: 0.0866 - r_factor_metric: 0.7901
# Epoch 45/60
# 1/1 [==============================] - 0s 35ms/step - loss: 0.0881 - r_factor_metric: 0.7858
# Epoch 46/60
# 1/1 [==============================] - 0s 34ms/step - loss: 0.0936 - r_factor_metric: 0.7143
# Epoch 47/60
# 1/1 [==============================] - 0s 34ms/step - loss: 0.1400 - r_factor_metric: 0.8159
# Epoch 48/60
# 1/1 [==============================] - 0s 34ms/step - loss: 0.0774 - r_factor_metric: 0.8221
# Epoch 49/60
# 1/1 [==============================] - 0s 32ms/step - loss: 0.0995 - r_factor_metric: 0.8561
# Epoch 50/60
# 1/1 [==============================] - 0s 34ms/step - loss: 0.1357 - r_factor_metric: 0.8884
# Epoch 51/60
# 1/1 [==============================] - 0s 38ms/step - loss: 0.1792 - r_factor_metric: 0.8300
# Epoch 52/60
# 1/1 [==============================] - 0s 33ms/step - loss: 0.0596 - r_factor_metric: 0.6933
# Epoch 53/60
# 1/1 [==============================] - 0s 32ms/step - loss: 0.1343 - r_factor_metric: 0.9081
# Epoch 54/60
# 1/1 [==============================] - 0s 32ms/step - loss: 0.0894 - r_factor_metric: 0.8379
# Epoch 55/60
# 1/1 [==============================] - 0s 33ms/step - loss: 0.0878 - r_factor_metric: 0.7713
# Epoch 56/60
# 1/1 [==============================] - 0s 34ms/step - loss: 0.0868 - r_factor_metric: 0.8053
# Epoch 57/60
# 1/1 [==============================] - 0s 33ms/step - loss: 0.1642 - r_factor_metric: 0.9325
# Epoch 58/60
# 1/1 [==============================] - 0s 33ms/step - loss: 0.1011 - r_factor_metric: 0.8718
# Epoch 59/60
# 1/1 [==============================] - 0s 33ms/step - loss: 0.1190 - r_factor_metric: 0.8588
# Epoch 60/60
# 1/1 [==============================] - 0s 34ms/step - loss: 0.1028 - r_factor_metric: 0.8587
# (20,)
# Final loss: 1.028e-01
# Shape of atom_shift_list: 156
# Shape of sf_combined: (None,), Shape of x_combined: (None, 3)
# Epoch 1/60
# Shape of atom_shift_list: 156
# Shape of sf_combined: (67,), Shape of x_combined: (67, 3)
# Shape of atom_shift_list: 156
# Shape of sf_combined: (67,), Shape of x_combined: (67, 3)
# 1/1 [==============================] - 7s 7s/step - loss: 0.1016 - r_factor_metric: 0.8553
# Epoch 2/60
# 1/1 [==============================] - 0s 34ms/step - loss: 0.0712 - r_factor_metric: 0.7022
# Epoch 3/60
# 1/1 [==============================] - 0s 32ms/step - loss: 0.1315 - r_factor_metric: 0.9231
# Epoch 4/60
# 1/1 [==============================] - 0s 33ms/step - loss: 0.1154 - r_factor_metric: 0.8651
# Epoch 5/60
# 1/1 [==============================] - 0s 34ms/step - loss: 0.1292 - r_factor_metric: 0.9330
# Epoch 6/60
# 1/1 [==============================] - 0s 35ms/step - loss: 0.0764 - r_factor_metric: 0.7639
# Epoch 7/60
# 1/1 [==============================] - 0s 35ms/step - loss: 0.1108 - r_factor_metric: 0.8364
# Epoch 8/60
# 1/1 [==============================] - 0s 34ms/step - loss: 0.1665 - r_factor_metric: 0.9154
# Epoch 9/60
# 1/1 [==============================] - 0s 32ms/step - loss: 0.1344 - r_factor_metric: 0.9326
# Epoch 10/60
# 1/1 [==============================] - 0s 34ms/step - loss: 0.1196 - r_factor_metric: 0.8929
# Epoch 11/60
# 1/1 [==============================] - 0s 34ms/step - loss: 0.1567 - r_factor_metric: 0.9393
# Epoch 12/60
# 1/1 [==============================] - 0s 33ms/step - loss: 0.2056 - r_factor_metric: 0.8646
# Epoch 13/60
# 1/1 [==============================] - 0s 34ms/step - loss: 0.2177 - r_factor_metric: 0.8993
# Epoch 14/60
# 1/1 [==============================] - 0s 33ms/step - loss: 0.1074 - r_factor_metric: 0.8481
# Epoch 15/60
# 1/1 [==============================] - 0s 34ms/step - loss: 0.0766 - r_factor_metric: 0.7949
# Epoch 16/60
# 1/1 [==============================] - 0s 36ms/step - loss: 0.0954 - r_factor_metric: 0.8881
# Epoch 17/60
# 1/1 [==============================] - 0s 34ms/step - loss: 0.1016 - r_factor_metric: 0.7888
# Epoch 18/60
# 1/1 [==============================] - 0s 33ms/step - loss: 0.0631 - r_factor_metric: 0.7142
# Epoch 19/60
# 1/1 [==============================] - 0s 32ms/step - loss: 0.0928 - r_factor_metric: 0.7694
# Epoch 20/60
# 1/1 [==============================] - 0s 34ms/step - loss: 0.0899 - r_factor_metric: 0.8258
# Epoch 21/60
# 1/1 [==============================] - 0s 33ms/step - loss: 0.1058 - r_factor_metric: 0.8948
# Epoch 22/60
# 1/1 [==============================] - 0s 34ms/step - loss: 0.1115 - r_factor_metric: 0.8690
# Epoch 23/60
# 1/1 [==============================] - 0s 33ms/step - loss: 0.1944 - r_factor_metric: 1.0475
# Epoch 24/60
# 1/1 [==============================] - 0s 33ms/step - loss: 0.0850 - r_factor_metric: 0.7862
# Epoch 25/60
# 1/1 [==============================] - 0s 32ms/step - loss: 0.1390 - r_factor_metric: 0.9588
# Epoch 26/60
# 1/1 [==============================] - 0s 34ms/step - loss: 0.1220 - r_factor_metric: 0.9209
# Epoch 27/60
# 1/1 [==============================] - 0s 32ms/step - loss: 0.0751 - r_factor_metric: 0.7602
# Epoch 28/60
# 1/1 [==============================] - 0s 33ms/step - loss: 0.1015 - r_factor_metric: 0.8173
# Epoch 29/60
# 1/1 [==============================] - 0s 32ms/step - loss: 0.1025 - r_factor_metric: 0.8471
# Epoch 30/60
# 1/1 [==============================] - 0s 34ms/step - loss: 0.1283 - r_factor_metric: 0.9083
# Epoch 31/60
# 1/1 [==============================] - 0s 34ms/step - loss: 0.0677 - r_factor_metric: 0.7319
# Epoch 32/60
# 1/1 [==============================] - 0s 33ms/step - loss: 0.0682 - r_factor_metric: 0.8020
# Epoch 33/60
# 1/1 [==============================] - 0s 33ms/step - loss: 0.0854 - r_factor_metric: 0.7862
# Epoch 34/60
# 1/1 [==============================] - 0s 41ms/step - loss: 0.1571 - r_factor_metric: 0.9202
# Epoch 35/60
# 1/1 [==============================] - 0s 33ms/step - loss: 0.1330 - r_factor_metric: 0.9297
# Epoch 36/60
# 1/1 [==============================] - 0s 34ms/step - loss: 0.0987 - r_factor_metric: 0.7940
# Epoch 37/60
# 1/1 [==============================] - 0s 32ms/step - loss: 0.0976 - r_factor_metric: 0.8139
# Epoch 38/60
# 1/1 [==============================] - 0s 34ms/step - loss: 0.1105 - r_factor_metric: 0.8264
# Epoch 39/60
# 1/1 [==============================] - 0s 33ms/step - loss: 0.1350 - r_factor_metric: 0.9165
# Epoch 40/60
# 1/1 [==============================] - 0s 34ms/step - loss: 0.1087 - r_factor_metric: 0.9115
# Epoch 41/60
# 1/1 [==============================] - 0s 33ms/step - loss: 0.1202 - r_factor_metric: 0.9358
# Epoch 42/60
# 1/1 [==============================] - 0s 32ms/step - loss: 0.0985 - r_factor_metric: 0.7539
# Epoch 43/60
# 1/1 [==============================] - 0s 34ms/step - loss: 0.1413 - r_factor_metric: 0.8115
# Epoch 44/60
# 1/1 [==============================] - 0s 33ms/step - loss: 0.0665 - r_factor_metric: 0.7162
# Epoch 45/60
# 1/1 [==============================] - 0s 34ms/step - loss: 0.1289 - r_factor_metric: 0.8765
# Epoch 46/60
# 1/1 [==============================] - 0s 34ms/step - loss: 0.3443 - r_factor_metric: 1.1220
# Epoch 47/60
# 1/1 [==============================] - 0s 33ms/step - loss: 0.1099 - r_factor_metric: 0.8754
# Epoch 48/60
# 1/1 [==============================] - 0s 33ms/step - loss: 0.3454 - r_factor_metric: 1.0334
# Epoch 49/60
# 1/1 [==============================] - 0s 31ms/step - loss: 0.0635 - r_factor_metric: 0.7131
# Epoch 50/60
# 1/1 [==============================] - 0s 32ms/step - loss: 0.1182 - r_factor_metric: 0.8694
# Epoch 51/60
# 1/1 [==============================] - 0s 33ms/step - loss: 0.1350 - r_factor_metric: 0.9074
# Epoch 52/60
# 1/1 [==============================] - 0s 33ms/step - loss: 0.1589 - r_factor_metric: 0.9230
# Epoch 53/60
# 1/1 [==============================] - 0s 34ms/step - loss: 0.1557 - r_factor_metric: 1.0173
# Epoch 54/60
# 1/1 [==============================] - 0s 33ms/step - loss: 0.1393 - r_factor_metric: 0.8131
# Epoch 55/60
# 1/1 [==============================] - 0s 34ms/step - loss: 0.0584 - r_factor_metric: 0.6738
# Epoch 56/60
# 1/1 [==============================] - 0s 33ms/step - loss: 0.0573 - r_factor_metric: 0.6927
# Epoch 57/60
# 1/1 [==============================] - 0s 33ms/step - loss: 0.1442 - r_factor_metric: 0.9614
# Epoch 58/60
# 1/1 [==============================] - 0s 33ms/step - loss: 0.1670 - r_factor_metric: 1.0208
# Epoch 59/60
# 1/1 [==============================] - 0s 34ms/step - loss: 0.1353 - r_factor_metric: 0.9069
# Epoch 60/60
# 1/1 [==============================] - 0s 32ms/step - loss: 0.1267 - r_factor_metric: 0.9004
# (20,)
# Final loss: 1.267e-01
# Shape of atom_shift_list: 156
# Shape of sf_combined: (None,), Shape of x_combined: (None, 3)
# Epoch 1/60
# Shape of atom_shift_list: 156
# Shape of sf_combined: (67,), Shape of x_combined: (67, 3)
# Shape of atom_shift_list: 156
# Shape of sf_combined: (67,), Shape of x_combined: (67, 3)
# 1/1 [==============================] - 8s 8s/step - loss: 0.0994 - r_factor_metric: 0.8494
# Epoch 2/60
# 1/1 [==============================] - 0s 31ms/step - loss: 0.0920 - r_factor_metric: 0.8385
# Epoch 3/60
# 1/1 [==============================] - 0s 33ms/step - loss: 0.1177 - r_factor_metric: 0.9169
# Epoch 4/60
# 1/1 [==============================] - 0s 32ms/step - loss: 0.0922 - r_factor_metric: 0.8195
# Epoch 5/60
# 1/1 [==============================] - 0s 33ms/step - loss: 0.1967 - r_factor_metric: 0.8865
# Epoch 6/60
# 1/1 [==============================] - 0s 33ms/step - loss: 0.0741 - r_factor_metric: 0.7106
# Epoch 7/60
# 1/1 [==============================] - 0s 34ms/step - loss: 0.1905 - r_factor_metric: 0.9718
# Epoch 8/60
# 1/1 [==============================] - 0s 33ms/step - loss: 0.0979 - r_factor_metric: 0.7671
# Epoch 9/60
# 1/1 [==============================] - 0s 34ms/step - loss: 0.1605 - r_factor_metric: 0.9346
# Epoch 10/60
# 1/1 [==============================] - 0s 33ms/step - loss: 0.2193 - r_factor_metric: 0.9964
# Epoch 11/60
# 1/1 [==============================] - 0s 32ms/step - loss: 0.1656 - r_factor_metric: 0.9599
# Epoch 12/60
# 1/1 [==============================] - 0s 34ms/step - loss: 0.1454 - r_factor_metric: 0.9618
# Epoch 13/60
# 1/1 [==============================] - 0s 33ms/step - loss: 0.1028 - r_factor_metric: 0.8988
# Epoch 14/60
# 1/1 [==============================] - 0s 34ms/step - loss: 0.0754 - r_factor_metric: 0.7657
# Epoch 15/60
# 1/1 [==============================] - 0s 34ms/step - loss: 0.1194 - r_factor_metric: 0.8997
# Epoch 16/60
# 1/1 [==============================] - 0s 33ms/step - loss: 0.0940 - r_factor_metric: 0.8580
# Epoch 17/60
# 1/1 [==============================] - 0s 34ms/step - loss: 0.0918 - r_factor_metric: 0.8262
# Epoch 18/60
# 1/1 [==============================] - 0s 33ms/step - loss: 0.0723 - r_factor_metric: 0.8065
# Epoch 19/60
# 1/1 [==============================] - 0s 33ms/step - loss: 0.0998 - r_factor_metric: 0.8090
# Epoch 20/60
# 1/1 [==============================] - 0s 34ms/step - loss: 0.1210 - r_factor_metric: 0.8350
# Epoch 21/60
# 1/1 [==============================] - 0s 34ms/step - loss: 0.1662 - r_factor_metric: 0.9357
# Epoch 22/60
# 1/1 [==============================] - 0s 33ms/step - loss: 0.1670 - r_factor_metric: 0.9086
# Epoch 23/60
# 1/1 [==============================] - 0s 33ms/step - loss: 0.1950 - r_factor_metric: 0.8911
# Epoch 24/60
# 1/1 [==============================] - 0s 34ms/step - loss: 0.1770 - r_factor_metric: 0.8750
# Epoch 25/60
# 1/1 [==============================] - 0s 34ms/step - loss: 0.0890 - r_factor_metric: 0.8622
# Epoch 26/60
# 1/1 [==============================] - 0s 39ms/step - loss: 0.0921 - r_factor_metric: 0.8750
# Epoch 27/60
# 1/1 [==============================] - 0s 33ms/step - loss: 0.1096 - r_factor_metric: 0.8528
# Epoch 28/60
# 1/1 [==============================] - 0s 34ms/step - loss: 0.0985 - r_factor_metric: 0.7421
# Epoch 29/60
# 1/1 [==============================] - 0s 33ms/step - loss: 0.0777 - r_factor_metric: 0.7426
# Epoch 30/60
# 1/1 [==============================] - 0s 33ms/step - loss: 0.0661 - r_factor_metric: 0.6642
# Epoch 31/60
# 1/1 [==============================] - 0s 33ms/step - loss: 0.1288 - r_factor_metric: 0.9164
# Epoch 32/60
# 1/1 [==============================] - 0s 33ms/step - loss: 0.1336 - r_factor_metric: 0.9226
# Epoch 33/60
# 1/1 [==============================] - 0s 34ms/step - loss: 0.1941 - r_factor_metric: 0.8744
# Epoch 34/60
# 1/1 [==============================] - 0s 34ms/step - loss: 0.1458 - r_factor_metric: 0.7944
# Epoch 35/60
# 1/1 [==============================] - 0s 32ms/step - loss: 0.1051 - r_factor_metric: 0.7867
# Epoch 36/60
# 1/1 [==============================] - 0s 34ms/step - loss: 0.0872 - r_factor_metric: 0.8088
# Epoch 37/60
# 1/1 [==============================] - 0s 34ms/step - loss: 0.0790 - r_factor_metric: 0.8065
# Epoch 38/60
# 1/1 [==============================] - 0s 33ms/step - loss: 0.1122 - r_factor_metric: 0.8739
# Epoch 39/60
# 1/1 [==============================] - 0s 33ms/step - loss: 0.1473 - r_factor_metric: 0.8650
# Epoch 40/60
# 1/1 [==============================] - 0s 32ms/step - loss: 0.1302 - r_factor_metric: 0.9845
# Epoch 41/60
# 1/1 [==============================] - 0s 34ms/step - loss: 0.1182 - r_factor_metric: 0.9226
# Epoch 42/60
# 1/1 [==============================] - 0s 33ms/step - loss: 0.0803 - r_factor_metric: 0.8095
# Epoch 43/60
# 1/1 [==============================] - 0s 34ms/step - loss: 0.1267 - r_factor_metric: 0.9492
# Epoch 44/60
# 1/1 [==============================] - 0s 33ms/step - loss: 0.1537 - r_factor_metric: 0.9713
# Epoch 45/60
# 1/1 [==============================] - 0s 34ms/step - loss: 0.1629 - r_factor_metric: 0.8256
# Epoch 46/60
# 1/1 [==============================] - 0s 32ms/step - loss: 0.2202 - r_factor_metric: 1.0585
# Epoch 47/60
# 1/1 [==============================] - 0s 34ms/step - loss: 0.1066 - r_factor_metric: 0.8340
# Epoch 48/60
# 1/1 [==============================] - 0s 34ms/step - loss: 0.0927 - r_factor_metric: 0.8159
# Epoch 49/60
# 1/1 [==============================] - 0s 35ms/step - loss: 0.1098 - r_factor_metric: 0.8532
# Epoch 50/60
# 1/1 [==============================] - 0s 33ms/step - loss: 0.1157 - r_factor_metric: 0.9291
# Epoch 51/60
# 1/1 [==============================] - 0s 34ms/step - loss: 0.2005 - r_factor_metric: 0.8641
# Epoch 52/60
# 1/1 [==============================] - 0s 33ms/step - loss: 0.1122 - r_factor_metric: 0.8576
# Epoch 53/60
# 1/1 [==============================] - 0s 32ms/step - loss: 0.1804 - r_factor_metric: 0.9746
# Epoch 54/60
# 1/1 [==============================] - 0s 33ms/step - loss: 0.1318 - r_factor_metric: 0.8973
# Epoch 55/60
# 1/1 [==============================] - 0s 35ms/step - loss: 0.1461 - r_factor_metric: 0.9151
# Epoch 56/60
# 1/1 [==============================] - 0s 34ms/step - loss: 0.0962 - r_factor_metric: 0.8307
# Epoch 57/60
# 1/1 [==============================] - 0s 38ms/step - loss: 0.1013 - r_factor_metric: 0.8446
# Epoch 58/60
# 1/1 [==============================] - 0s 34ms/step - loss: 0.0864 - r_factor_metric: 0.8205
# Epoch 59/60
# 1/1 [==============================] - 0s 33ms/step - loss: 0.1701 - r_factor_metric: 0.8454
# Epoch 60/60
# 1/1 [==============================] - 0s 33ms/step - loss: 0.2298 - r_factor_metric: 1.0459
# (20,)
# Final loss: 2.298e-01
# Shape of atom_shift_list: 156
# Shape of sf_combined: (None,), Shape of x_combined: (None, 3)
# Epoch 1/60
# Shape of atom_shift_list: 156
# Shape of sf_combined: (67,), Shape of x_combined: (67, 3)
# Shape of atom_shift_list: 156
# Shape of sf_combined: (67,), Shape of x_combined: (67, 3)
# 1/1 [==============================] - 7s 7s/step - loss: 0.0994 - r_factor_metric: 0.8494
# Epoch 2/60
# 1/1 [==============================] - 0s 33ms/step - loss: 0.0727 - r_factor_metric: 0.7603
# Epoch 3/60
# 1/1 [==============================] - 0s 34ms/step - loss: 0.0991 - r_factor_metric: 0.8537
# Epoch 4/60
# 1/1 [==============================] - 0s 34ms/step - loss: 0.0921 - r_factor_metric: 0.8378
# Epoch 5/60
# 1/1 [==============================] - 0s 33ms/step - loss: 0.1467 - r_factor_metric: 0.9592
# Epoch 6/60
# 1/1 [==============================] - 0s 33ms/step - loss: 0.0957 - r_factor_metric: 0.8593
# Epoch 7/60
# 1/1 [==============================] - 0s 32ms/step - loss: 0.1313 - r_factor_metric: 0.9095
# Epoch 8/60
# 1/1 [==============================] - 0s 33ms/step - loss: 0.1469 - r_factor_metric: 0.8429
# Epoch 9/60
# 1/1 [==============================] - 0s 31ms/step - loss: 0.1187 - r_factor_metric: 0.8416
# Epoch 10/60
# 1/1 [==============================] - 0s 34ms/step - loss: 0.3716 - r_factor_metric: 0.9475
# Epoch 11/60
# 1/1 [==============================] - 0s 34ms/step - loss: 0.0886 - r_factor_metric: 0.8257
# Epoch 12/60
# 1/1 [==============================] - 0s 35ms/step - loss: 0.0720 - r_factor_metric: 0.7655
# Epoch 13/60
# 1/1 [==============================] - 0s 33ms/step - loss: 0.1746 - r_factor_metric: 0.9237
# Epoch 14/60
# 1/1 [==============================] - 0s 34ms/step - loss: 0.0787 - r_factor_metric: 0.7705
# Epoch 15/60
# 1/1 [==============================] - 0s 32ms/step - loss: 0.1677 - r_factor_metric: 1.0371
# Epoch 16/60
# 1/1 [==============================] - 0s 36ms/step - loss: 0.0852 - r_factor_metric: 0.8386
# Epoch 17/60
# 1/1 [==============================] - 0s 33ms/step - loss: 0.1451 - r_factor_metric: 0.7588
# Epoch 18/60
# 1/1 [==============================] - 0s 36ms/step - loss: 0.2927 - r_factor_metric: 1.0747
# Epoch 19/60
# 1/1 [==============================] - 0s 33ms/step - loss: 0.1428 - r_factor_metric: 0.9181
# Epoch 20/60
# 1/1 [==============================] - 0s 32ms/step - loss: 0.1444 - r_factor_metric: 0.8374
# Epoch 21/60
# 1/1 [==============================] - 0s 34ms/step - loss: 0.4812 - r_factor_metric: 1.1926
# Epoch 22/60
# 1/1 [==============================] - 0s 35ms/step - loss: 0.2097 - r_factor_metric: 1.0463
# Epoch 23/60
# 1/1 [==============================] - 0s 34ms/step - loss: 0.1019 - r_factor_metric: 0.8041
# Epoch 24/60
# 1/1 [==============================] - 0s 33ms/step - loss: 0.1539 - r_factor_metric: 0.9661
# Epoch 25/60
# 1/1 [==============================] - 0s 32ms/step - loss: 0.1451 - r_factor_metric: 0.8780
# Epoch 26/60
# 1/1 [==============================] - 0s 33ms/step - loss: 0.1454 - r_factor_metric: 0.8674
# Epoch 27/60
# 1/1 [==============================] - 0s 32ms/step - loss: 0.1047 - r_factor_metric: 0.8302
# Epoch 28/60
# 1/1 [==============================] - 0s 33ms/step - loss: 0.1239 - r_factor_metric: 0.9015
# Epoch 29/60
# 1/1 [==============================] - 0s 34ms/step - loss: 0.1016 - r_factor_metric: 0.8628
# Epoch 30/60
# 1/1 [==============================] - 0s 34ms/step - loss: 0.1548 - r_factor_metric: 0.9553
# Epoch 31/60
# 1/1 [==============================] - 0s 34ms/step - loss: 0.3091 - r_factor_metric: 0.8849
# Epoch 32/60
# 1/1 [==============================] - 0s 33ms/step - loss: 0.0682 - r_factor_metric: 0.6797
# Epoch 33/60
# 1/1 [==============================] - 0s 31ms/step - loss: 0.1260 - r_factor_metric: 0.9352
# Epoch 34/60
# 1/1 [==============================] - 0s 33ms/step - loss: 0.1537 - r_factor_metric: 0.8981
# Epoch 35/60
# 1/1 [==============================] - 0s 34ms/step - loss: 0.1158 - r_factor_metric: 0.8833
# Epoch 36/60
# 1/1 [==============================] - 0s 33ms/step - loss: 0.0905 - r_factor_metric: 0.7641
# Epoch 37/60
# 1/1 [==============================] - 0s 32ms/step - loss: 0.0749 - r_factor_metric: 0.8151
# Epoch 38/60
# 1/1 [==============================] - 0s 33ms/step - loss: 0.1210 - r_factor_metric: 0.8712
# Epoch 39/60
# 1/1 [==============================] - 0s 33ms/step - loss: 0.0727 - r_factor_metric: 0.7567
# Epoch 40/60
# 1/1 [==============================] - 0s 32ms/step - loss: 0.1882 - r_factor_metric: 0.9125
# Epoch 41/60
# 1/1 [==============================] - 0s 33ms/step - loss: 0.1016 - r_factor_metric: 0.8331
# Epoch 42/60
# 1/1 [==============================] - 0s 38ms/step - loss: 0.0884 - r_factor_metric: 0.7487
# Epoch 43/60
# 1/1 [==============================] - 0s 36ms/step - loss: 0.1242 - r_factor_metric: 0.8305
# Epoch 44/60
# 1/1 [==============================] - 0s 35ms/step - loss: 0.0889 - r_factor_metric: 0.7883
# Epoch 45/60
# 1/1 [==============================] - 0s 34ms/step - loss: 0.1497 - r_factor_metric: 0.8071
# Epoch 46/60
# 1/1 [==============================] - 0s 33ms/step - loss: 0.0926 - r_factor_metric: 0.8181
# Epoch 47/60
# 1/1 [==============================] - 0s 33ms/step - loss: 0.1637 - r_factor_metric: 0.9350
# Epoch 48/60
# 1/1 [==============================] - 0s 34ms/step - loss: 0.0793 - r_factor_metric: 0.7383
# Epoch 49/60
# 1/1 [==============================] - 0s 32ms/step - loss: 0.1016 - r_factor_metric: 0.8450
# Epoch 50/60
# 1/1 [==============================] - 0s 33ms/step - loss: 0.0657 - r_factor_metric: 0.6941
# Epoch 51/60
# 1/1 [==============================] - 0s 34ms/step - loss: 0.1209 - r_factor_metric: 0.8040
# Epoch 52/60
# 1/1 [==============================] - 0s 34ms/step - loss: 0.1088 - r_factor_metric: 0.8668
# Epoch 53/60
# 1/1 [==============================] - 0s 34ms/step - loss: 0.0959 - r_factor_metric: 0.8544
# Epoch 54/60
# 1/1 [==============================] - 0s 32ms/step - loss: 0.1525 - r_factor_metric: 0.9535
# Epoch 55/60
# 1/1 [==============================] - 0s 34ms/step - loss: 0.1927 - r_factor_metric: 0.9206
# Epoch 56/60
# 1/1 [==============================] - 0s 34ms/step - loss: 0.1206 - r_factor_metric: 0.8594
# Epoch 57/60
# 1/1 [==============================] - 0s 34ms/step - loss: 0.1023 - r_factor_metric: 0.8016
# Epoch 58/60
# 1/1 [==============================] - 0s 33ms/step - loss: 0.1130 - r_factor_metric: 0.7855
# Epoch 59/60
# 1/1 [==============================] - 0s 34ms/step - loss: 0.1579 - r_factor_metric: 0.8597
# Epoch 60/60
# 1/1 [==============================] - 0s 33ms/step - loss: 0.1137 - r_factor_metric: 0.9695
# (20,)
# Final loss: 1.137e-01
# time elapsed: 58.09 seconds
# With 5.16436436109081 iterations per second

# %%
all_losses = best_loss_overall
best_model_pars = best_pars_overall
min_loss = best_rf_overall

print(f"min loss: {min_loss}")


# Plotting the loss values
plt.figure(figsize=(10, 6))

# Plot the loss values for each iteration
for i, loss_values in enumerate(all_losses):
    plt.plot(loss_values, label=f'Iteration {i+1}')

plt.title('Loss vs Epochs')
plt.xlabel('Epochs')
plt.ylabel('Loss')
# plt.legend()
plt.grid(True)
plt.show()
# Out:
# min loss: 0.08317147940397263

# %%
mode_names = pd.read_csv('C:/Users/User/Desktop/uzh_intern/CrystalClearFit/alrisDistortionFit/La2CuO4/raw_data/La2CuO4_displacivemode_names.txt' , delim_whitespace=True, header=None)

mode_names = mode_names.values.tolist()
mode_names = pd.DataFrame(mode_names)

# Print the best model parameters
print("min loss:", min_loss)
print("Best model parameters:") 
for i, par in enumerate(best_model_pars):
    print(f"{mode_names.iloc[i , 0]} : {par.numpy():.8f}")
    
# Print the model summary
print("Number of iterations:", n_iter)
print("Number of features:", n_features)
#modes = get_mode_amplitudes_p63(*best_model_pars)
#print("Modes:")
##for key, val in modes.items():
    #print(f"{key}: {val*1000:.4f}")
# Out:
# min loss: 0.08317147940397263
# Best model parameters:
# Cmca[1,0,0]Y1+(a)[La1:f:dsp] : -0.35701862
# Cmca[1,0,0]Y1+(a)[La1:f:dsp] : 2.04651737
# Cmca[1,0,0]Y3+(a)[La1:f:dsp] : 1.27269351
# Cmca[1,0,0]Y3+(a)[La1:f:dsp] : 0.08656345
# Cmca[1,0,0]Y1+(a)[O1:f:dsp] : 1.36680508
# Cmca[1,0,0]Y1+(a)[O1:f:dsp] : -1.17308259
# Cmca[1,0,0]Y3+(a)[O1:f:dsp] : -2.02317452
# Cmca[1,0,0]Y3+(a)[O1:f:dsp] : -1.62575138
# Cmca[1,0,0]Y1+(a)[O2:e:dsp] : -3.22527575
# Cmca[1,0,0]Y3+(a)[O2:e:dsp] : 1.34222901
# Cmca[1,0,0]Y3+(a)[O2:e:dsp] : 2.60493350
# Cmca[1,0,0]Y1+(a)[O3:g:dsp] : 3.16197729
# Cmca[1,0,0]Y1+(a)[O3:g:dsp] : 1.53902960
# Cmca[1,0,0]Y1+(a)[O3:g:dsp] : -1.80811179
# Cmca[1,0,0]Y3+(a)[O3:g:dsp] : -1.99189913
# Cmca[1,0,0]Y3+(a)[O3:g:dsp] : -1.17908025
# Cmca[1,0,0]Y3+(a)[O3:g:dsp] : -0.99477476
# Cmca[1,0,0]Y1+(a)[O4:e:dsp] : 2.61498666
# Cmca[1,0,0]Y3+(a)[O4:e:dsp] : -0.90743369
# Cmca[1,0,0]Y3+(a)[O4:e:dsp] : 0.80403823
# Number of iterations: 5
# Number of features: 67
# C:\Users\User\AppData\Local\Temp\ipykernel_23532\3457527789.py:1: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   mode_names = pd.read_csv('C:/Users/User/Desktop/uzh_intern/CrystalClearFit/alrisDistortionFit/La2CuO4/raw_data/La2CuO4_displacivemode_names.txt' , delim_whitespace=True, header=None)

# %%
def plot_plane_sim_vs_exp(ax, df, k, min_loss , r_factor , norm_plane=False):
    exp_data_0 = df.loc[df['k'] == k].copy()
    if norm_plane:
        exp_data_0['intensity_sim'] = exp_data_0['intensity_sim'] / np.sum(exp_data_0['intensity_sim'])
        exp_data_0['intensity_exp'] = exp_data_0['intensity_exp'] / np.sum(exp_data_0['intensity_exp'])
    
    ax.scatter(exp_data_0['h'], exp_data_0['l'], 
               s=exp_data_0['intensity_sim'] * 0.1, color='red', edgecolor="black",
               label='Sim', marker=MarkerStyle("o", fillstyle="right"))
    ax.scatter(exp_data_0['h'], exp_data_0['l'], 
               s=exp_data_0['intensity_exp'] * 0.1 , color='blue', edgecolor="black",
               label='Exp', marker=MarkerStyle("o", fillstyle="left"))
    
    ax.set_xlabel(f"h in (h, {k}, l) [r.l.u.]")
    ax.set_ylabel(f"l in (h, {k}, l) [r.l.u.]")
    ax.set_title(f"k = {k} , min loss = {min_loss:.4f}, r-factor (normalised)= {r_factor:.4f}")
    ax.legend()


def plot_plane_sim_vs_exp1(ax, df, l,  min_loss , r_factor , norm_plane=False):
    exp_data_0 = df.loc[df['l'] == l].copy()
    if norm_plane:
        exp_data_0['intensity_sim'] = exp_data_0['intensity_sim'] / np.sum(exp_data_0['intensity_sim'])
        exp_data_0['intensity_exp'] = exp_data_0['intensity_exp'] / np.sum(exp_data_0['intensity_exp'])
    
    ax.scatter(exp_data_0['h'], exp_data_0['k'], 
               s=exp_data_0['intensity_sim'] * 0.1, color='red', edgecolor="black",
               label='Sim', marker=MarkerStyle("o", fillstyle="right"))
    ax.scatter(exp_data_0['h'], exp_data_0['k'], 
               s=exp_data_0['intensity_exp'] * 0.1, color='blue', edgecolor="black",
               label='Exp', marker=MarkerStyle("o", fillstyle="left"))
    
    ax.set_xlabel(f"h in (h, k, {l}) [r.l.u.]")
    ax.set_ylabel(f"k in (h, k, {l}) [r.l.u.]")
    ax.set_title(f"l = {l} , min loss = {min_loss:.4f}, r-factor (normalised)= {r_factor:.4f}")
    ax.legend()

# %%
def plot_plane_sim_vs_exp_ruggero(ax, df, k, min_loss , r_factor , norm_plane=False):
    exp_data_0 = df.loc[df['k'] == k].copy()
    if norm_plane:
        exp_data_0['intensity_sim'] = exp_data_0['intensity_sim'] / np.sum(exp_data_0['intensity_sim'])
        exp_data_0['intensity_exp'] = exp_data_0['intensity_exp'] / np.sum(exp_data_0['intensity_exp'])
    
    ax.scatter(exp_data_0['h'], exp_data_0['l'], 
               s=exp_data_0['intensity_sim'] * 10000, color='red', edgecolor="black",
               label='Sim', marker=MarkerStyle("o", fillstyle="right"))
    ax.scatter(exp_data_0['h'], exp_data_0['l'], 
               s=exp_data_0['intensity_exp'] * 10000 , color='blue', edgecolor="black",
               label='Exp', marker=MarkerStyle("o", fillstyle="left"))
    
    ax.set_xlabel(f"h in (h, {k}, l) [r.l.u.]")
    ax.set_ylabel(f"l in (h, {k}, l) [r.l.u.]")
    ax.set_title(f"k = {k} , min loss = {min_loss:.4f}, r-factor (normalised)= {r_factor:.4f}")
    ax.legend()


def plot_plane_sim_vs_exp1_ruggero(ax, df, l,  min_loss , r_factor , norm_plane=False):
    exp_data_0 = df.loc[df['l'] == l].copy()
    if norm_plane:
        exp_data_0['intensity_sim'] = exp_data_0['intensity_sim'] / np.sum(exp_data_0['intensity_sim'])
        exp_data_0['intensity_exp'] = exp_data_0['intensity_exp'] / np.sum(exp_data_0['intensity_exp'])
    
    ax.scatter(exp_data_0['h'], exp_data_0['k'], 
               s=exp_data_0['intensity_sim'] * 1000, color='red', edgecolor="black",
               label='Sim', marker=MarkerStyle("o", fillstyle="right"))
    ax.scatter(exp_data_0['h'], exp_data_0['k'], 
               s=exp_data_0['intensity_exp'] * 1000, color='blue', edgecolor="black",
               label='Exp', marker=MarkerStyle("o", fillstyle="left"))
    
    ax.set_xlabel(f"h in (h, k, {l}) [r.l.u.]")
    ax.set_ylabel(f"k in (h, k, {l}) [r.l.u.]")
    ax.set_title(f"l = {l} , min loss = {min_loss:.4f}, r-factor (normalised)= {r_factor:.4f}")
    ax.legend()

# %%
def alris_r_factor(data):
    exp_intensity = data['intensity_exp'] / np.sum(data['intensity_exp'])
    simulated_intensity = data['intensity_sim'] / np.sum(data['intensity_sim'])
    alris_r_factor_normalised = np.sum(np.abs(exp_intensity - simulated_intensity)) / np.sum(np.abs(exp_intensity))

    alris_r_factor_not_normalised = np.sum(np.abs(data['intensity_exp'] - data['intensity_sim'])) / np.sum(np.abs(data['intensity_exp']))
    return alris_r_factor_normalised , alris_r_factor_not_normalised

# %%
exp_data = pd.read_csv('C:/Users/User/Desktop/uzh_intern/CrystalClearFit/alrisDistortionFit/La2CuO4/raw_data/peaks1.csv')
intensity, intensity_summed , intensity_unscaled = fun_tf(features, best_model_pars)
exp_data['intensity_sim'] = intensity_unscaled.numpy()  # Convert to numpy array for further processing
exp_data['intensity_sim_normalised'] = intensity.numpy()
exp_data['ratio'] = (exp_data['intensity_exp'] / np.sum(exp_data['intensity_exp'])) / (exp_data['intensity_sim'] / np.sum(exp_data['intensity_sim']))
alris_r_factor_value_normalised , alris_r_factor_value_not_normalised  = alris_r_factor(exp_data)
exp_data['rfactor_normalised'] = alris_r_factor_value_normalised
exp_data['rfactor_not_normalised'] = alris_r_factor_value_not_normalised
exp_data['min_loss'] = min_loss
print(f"alris r-factor: {alris_r_factor_value_normalised:.4f}")
print(f"alris r-factor not normalised: {alris_r_factor_value_not_normalised:.4f}")
# Out:
# Shape of atom_shift_list: 156
# Shape of sf_combined: (67,), Shape of x_combined: (67, 3)
# alris r-factor: 0.8159
# alris r-factor not normalised: 7.1690

# %%
# Prepare subplot grid
fig, axs = plt.subplots(1, 2, figsize=(9, 7), constrained_layout=True)
plt.style.use('default')
plot_plane_sim_vs_exp(axs[0], exp_data, 0, min_loss ,alris_r_factor_value_normalised, norm_plane=True)
plot_plane_sim_vs_exp1(axs[1], exp_data, 0,min_loss ,alris_r_factor_value_normalised, norm_plane=True)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 2
#       1 # Prepare subplot grid
# ----> 2 fig, axs = plt.subplots(1, 2, figsize=(9, 7), constrained_layout=True)
#       3 plt.style.use('default')
#       4 plot_plane_sim_vs_exp(axs[0], exp_data, 0, min_loss ,alris_r_factor_value_normalised, norm_plane=True)
#
# NameError: name 'plt' is not defined

# %%
ruggero = pd.read_csv('C:/Users/User/Desktop/uzh_intern/CrystalClearFit/alrisDistortionFit/La2CuO4/raw_data/completely_raw_data.txt' , header=None, delim_whitespace=True)
ruggero = ruggero.values.tolist()
ruggero = np.array(ruggero)
ruggero_pd_dataframe = pd.DataFrame({
    'h': ruggero[:,0],
    'k': ruggero[:,1],
    'l': ruggero[:,2],
    'intensity_exp': ruggero[:,3],
    'intensity_sim': ruggero[:,4],  # Scale the simulated intensity
    'ratio': ruggero[:,5],
})

ruggero_scaled_sim = ruggero[:,4] * ruggero[:,5]
ruggero_ratio = (ruggero[:, 3] / np.sum(ruggero[:,3])) / (ruggero_scaled_sim / np.sum(ruggero_scaled_sim)) # Extract the 5th column
ruggero_rfactor_normalised , ruggero_rfactor_not_normalised = alris_r_factor(ruggero_pd_dataframe)
print(f"ruggero r-factor: {ruggero_rfactor_normalised:.4f}")
print(f"ruggero r-factor not normalised: {ruggero_rfactor_not_normalised:.4f}")

# Prepare subplot grid
fig1, axs = plt.subplots(1, 2, figsize=(9, 7), constrained_layout=True)
plt.style.use('default')
plot_plane_sim_vs_exp_ruggero(axs[0], ruggero_pd_dataframe , 0, min_loss ,ruggero_rfactor_normalised, norm_plane=True)
plot_plane_sim_vs_exp1_ruggero(axs[1], ruggero_pd_dataframe , 0,min_loss ,ruggero_rfactor_normalised, norm_plane=True)
exp_data_ratio = exp_data['ratio']

#make subplots for the histograms
fig , (ax1 , ax2) = plt.subplots(1 , 2 , figsize=(9, 5), constrained_layout=True)
ax1.hist(exp_data_ratio, bins=50, alpha=0.5, label='Ratio of Exp/Sim Intensities')
ax1.hist(1/exp_data_ratio, bins=50, range = (np.min(exp_data_ratio) , np.max(exp_data_ratio)),alpha=0.5, label='Ratio of sim/exp Intensities')
ax1.legend()
ax1.set_title('our histogram')
ax1.set(xlabel='ratio', ylabel='freq')
ax2.hist(ruggero_ratio, bins=50, alpha=0.5, label='ruggero exp/sim ratio')
ax2.hist(1/ruggero_ratio, bins=50, alpha=0.5, label='ruggero sim/exp ratio')
ax2.set_title('ruggero histogram')
ax2.legend()
ax1.set(xlabel='ratio', ylabel='freq')
# Out:
# C:\Users\User\AppData\Local\Temp\ipykernel_23532\2782612454.py:1: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   ruggero = pd.read_csv('C:/Users/User/Desktop/uzh_intern/CrystalClearFit/alrisDistortionFit/La2CuO4/raw_data/completely_raw_data.txt' , header=None, delim_whitespace=True)
# ruggero r-factor: 0.2465
# ruggero r-factor not normalised: 0.7921
# [Text(0.5, 0, 'ratio'), Text(0, 0.5, 'freq')]

# %%
x = np.linspace(0 ,1500, 10000)
y = x
plt.scatter(exp_data['intensity_exp'], exp_data['intensity_sim'], s=2, alpha=0.5 , label='our fit')
plt.scatter(ruggero[:,3] , ruggero_scaled_sim, s=2, alpha=0.5, color='red', label='ruggero fit')
plt.plot(x , y, color='black', linestyle='--', label='y=x line')
plt.legend()
plt.grid(True)
plt.title('Comparison of Experimental and Simulated Intensities')
plt.xlabel('Experimental Intensities')
plt.ylabel('Simulated Intensities')
plt.axis('equal')
plt.xlim(0, 1500)
plt.ylim(0, 1500)
plt.show()
# Out:
# Ignoring fixed x limits to fulfill fixed data aspect with adjustable data limits.

# %%
#save the experiment data with simulated intensities
exp_data.to_csv('C:/Users/User/Desktop/uzh_intern/CrystalClearFit/alrisDistortionFit/La2CuO4/fitted_data/La2CuO4_peaks_with_simulated_intensities.txt', index=False , sep='\t')

#save all the parameters and the modes
with open('C:/Users/User/Desktop/uzh_intern/CrystalClearFit/alrisDistortionFit/La2CuO4/fitted_data/La2CuO4_parameters_and_modes.txt', 'w') as f:
    f.write(f"final loss: {min_loss:.8f}\n")
    f.write(f'r-factor normalised: {alris_r_factor_value_normalised:.8f}\n')
    f.write(f'r-factor not normalised: {alris_r_factor_value_not_normalised:.8f}\n')
    f.write(f"learning_rate: {lr[0]:.8f}\n")
    f.write(f"n_epochs: {n_epochs}\n")
    f.write(f"Best model parameters:\n")
    for i, par in enumerate(best_model_pars):
        f.write(f"{mode_names.iloc[i, 0]} : {par.numpy():.8f} \n")

abs_params = tf.abs(best_model_pars)
best_model_pars_compare = best_model_pars.numpy()
best_model_pars_compare = best_model_pars_compare / np.max(best_model_pars_compare)

#save all the parameters and the modes
with open('C:/Users/User/Desktop/uzh_intern/CrystalClearFit/alrisDistortionFit/La2CuO4/fitted_data/La2CuO4_parameters_and_modes_normalised.txt', 'w') as f:
    f.write(f"final loss: {min_loss:.8f}\n")
    f.write(f"learning_rate: {lr[0]:.8f}\n")
    f.write(f"n_epochs: {n_epochs}\n")
    f.write(f"Best model parameters:\n")
    for i, par in enumerate(best_model_pars_compare):
        f.write(f"{mode_names.iloc[i, 0]} : {par:.8f} \n")

# %%
best_data = pd.read_csv('C:/Users/User/Desktop/uzh_intern/CrystalClearFit/alrisDistortionFit/La2CuO4/fitted_data/La2CuO4_peaks_with_simulated_intensities.txt' , sep='\t')

best_data_plot = pd.DataFrame({
    'h': best_data['h'],
    'k': best_data['k'],
    'l': best_data['l'],
    'intensity_sim': best_data['intensity_sim'],
    'intensity_exp': best_data['intensity_exp'],
    'ratio': best_data['ratio'],
})
best_min_loss = best_data['min_loss'].iloc[0]
best_rfactor_normalised = best_data['rfactor_normalised'].iloc[0]
best_data_ratio = best_data_plot['ratio']
# Prepare subplot grid
fig, axs = plt.subplots(1, 2, figsize=(9, 7), constrained_layout=True)
plt.style.use('default')
plot_plane_sim_vs_exp(axs[0], best_data, 0, best_min_loss , best_rfactor_normalised, norm_plane=False)
plot_plane_sim_vs_exp1(axs[1], best_data, 0, best_min_loss , best_rfactor_normalised,norm_plane=False)
plt.show()

ruggero = pd.read_csv('C:/Users/User/Desktop/uzh_intern/CrystalClearFit/alrisDistortionFit/La2CuO4/raw_data/completely_raw_data.txt' , header=None, delim_whitespace=True)
ruggero = ruggero.values.tolist()
ruggero = np.array(ruggero)
ruggero_pd_dataframe = pd.DataFrame({
    'h': ruggero[:,0],
    'k': ruggero[:,1],
    'l': ruggero[:,2],
    'intensity_exp': ruggero[:,3],
    'intensity_sim': ruggero[:,4],
    'scaling': ruggero[:,5],
})

ruggero_scaled_sim = ruggero[:,4] * ruggero[:,5]
ruggero_ratio = (ruggero[:, 3] / np.sum(ruggero[:,3])) / (ruggero_scaled_sim / np.sum(ruggero_scaled_sim)) # Extract the 5th column

rugger_rfactor_normalised , rugger_rfactor_not_normalised = alris_r_factor(ruggero_pd_dataframe)
print(f"ruggero r-factor: {rugger_rfactor_normalised:.4f}")
print(f"ruggero r-factor not normalised: {rugger_rfactor_not_normalised:.4f}")
alris_r_factor_value_normalised , alris_r_factor_value_not_normalised = alris_r_factor(best_data_plot)
print(f"alris normalised r-factor for best data: {alris_r_factor_value_normalised:.4f}")
print(f"alris not normalised r-factor for best data: {alris_r_factor_value_not_normalised:.4f}")


#make subplots for the histograms
fig , (ax1 , ax2) = plt.subplots(1 , 2 , figsize=(9, 5), constrained_layout=True)
ax1.hist(best_data_ratio, bins=50, alpha=0.5, label='Ratio of Exp/Sim Intensities')
ax1.hist(1/best_data_ratio, bins=50, range = (np.min(best_data_ratio) , np.max(best_data_ratio)),alpha=0.5, label='Ratio of sim/exp Intensities')
ax1.legend()
ax1.set_title('our best histogram')
ax1.set(xlabel='ratio', ylabel='freq')
ax2.hist(ruggero_ratio, bins=50, alpha=0.5, label='ruggero exp/sim ratio')
ax2.hist(1/ruggero_ratio, bins=50, alpha=0.5, label='ruggero sim/exp ratio')
ax2.set_title('ruggero histogram')
ax2.legend()
ax1.set(xlabel='ratio', ylabel='freq')
# Out:
# ruggero r-factor: 0.2465
# ruggero r-factor not normalised: 0.7921
# alris normalised r-factor for best data: 0.5491
# alris not normalised r-factor for best data: 1.3231
# C:\Users\User\AppData\Local\Temp\ipykernel_15000\3708074255.py:21: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   ruggero = pd.read_csv('C:/Users/User/Desktop/uzh_intern/CrystalClearFit/alrisDistortionFit/La2CuO4/raw_data/completely_raw_data.txt' , header=None, delim_whitespace=True)
# [Text(0.5, 0, 'ratio'), Text(0, 0.5, 'freq')]

# %%
x = np.linspace(0 ,1500, 10000)
y = x
plt.scatter(best_data_plot['intensity_exp'], best_data_plot['intensity_sim'], s=2, alpha=0.5 , label='our fit')
plt.scatter(ruggero[:,3] , ruggero_scaled_sim, s=2, alpha=0.5, color='red', label='ruggero fit')
plt.plot(x , y, color='black', linestyle='--', label='y=x line')
plt.legend()
plt.grid(True)
plt.title('Comparison of Experimental and Simulated Intensities')
plt.xlabel('Experimental Intensities')
plt.ylabel('Simulated Intensities')
plt.axis('equal')
plt.xlim(0, 1500)
plt.ylim(0, 1500)
plt.show()
# Out:
# Ignoring fixed x limits to fulfill fixed data aspect with adjustable data limits.
